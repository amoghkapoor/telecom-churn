# %% [markdown]
# # Problem Statement

# %% [markdown]
# **Customer churn is a major problem and one of the most important concerns for large companies especially in the telecom sector due to the direct effect on the revenue of the company. Research shows that acquiring a customer is 5 times more costlier than retaining one.**
#
# **Companies are seeking to develop means and tools to predict potential churn customers. Hence, analysing factors that impact customer churn is important to take necessary actions to reduce this churn.**

# %% [markdown]
# # Importing libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# # Data pre-processing

# %%
df = pd.read_csv("WA_Fn-UseC_-Telco-Customer-Churn.csv")

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df["customerID"].duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.drop(columns="customerID", inplace=True)

# %%
def aon_slab(months):
    if months <= 3: return "00 - 03"
    elif months > 3 and months <= 6: return "04 - 06"
    elif months > 6 and months <= 12: return "07 - 12"
    elif months > 12 and months <= 24: return "13 - 24"
    elif months > 24 and months <= 36: return "25 - 36"
    elif months > 36 and months <= 48: return "37 - 48"
    elif months > 48 and months <= 60: return "49 - 60"
    elif months > 60 and months <= 72: return "61 - 72"

# %%
df["AON"] = df["tenure"].apply(aon_slab)

# %%
df = df.replace(r'^\s*$', np.nan, regex=True)
df.isna().sum()
# Out:
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# AON                  0
# dtype: int64

# %%
df = df.astype({"TotalCharges": "float"})

# %%
df["TotalCharges"] = df["TotalCharges"].replace(np.nan, 0)

# %% [markdown]
# ##### Splitting of dataset basis churn

# %%
df_churn = df[df["Churn"] == "Yes"]
df_not_churn = df[df["Churn"] == "No"]

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## General Churn Ratio

# %%
df.groupby("Churn").size().plot(kind="pie", autopct="%1.1f%%", title="Churn Ratio");

# %% [markdown]
# ---
# **The telecom operator has an overall churn of 26.5%**
#
# **The dataset is unbalanced in a near about 3 : 1 ratio for Not-Churn : Churn customers. Due to this, predictions will be biased towards Not-Churn customers.**
#
# ---

# %% [markdown]
# ## Demographic Analysis

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(20, 15))

df.groupby("gender").size().plot(kind="pie", autopct="%1.1f%%", title="Gender Ratio", ax=axes[0,0]);

cols = ["gender", "Partner", "SeniorCitizen", "Dependents"]
title = ["Gender Ratio", "Partner Ratio", "Senior Citizen Ratio", "Dependents Ratio"]
labels = [["Female", "Male"], ["No", "Yes"], ["No", "Yes"], ["No", "Yes"]]

row = 0
col = 0

for i in range(4):
    df.groupby(cols[i]).size().plot(kind="pie", autopct="%1.1f%%", title=title[i], labels=labels[i], ax=axes[row,col]);
    
    col += 1
    if i == 1:
        col, row = 0, 1

# %% [markdown]
# ---
# 1. **Gender and partner composition is almost equally distributed.**
# 2. **Maximum customers are not a senior citizen - 84%.**
# 3. **70% customers do not have a dependent.**
# ---

# %%
fig, axes = plt.subplots(ncols= 2, nrows=2, figsize=(20, 20))

ax1 = (pd.crosstab(df["gender"], df["Churn"], normalize="index")*100).round(2).plot.bar(rot = 0, ylim=(0, 100), ax = axes[0,0])
ax1.set_ylabel("Percentage")
for container in ax1.containers:
    ax1.bar_label(container)
ax1.legend(loc='upper right', title="Churn")
ax1.set_title("Gender based churn %");
ax1.yaxis.label.set_size(15)
ax1.xaxis.label.set_size(15)
ax1.title.set_size(20);

ax2 = (pd.crosstab(df["SeniorCitizen"], df["Churn"], normalize="index")*100).round(2).plot.bar(rot=0, ylim=(0, 100), ax=axes[0,1])
ax2.set_ylabel("Percentage")
for container in ax2.containers:
    ax2.bar_label(container)
ax2.set_xlabel("Senior Citizen")
ax2.set_xticks(ticks=[0,1], labels=["No", "Yes"])
ax2.legend(loc='upper right', title="Churn", labels=["No", "Yes"])
ax2.set_title("Senior citizen based churn %")
ax2.yaxis.label.set_size(15)
ax2.xaxis.label.set_size(15)
ax2.title.set_size(20);

ax3 = (pd.crosstab(df["Dependents"], df["Churn"], normalize="index")*100).round(2).plot.bar(rot=0, ylim=(0, 100), ax=axes[1,0])
for container in ax3.containers:
    ax3.bar_label(container)
ax3.set_ylabel("Percentage")
ax3.legend(loc='upper right', title="Churn")
ax3.set_title("Dependents based churn %")
ax3.yaxis.label.set_size(15)
ax3.xaxis.label.set_size(15)
ax3.title.set_size(20);

ax4 = (pd.crosstab(df["Partner"], df["Churn"], normalize="index")*100).round(2).plot.bar(rot=0, ylim=(0, 100), ax=axes[1,1])
for container in ax4.containers:
    ax4.bar_label(container)
ax4.set_ylabel("Percentage")
ax4.legend(loc='upper right',title="Churn")
ax4.set_title("Partner based churn %")
ax4.yaxis.label.set_size(15)
ax4.xaxis.label.set_size(15)
ax4.title.set_size(20);

# %% [markdown]
# ---
# 1. **There is no major impact in churn basis gender.**
# 2. **Senior citizen customers have a higher percentage of churn.**
# 3. **Customers with no dependents or no partner churn more.**
# ___

# %%
fig, axes = plt.subplots(ncols=2, figsize=(20, 10))

titles = ["% Churn - Non Senior Citizen with no partners or dependents", "% Churn - Senior Citizen with no partners or dependents"]

for i in range(2):
    tmp = df[(df["SeniorCitizen"] == i) & (df["Dependents"] == "No") & (df["Partner"] == "No")]["Churn"].value_counts()
    ax = (tmp/tmp.sum()*100).round(2).plot.bar(rot=0, ax=axes[i], ylim=(0, 100))

    for container in ax.containers:
        ax.bar_label(container)

    ax.set_ylabel("Percentage")
    ax.set_title(titles[i]);

# %% [markdown]
# ___
# **Approximately 50% of senior citizens having no partner or dependents churn out. This might be due to the fact that they are free to move to other operators without any obligation to others.**
# ___

# %%
fig, axes = plt.subplots(ncols=2, figsize=(20, 10))

titles = ["% Churn - Non Senior Citizen Ratio of Dependent & Non-Dependent", "% Churn - Senior Citizen Ratio of Dependent & Non-Dependent"]

for i in range(2):
    
    tmp = df[(df["SeniorCitizen"] == i) & (df["Churn"] == "Yes")]["Dependents"].value_counts()
    ax = (tmp/tmp.sum()*100).round(2).plot.bar(rot=0, ax=axes[i], ylim=(0, 100))

    for container in ax.containers:
        ax.bar_label(container)

    ax.set_ylabel("Percentage")
    ax.set_title(titles[i]);

# %% [markdown]
# ---
# - **Dependent as a parameter cannot be influenced by the operator.**
# - **Senior citizen with no dependents and with high churn need to be further analysed to identify if churn is during their life cycle or due to deaths.**
# ___

# %% [markdown]
# ## Outlier Analysis

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(20, 12))

cols = ["tenure", "TotalCharges", "MonthlyCharges"]

for i in range(3):
    sns.boxplot(data=df, y=cols[i], ax=axes[i]);
    axes[i].yaxis.label.set_size(15)

# %% [markdown]
# ___
# **There are no outliers in the above three data columns.**
# ___

# %% [markdown]
# ## Feature Analysis

# %% [markdown]
# ### Customer spread across Age On Network

# %%
plt.hist(df["tenure"], bins=20)
plt.xlabel("Tenure")
plt.ylabel("Number of customers")
plt.title("Customer spread across Tenure");

# %% [markdown]
# ___
# **There is a high focus on new acquisitions**
# ___

# %%
sns.set_style("white")

fig, ax1 = plt.subplots(figsize=(12, 6))
temp1 = df.groupby("AON")["Churn"].count()
plt.bar(x=temp1.index, height=temp1.values, label="Number of customers" )
ax1.set_ylabel("Number of Customers")
ax1.set_xlabel("AON (months)")

ax2 = ax1.twinx()
ax2.set_ylim(0, 100)
temp2 = (pd.crosstab(df["AON"], df["Churn"], normalize="index")["Yes"]*100).reset_index()
plt.plot(temp2["AON"], temp2["Yes"], c="#ff7f0e", label="Churn Rate")
vals = ax2.get_yticks()
ax2.set_ylabel("Churn Rate")
ax2.set_yticklabels(['{} %'.format(x) for x in vals])

blue_patch = mpatches.Patch(color='#1f77b4', label='Number of customers')
orange_patch = mpatches.Patch(color='#ff7f0e', label='Churn rate')
plt.legend(handles=[blue_patch, orange_patch], loc="upper left")
plt.title("% Churn against AON");

pd.concat([temp1, temp2.set_index("AON")], axis=1).round(2).reset_index().rename(columns={"Churn": "Count", "Yes": "Churn Rate"})
# Out:
# /var/folders/gw/6_tkq4n57_nc8ff1z308kvqr0000gp/T/ipykernel_2047/3188960041.py:15: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_yticklabels(['{} %'.format(x) for x in vals])
#        AON  Count  Churn Rate
# 0  00 - 03   1062       56.21
# 1  04 - 06    419       44.63
# 2  07 - 12    705       35.89
# 3  13 - 24   1024       28.71
# 4  25 - 36    832       21.63
# 5  37 - 48    762       19.03
# 6  49 - 60    832       14.42
# 7  61 - 72   1407        6.61

# %% [markdown]
# ___
# - **Quality of acquisition is a concern as only 44% of new customers after 3 months choose to stay with the current telecom operator, whereas customers with higher AON are loyal.**
# - **Churn % is a reducing trend against AON.**
# ___

# %%
df_3 = df[df["AON"] == "00 - 03"]
df_3
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female              0     Yes         No       1           No
# 2       Male              0      No         No       2          Yes
# 4     Female              0      No         No       2          Yes
# 20      Male              1      No         No       1           No
# 22      Male              0      No         No       1          Yes
# ...      ...            ...     ...        ...     ...          ...
# 7010  Female              1     Yes         No       1          Yes
# 7016  Female              0      No         No       1          Yes
# 7018    Male              0     Yes        Yes       1          Yes
# 7030  Female              0      No         No       2          Yes
# 7032    Male              1      No         No       1          Yes
#
#          MultipleLines InternetService       OnlineSecurity  \
# 0     No phone service             DSL                   No
# 2                   No             DSL                  Yes
# 4                   No     Fiber optic                   No
# 20    No phone service             DSL                   No
# 22                  No              No  No internet service
# ...                ...             ...                  ...
# 7010               Yes     Fiber optic                   No
# 7016                No             DSL                   No
# 7018                No     Fiber optic                   No
# 7030                No              No  No internet service
# 7032               Yes     Fiber optic                   No
#
#              OnlineBackup  ...          TechSupport          StreamingTV  \
# 0                     Yes  ...                   No                   No
# 2                     Yes  ...                   No                   No
# 4                      No  ...                   No                   No
# 20                     No  ...                   No                   No
# 22    No internet service  ...  No internet service  No internet service
# ...                   ...  ...                  ...                  ...
# 7010                   No  ...                   No                   No
# 7016                  Yes  ...                   No                   No
# 7018                   No  ...                   No                   No
# 7030  No internet service  ...  No internet service  No internet service
# 7032                   No  ...                   No                   No
#
#           StreamingMovies        Contract PaperlessBilling     PaymentMethod  \
# 0                      No  Month-to-month              Yes  Electronic check
# 2                      No  Month-to-month              Yes      Mailed check
# 4                      No  Month-to-month              Yes  Electronic check
# 20                    Yes  Month-to-month              Yes  Electronic check
# 22    No internet service  Month-to-month               No      Mailed check
# ...                   ...             ...              ...               ...
# 7010                   No  Month-to-month              Yes  Electronic check
# 7016                   No  Month-to-month               No  Electronic check
# 7018                   No  Month-to-month              Yes      Mailed check
# 7030  No internet service  Month-to-month              Yes      Mailed check
# 7032                   No  Month-to-month              Yes  Electronic check
#
#      MonthlyCharges  TotalCharges  Churn      AON
# 0             29.85         29.85     No  00 - 03
# 2             53.85        108.15    Yes  00 - 03
# 4             70.70        151.65    Yes  00 - 03
# 20            39.65         39.65    Yes  00 - 03
# 22            20.15         20.15    Yes  00 - 03
# ...             ...           ...    ...      ...
# 7010          74.45         74.45    Yes  00 - 03
# 7016          49.95         49.95     No  00 - 03
# 7018          70.65         70.65    Yes  00 - 03
# 7030          20.05         39.25     No  00 - 03
# 7032          75.75         75.75    Yes  00 - 03
#
# [1062 rows x 21 columns]

# %%
a = (((df_churn["AON"].sort_values().value_counts(sort=False)))/(df_churn["AON"].value_counts().sum())*100).round(2).plot(kind="bar", figsize=(11, 6))
plt.xticks(rotation=0)
plt.xlabel("AON (months)")
plt.ylabel("Percentage")
plt.title("AON Wise - Churn Ratio");

for container in a.containers:
    a.bar_label(container)

(((df_churn["AON"].sort_values().value_counts(sort=False)))/(df_churn["AON"].value_counts().sum())*100).round(2).reset_index().rename(columns={"count": "Percentage"})
# Out:
#        AON  Percentage
# 0  00 - 03       31.94
# 1  04 - 06       10.01
# 2  07 - 12       13.54
# 3  13 - 24       15.73
# 4  25 - 36        9.63
# 5  37 - 48        7.76
# 6  49 - 60        6.42
# 7  61 - 72        4.98

# %% [markdown]
# ___
# **Maximum number of customers churned are under 3 months of usage.**
#
# **There is a sharp decline after 3 months in the churn rate.**
# ___

# %%
sns.boxplot(data=df, x="Churn", y="tenure", palette=["#ff7f0e", "#1f77b4"])

plt.title("Churn - Tenure");

# %% [markdown]
# ___
# - **50% of the customers who left the service did so in the first 10 months.**
#
# - **This is probably because the customers are testing out the varied services available to them and hence, in order to save money, 1 month service is tested out.**
# ___

# %% [markdown]
# ### Phone Service

# %%
fig, axes = plt.subplots(ncols =2, figsize=(20, 10))
df.groupby("PhoneService").size().plot(kind="pie", autopct="%1.1f%%", labels=["No", "Yes"], title="Phone Service Distribution", ax=axes[0]);
df[df["PhoneService"] == "Yes"].groupby("MultipleLines").size().plot(kind="pie", autopct="%1.1f%%", labels=["No", "Yes"], title="Multiple Lines Distribution");

# %%
fig, axes = plt.subplots(ncols=2, figsize=(19, 8))

ax1 = (pd.crosstab(df["PhoneService"], df["Churn"], normalize="index")*100).round(2).plot.bar(rot=0, ylim=(0, 100), ax=axes[0])
ax1.legend(loc='upper right', title="Churn")
ax1.set_xlabel("Phone Service")
ax1.set_ylabel("Percentage")

for container in ax1.containers:
    ax1.bar_label(container)
ax1.yaxis.label.set_size(15)
ax1.xaxis.label.set_size(15)
ax1.set_title("% Churn - Phone Service");

ax2 = (pd.crosstab(df[df["PhoneService"] != "No"]["MultipleLines"], df["Churn"], normalize="index")*100).round(2).plot.bar(rot = 0, ax=axes[1])
ax2.legend(loc='upper right', title="Churn")
ax2.set_xlabel("Multiple Lines")
ax2.set_ylabel("Percentage")

for container in ax2.containers:
    ax2.bar_label(container)
ax2.yaxis.label.set_size(15)
ax2.xaxis.label.set_size(15)
ax2.set_title("% Churn - Multiple Lines");

# %% [markdown]
# ___
# - **There is no significant difference in churn percentage for customers subscribing to phone vs non-subscription.**
# - **Multiple line subscription within phone service also have a equal distribution of churn with customers who do not have multiple lines.**
# ___

# %%
fig,axes = plt.subplots(ncols=2, figsize=(20, 10))

ax1 = sns.boxplot(data=df, x="PhoneService", y="MonthlyCharges", ax=axes[0])
ax1.set_ylabel("Monthly Charges")
ax1.set_xlabel("Phone Service")
ax1.set_title("Monthly Charge basis Phone Service");

ax2 = sns.boxplot(data=df[df["PhoneService"] != "No"], x="MultipleLines", y="MonthlyCharges", ax=axes[1])
ax2.set_ylabel("Monthly Charges")
ax2.set_xlabel("Multiple Lines")
ax2.set_title("Monthly Charge basis Multiple Lines");

# %% [markdown]
# ___
# **As expected the monthly charge for customers availing phone service is high in comparision to customers not subscribing and similarly for subscribers with multiple lines have a high monthly charge.**
# ___

# %% [markdown]
# ### Internet Service

# %%
fig, axes = plt.subplots(ncols = 2, figsize=(20, 9))

ax1 = df.groupby("InternetService").size().plot(kind="pie", autopct="%1.1f%%", title="Internet Service Distribution", ax=axes[0]);

ax2 = (pd.crosstab(df["InternetService"], df["Churn"], normalize="index")*100).round(2).plot.bar(rot=0, ylim=(0, 100), ax=axes[1])
ax2.legend(loc='upper right', title="Churn")
ax2.set_ylabel("Percentage")
ax2.set_xlabel("Internet Service")
for container in ax2.containers:
    ax2.bar_label(container)
ax2.yaxis.label.set_size(15)
ax2.xaxis.label.set_size(15)
ax2.set_title("% Churn against Internet Service");

# %% [markdown]
# ___
# **Maximum number of customers have adopted fiber optics as their mode of internet service and also have a high percentage of churn in comparison to DSL service.**
# ___

# %%
sns.boxplot(data=df, x="InternetService", y="MonthlyCharges")
plt.ylabel("Monthly Charges")
plt.xlabel("Internet Service")
plt.title("Monthly Charges basis Internet Services");

# %% [markdown]
# ___
# **Fiber optic service have a higher charge and churn % in comparison to DSL which is in sync to high churn percentage in customers with a high monthly charge.**
# ___

# %%
tmp = df[df["SeniorCitizen"] == 1]["InternetService"].value_counts()
ax = (tmp/tmp.sum()*100).round(2).plot.bar(rot=0, ylim=(0, 100), title="Distribution of interent service of senior citizens", ylabel="Percentage");

for container in ax.containers:
    ax.bar_label(container)

# %%
tmp = df[df["InternetService"] == "Fiber optic"]["SeniorCitizen"].value_counts()
ax = (tmp/tmp.sum()*100).round(2).plot.bar(rot=0, ylim=(0, 100))
for container in ax.containers:
    ax.bar_label(container)

# %% [markdown]
# ___
# **73% of senior citizens opt for the fiber optic as their choice of internet service, which makes up 27% of the total market of fiber optics**
# ___

# %%
ax = (pd.crosstab( df[df["SeniorCitizen"] == 1]["InternetService"], df[df["SeniorCitizen"] == 1]["Churn"], normalize="index")*100).round(2).plot.bar(ylim=(0, 100), rot=0, title="% Churn of senior citizens basis internet service", ylabel="Percentage");
for container in ax.containers:
    ax.bar_label(container)

# %% [markdown]
# ___
# **Nearly 50% of the senior citizens with fiber optic as their internet service churn out, suggesting that the operator must certainly focus on the senior citizen customer segement using this service.**
# ___

# %%
ax = (pd.crosstab( df[df["SeniorCitizen"] == 0]["InternetService"], df[df["SeniorCitizen"] == 0]["Churn"], normalize="index")*100).round(2).plot.bar(ylim=(0, 100), rot=0, title="% Churn of non senior citizens basis internet service", ylabel="Percentage");
for container in ax.containers:
    ax.bar_label(container)

# %% [markdown]
# ___
# - **40% of non-senior citizen with fiber optics also churn out.**
# - **This indicates that the problem is with the fiber optics rather than any age segment.**
# ___

# %%
fig, axes = plt.subplots(ncols = 3, figsize=(12, 5))

df[df["PhoneService"] == "Yes"].groupby("Churn").size().plot(kind="pie", autopct="%1.1f%%", ax=axes[0], title="% Churn - Phone Service Base")
df[df["InternetService"] != "No"].groupby("Churn").size().plot(kind="pie", autopct="%1.1f%%", ax=axes[1], title="% Churn - Internet Service Base")
df[(df["PhoneService"] == "Yes") & (df["InternetService"] != "No")].groupby("Churn").size().plot(kind="pie", autopct="%1.1f%%", ax=axes[2], title="% Churn - Phone & Internet Service Base");

# %% [markdown]
# ___
# **Customer with internet service have a higher churn percentage as compared to customer with only phone service.**
# ___

# %% [markdown]
# ### Addon Services within Internet Service

# %%
df['Number of Additional Services'] = (df[['OnlineSecurity','OnlineBackup','DeviceProtection',
                                           'TechSupport','StreamingTV','StreamingMovies']]=="Yes").sum(axis=1)

# %%
sns.set_style("white")

fig, ax1 = plt.subplots(figsize=(12, 6))
temp1 = df.groupby("Number of Additional Services")["Churn"].count()
plt.bar(x=temp1.index, height=temp1.values, label="Number of Additional Services" )
ax1.set_ylabel("Number of customers")
ax1.set_xlabel("Number of Additional Services")

ax2 = ax1.twinx()
ax2.set_ylim(0, 100)
temp2 = (pd.crosstab(df["Number of Additional Services"], df["Churn"], normalize="index")["Yes"]*100).reset_index()
plt.plot(temp2["Number of Additional Services"], temp2["Yes"], c="#ff7f0e", label="Churn Rate")
vals = ax2.get_yticks()
ax2.set_ylabel("Churn Rate")
ax2.set_yticklabels(['{} %'.format(x) for x in vals])

blue_patch = mpatches.Patch(color='#1f77b4', label='Number of customers')
orange_patch = mpatches.Patch(color='#ff7f0e', label='Churn rate')
plt.legend(handles=[blue_patch, orange_patch], loc="upper right");
plt.title("Addon Service count vs Churn Percentage")

pd.concat([temp1, temp2.set_index("Number of Additional Services")], axis=1).round(2).reset_index().rename(columns={"Churn": "Count", "Yes": "Churn Rate"})
# Out:
# /var/folders/gw/6_tkq4n57_nc8ff1z308kvqr0000gp/T/ipykernel_2047/2777505033.py:15: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_yticklabels(['{} %'.format(x) for x in vals])
#    Number of Additional Services  Count  Churn Rate
# 0                              0   2219       21.41
# 1                              1    966       45.76
# 2                              2   1033       35.82
# 3                              3   1118       27.37
# 4                              4    852       22.30
# 5                              5    571       12.43
# 6                              6    284        5.28

# %% [markdown]
# ___
# **Churn percentage reduces with increase in additional services, highest in customers with only one additional services.**
# ___

# %%
df_temp = (df[df["Number of Additional Services"] == 1].replace({"Yes": 1, "No": 0})).groupby("Churn")[["OnlineSecurity", "OnlineBackup", "DeviceProtection", "TechSupport", "StreamingTV", "StreamingMovies"]].sum()
for column in df_temp.columns:
    df_temp[column] = (df_temp[column]/(df_temp[column].sum())*100).round(2)
ax = df_temp.transpose().plot.bar(ylim=(0, 100), figsize=(15, 8), ylabel="Percentage", rot=0)
ax.set_figsize=(20, 10)
plt.legend(loc='center right', bbox_to_anchor=(1.07, 0.5), title="Churn", labels=["No", "Yes"])
plt.title("Single additional service customers - Churn % ")

for container in ax.containers:
    ax.bar_label(container);

# %% [markdown]
# ___
# - **Quality of Streaming Services seems to be a serious concern as they have high churn percentage > 60 % which should be evaluated by the operator to take corrective action.**
# - **Customers with online security and tech support have a lower churn percentage which could be a strong point of the operator which should be leveraged by the operator to reduce churn.**
# ___

# %% [markdown]
# ##### Further spliting the data basis interent services for analysis of the additional services

# %%
df_internet = df[df["InternetService"] != "No"]

# %%
fig, axes = plt.subplots(ncols=2, nrows=3, figsize=(16, 21))

cols = ["OnlineSecurity", "OnlineBackup", "DeviceProtection", "TechSupport", "StreamingTV", "StreamingMovies"]
col, row = 0, 0

fig.suptitle("Additional Service-wise customer churn %", fontsize=30)

for i in range(6):
    ax = (pd.crosstab(df_internet["Churn"], df_internet[cols[i]], normalize="index")*100).round(2).plot.bar(rot=0, ylabel="Percentage", ylim=(0, 100), ax=axes[row, col])

    for container in ax.containers:
        ax.bar_label(container)

    ax.legend(loc='upper left', title=cols[i]);
    
    col += 1
    if i == 1:
        col, row = 0, 1
    elif i == 3:
        col, row = 0, 2

# %% [markdown]
# ___
# - **StreamingTV and StreamingMovies display an identical graph. Irrespective of being subscribed to StreamingTV & StreamingMovies, a lot of customers have been churned. Looks like the streaming content was not entirely at fault.**
# - **OnlineSecurity and TechSupport are the strong points of the operator, customers opting for these service tend to churn less.**
# ___

# %% [markdown]
# ### Contracts

# %%
ax =(pd.crosstab(df["Contract"], df["Churn"], normalize="index")*100).round(2).plot.bar(rot=0, color=["#1f77b4", "#ff7f0e"])

for container in ax.containers:
    ax.bar_label(container)

plt.ylabel("Percentage")
plt.legend(bbox_to_anchor=(1.2, 0.5), title="Churn")
plt.title("Contract wise Churn %");

# %% [markdown]
# ### Paperless Billing

# %%
ax=(pd.crosstab(df["PaperlessBilling"], df["Churn"], normalize="index")*100).round(2).plot.bar(rot=0, ylim=(0, 100))

for container in ax.containers:
    ax.bar_label(container)
    
plt.ylabel("Percentage")
plt.title("% Churn - Paperless Billing")
plt.legend(bbox_to_anchor=(1.2, 0.5), title="Churn");

# %%
sns.boxplot(data=df, x="PaperlessBilling", y="MonthlyCharges")
plt.title("Monthly charges basis Paperless Billing");

# %% [markdown]
# ### Payment Methods

# %%
ax = (pd.crosstab(df["PaymentMethod"], df["Churn"], normalize="index").round(2)*100).plot.bar(ylim=(0, 100), rot=15)

for container in ax.containers:
    ax.bar_label(container)
    
plt.ylabel("Percentage")
plt.title("% Churn - Payment Method")
plt.legend(loc='center right', bbox_to_anchor=(1.2, 0.5), title="Churn");

# %%
sns.boxplot(data=df, x="PaymentMethod", y="MonthlyCharges")
plt.xticks(rotation=45)
plt.title("Monthly Charge basis Payment Method");

# %%
df[df["PaymentMethod"] == "Electronic check"]

fig, axes = plt.subplots(ncols=2, figsize=(20, 10))
fig.suptitle("Scatterplot of customers using electronic check as a payment method basis Tenure and Monthly Charges", fontsize=20)

sns.scatterplot(data=df_not_churn[df_not_churn["PaymentMethod"] == "Electronic check"], x="tenure", y="MonthlyCharges", hue="Churn", alpha=1, ax=axes[0]);
sns.scatterplot(data=df_churn[df_churn["PaymentMethod"] == "Electronic check"], x="tenure", y="MonthlyCharges", hue="Churn", alpha=1, ax=axes[1], palette=["#ff7f0e"]);

# %% [markdown]
# ___
# - **Operator need to focus on online self service platform to ensure proper bill delivery and receipt of payments as there seems to be an issue with paperless billing and electronic checks which are both done online**
#
#
# - **Long term plans to be promoted as there is a lower churn percentage, this can be done by offering a lower rate as compared to the shorter plans.**
#
#
# - **Depending on the contract, operator can charge an exit levy for customers moving out in a monthly plan**
# ___

# %% [markdown]
# ### Charges

# %%
sns.kdeplot(df["TotalCharges"][(df["Churn"] == "No") ], fill = True, label="No")
sns.kdeplot(df["TotalCharges"][(df["Churn"] == "Yes") ], fill= True, label="Yes")
plt.legend(title="Churn");

# %%
sns.kdeplot(df["MonthlyCharges"][(df["Churn"] == "No") ], fill = True, label="No")
sns.kdeplot(df["MonthlyCharges"][(df["Churn"] == "Yes") ], fill= True, label="Yes")
plt.legend(title="Churn");

# %% [markdown]
# ##### To find the reason for the dips in graph

# %%
df[(df["MonthlyCharges"] <= 20) & (df["MonthlyCharges"] >= 0)].shape[0]
# Out:
# 656

# %%
df[(df["MonthlyCharges"] <= 30) & (df["MonthlyCharges"] >= 20)].shape[0]
# Out:
# 1040

# %%
df[(df["MonthlyCharges"] <= 40) & (df["MonthlyCharges"] >= 30)].shape[0]
# Out:
# 185

# %%
df[(df["MonthlyCharges"] <= 50) & (df["MonthlyCharges"] >= 40)].shape[0]
# Out:
# 462

# %%
sns.kdeplot(df["MonthlyCharges"][(df["Churn"] == "No") & (df["InternetService"] == "Fiber optic")], fill = True, label="No")
sns.kdeplot(df["MonthlyCharges"][(df["Churn"] == "Yes") & (df["InternetService"] == "Fiber optic")], fill= True, label="Yes")
plt.legend(title="Churn");

# %%
sns.scatterplot(data=df.sort_values("AON"), x='MonthlyCharges',y='TotalCharges',hue='AON',
               alpha=1,linewidth=0.5, palette="Dark2");

# %%
fig, axes = plt.subplots(ncols=2, figsize=(20, 10))
fig.suptitle("Scatterplot of customers basis Tenure and Monthly Charges", fontsize=20)

sns.scatterplot(data=df_not_churn, x="tenure", y="MonthlyCharges", hue="Churn", alpha=1, ax=axes[0]);
sns.scatterplot(data=df_churn, x="tenure", y="MonthlyCharges", hue="Churn", alpha=1, ax=axes[1], palette=["#ff7f0e"]);

# %% [markdown]
# ___
# - **Market is price sensitive as there is increase in churn against higher charge.**
# - **It is indicative that customers having a high monthly charge during onboarding churn the highest.**
# - **Old customers churn rarely and are loyal, but even the few customers that do so have a high monthly charge.**
# - **Customers with the base plan(lowest monthly charge) generally do not churn.**
# ___

# %%
sns.boxplot(data=df, x="Churn", y="MonthlyCharges", palette=["#ff7f0e", "#1f77b4"])
plt.title("Monthly Charge basis Churn");

# %%
sns.boxplot(data=df, x="SeniorCitizen", y="MonthlyCharges", palette=["#1f77b4", "#ff7f0e"])
plt.xlabel("Senior Citizen")
plt.xticks(ticks=[0,1], labels=["No", "Yes"])
plt.title("Monthly charge basis Senior Citizen");

# %%
fig, ax = plt.subplots(figsize=(20, 12))
sns.boxplot(data=df.sort_values("AON"), x="AON", y="MonthlyCharges", hue="Churn", palette=["#ff7f0e", "#1f77b4"])
plt.title("Monthly charge basis AON split on churn");

# %% [markdown]
# ___
# **The impact of monthly charges can be better analysed if the data was a continuous data, shared data looks to be a total charges divided by tenure, which can be misleading.**
# ___

# %% [markdown]
# # Analysis

# %% [markdown]
# ### The EDA showed both strengths and weaknesses of the operator.
#
# **Below are the factors and segments of customers the operator must focus on to reduce churn:**
#
# 1. Customers who have onboarded within the last 3 months.
# 2. There seems to be an issue with the fiber optic as an internet service.
# 3. Senior citizens without any dependents or partners.
# 4. Market looks to be price sensitive, customers with high monthly charges are one of the major reasons for churn.
# 5. Customers with monthly contracts have a higher churn rate as compared to customers with longer contract periods.
# 6. Customers opting for payments through electronic cheque and paperless billing.
#
# **Strengths of the operator which came out as part of analysis are listed below:**
# 1. Customers opting for tech support and online security have a lower churn percentage.
# 2. Customers who cross the 10 months AON churn less.

# %% [markdown]
# # Proposed Solutions

# %% [markdown]
# 1. The operator should review and analyse the pricing and the services offered by other operators in the market and benchmark his offerings to identify reasons for churn, similarly the sale channels followed by other operators should be compared to restrict 0-3 months churn.
#
#
# 2. Price elasticity models should be applied to determine the charges applied for various services.
#
#
# 3. The operator should strategise to maximise its topline and reduce bottom line by marginally reducing the monthly charges which would eventually have a longer AON customers and reduce acquisition cost.
#
#
# 4. To promote long term plans there should be a discount component as compared to monthly charges, for trial purpose a 6 month plan can also be introduced with 15 days rental discount.
#     - Only potential risk in long term plans is if the customer defaults in bill payment.
#     - There should be an exit charge in case customers are churning out within 12 months of onboarding.
#
#
# 5. Technical review and analysis for fiber optics service to be done to identify service gaps and take corrective action to improve the service quality.
#     - Customers’ complaints for fiber optic service should be analysed to understand the VOC(Voice of Customer) to get an insight into the problem faced by customers.
#     - Testing lab to be set up by the operator to experience the services.
#
#
# 6. Self service platform available to customers needs to be enhanced with a full bouquet of digital payment options and availability of digital bill copies.
#     - Improvement in UI/UX for seamless experience.
#     - Ease of setting up E-Check (Automated Clearing House) facility on self-service platform and avoid paper based E-check mandate.

# %% [markdown]
# # Model Building

# %% [markdown]
# ## Importing libraries

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import AdaBoostClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier

from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, average_precision_score
from sklearn.metrics import roc_auc_score, roc_curve, auc

from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold, StratifiedKFold, cross_val_score

from imblearn.over_sampling import SMOTE

# %% [markdown]
# ## Label Encoding

# %%
df.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
#        'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
#        'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod',
#        'MonthlyCharges', 'TotalCharges', 'Churn', 'AON',
#        'Number of Additional Services'],
#       dtype='object')

# %%
def ml_model(X_train, X_test, y_train, y_test):
    models = [
        ('Logistic Regression', LogisticRegression(random_state=42)),
        ('Decision Tree', DecisionTreeClassifier(random_state=42)),
        ('Random Forest', RandomForestClassifier(random_state=42)),
        ('Gaussian Naive Bayes', GaussianNB()),
        ('K-Nearest Neighbors', KNeighborsClassifier()),
        ('Support Vector Machine', SVC(random_state=42)),
        ('Gradient Boosting', GradientBoostingClassifier(random_state=42)),
        ('XGBoost', XGBClassifier(random_state=42)),
        ('LightGBM', LGBMClassifier(random_state=42)),
        ('ADA Boosting', AdaBoostClassifier(random_state=42)),
        ('CAT Boost', CatBoostClassifier(random_state=42))
    ]
    
    results = []

    for model_name, model in models:
        model.fit(X_train, y_train)

        y_pred = model.predict(X_test)

        accuracy = accuracy_score(y_test, y_pred)
        precision = precision_score(y_test, y_pred)
        f1 = f1_score(y_test, y_pred)
        recall = recall_score(y_test, y_pred)

        result = {
            'Model': model_name,
            'Accuracy': accuracy,
            'Precision': precision,
            'Recall': recall,
            'F1 Score': f1
        }
        results.append(result)
        
    return results

# %%
X = df.drop(columns=["Churn", "AON", "Number of Additional Services"])
y = df["Churn"].replace({"Yes": 1, "No": 0})

# %%
labelencoder = LabelEncoder()
cols = X.select_dtypes(include=["object"])

for col in cols:
    X[col] = labelencoder.fit_transform(X[col])

# %%
def encode_data(dataframe_series):
    if dataframe_series.dtype=='object':
        dataframe_series = LabelEncoder().fit_transform(dataframe_series)
    return dataframe_series

X = X.apply(lambda x: encode_data(x))

# %% [markdown]
# ### Handling imbalance data

# %% [markdown]
# #### Using Synthetic Minority Oversampling Technique to produce more samples where customers churn out

# %%
over = SMOTE(sampling_strategy = 1)
X,y = over.fit_resample(X,y)

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, random_state =2, test_size = 0.2)

# %%
ss = StandardScaler()
cols = ["MonthlyCharges", "TotalCharges", "tenure"]
x_train[cols] = ss.fit_transform(x_train[cols])

# %%
x_test[cols] = ss.transform(x_test[cols])

# %%
res = ml_model(x_train, x_test, y_train, y_test)
# Out:
# [LightGBM] [Info] Number of positive: 4144, number of negative: 4134
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001035 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 627
# [LightGBM] [Info] Number of data points in the train set: 8278, number of used features: 19
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500604 -> initscore=0.002416
# [LightGBM] [Info] Start training from score 0.002416
# Learning rate set to 0.025403
# 0:	learn: 0.6764517	total: 60.1ms	remaining: 1m
# 1:	learn: 0.6625356	total: 62.2ms	remaining: 31s
# 2:	learn: 0.6503825	total: 64.4ms	remaining: 21.4s
# 3:	learn: 0.6377362	total: 66.4ms	remaining: 16.5s
# 4:	learn: 0.6257189	total: 68.4ms	remaining: 13.6s
# 5:	learn: 0.6145336	total: 70.3ms	remaining: 11.6s
# 6:	learn: 0.6041416	total: 72.2ms	remaining: 10.2s
# 7:	learn: 0.5947806	total: 74ms	remaining: 9.18s
# 8:	learn: 0.5853420	total: 76ms	remaining: 8.37s
# 9:	learn: 0.5768644	total: 77.8ms	remaining: 7.7s
# 10:	learn: 0.5678271	total: 79.5ms	remaining: 7.15s
# 11:	learn: 0.5605051	total: 81.1ms	remaining: 6.67s
# 12:	learn: 0.5530659	total: 82.7ms	remaining: 6.28s
# 13:	learn: 0.5462995	total: 84.7ms	remaining: 5.96s
# 14:	learn: 0.5397997	total: 86.8ms	remaining: 5.7s
# 15:	learn: 0.5338955	total: 89ms	remaining: 5.47s
# 16:	learn: 0.5286007	total: 90.6ms	remaining: 5.24s
# 17:	learn: 0.5223545	total: 92.4ms	remaining: 5.04s
# 18:	learn: 0.5175377	total: 94.3ms	remaining: 4.87s
# 19:	learn: 0.5126716	total: 95.8ms	remaining: 4.69s
# 20:	learn: 0.5088326	total: 98ms	remaining: 4.57s
# 21:	learn: 0.5043281	total: 99.9ms	remaining: 4.44s
# 22:	learn: 0.5001928	total: 102ms	remaining: 4.33s
# 23:	learn: 0.4964647	total: 104ms	remaining: 4.21s
# 24:	learn: 0.4927544	total: 106ms	remaining: 4.12s
# 25:	learn: 0.4879041	total: 108ms	remaining: 4.05s
# 26:	learn: 0.4833641	total: 110ms	remaining: 3.96s
# 27:	learn: 0.4783371	total: 112ms	remaining: 3.88s
# 28:	learn: 0.4751425	total: 114ms	remaining: 3.8s
# 29:	learn: 0.4723169	total: 115ms	remaining: 3.73s
# 30:	learn: 0.4685213	total: 117ms	remaining: 3.66s
# 31:	learn: 0.4657674	total: 119ms	remaining: 3.6s
# 32:	learn: 0.4624083	total: 121ms	remaining: 3.54s
# 33:	learn: 0.4591410	total: 123ms	remaining: 3.5s
# 34:	learn: 0.4562622	total: 125ms	remaining: 3.44s
# 35:	learn: 0.4531045	total: 126ms	remaining: 3.39s
# 36:	learn: 0.4511837	total: 128ms	remaining: 3.34s
# 37:	learn: 0.4491879	total: 130ms	remaining: 3.3s
# 38:	learn: 0.4472364	total: 132ms	remaining: 3.25s
# 39:	learn: 0.4454038	total: 134ms	remaining: 3.21s
# 40:	learn: 0.4433934	total: 136ms	remaining: 3.18s
# 41:	learn: 0.4402170	total: 138ms	remaining: 3.15s
# 42:	learn: 0.4377255	total: 140ms	remaining: 3.12s
# 43:	learn: 0.4349338	total: 142ms	remaining: 3.09s
# 44:	learn: 0.4329463	total: 144ms	remaining: 3.06s
# 45:	learn: 0.4312323	total: 146ms	remaining: 3.03s
# 46:	learn: 0.4296688	total: 148ms	remaining: 3.01s
# 47:	learn: 0.4280497	total: 150ms	remaining: 2.98s
# 48:	learn: 0.4264571	total: 152ms	remaining: 2.96s
# 49:	learn: 0.4249917	total: 154ms	remaining: 2.93s
# 50:	learn: 0.4233981	total: 156ms	remaining: 2.9s
# 51:	learn: 0.4211591	total: 157ms	remaining: 2.87s
# 52:	learn: 0.4197033	total: 159ms	remaining: 2.84s
# 53:	learn: 0.4177527	total: 161ms	remaining: 2.82s
# 54:	learn: 0.4156118	total: 163ms	remaining: 2.79s
# 55:	learn: 0.4143170	total: 164ms	remaining: 2.77s
# 56:	learn: 0.4133943	total: 166ms	remaining: 2.74s
# 57:	learn: 0.4122493	total: 167ms	remaining: 2.71s
# 58:	learn: 0.4106224	total: 169ms	remaining: 2.69s
# 59:	learn: 0.4087531	total: 171ms	remaining: 2.67s
# 60:	learn: 0.4076575	total: 173ms	remaining: 2.66s
# 61:	learn: 0.4066251	total: 175ms	remaining: 2.64s
# 62:	learn: 0.4055872	total: 176ms	remaining: 2.62s
# 63:	learn: 0.4046874	total: 178ms	remaining: 2.61s
# 64:	learn: 0.4039135	total: 180ms	remaining: 2.59s
# 65:	learn: 0.4027347	total: 182ms	remaining: 2.57s
# 66:	learn: 0.4008213	total: 183ms	remaining: 2.55s
# 67:	learn: 0.3994965	total: 185ms	remaining: 2.54s
# 68:	learn: 0.3987998	total: 187ms	remaining: 2.52s
# 69:	learn: 0.3980702	total: 189ms	remaining: 2.51s
# 70:	learn: 0.3973604	total: 190ms	remaining: 2.49s
# 71:	learn: 0.3962964	total: 192ms	remaining: 2.48s
# 72:	learn: 0.3954389	total: 194ms	remaining: 2.46s
# 73:	learn: 0.3943433	total: 196ms	remaining: 2.46s
# 74:	learn: 0.3935906	total: 199ms	remaining: 2.45s
# 75:	learn: 0.3923648	total: 200ms	remaining: 2.44s
# 76:	learn: 0.3916713	total: 202ms	remaining: 2.42s
# 77:	learn: 0.3911070	total: 204ms	remaining: 2.41s
# 78:	learn: 0.3904646	total: 205ms	remaining: 2.39s
# 79:	learn: 0.3897839	total: 207ms	remaining: 2.38s
# 80:	learn: 0.3891339	total: 208ms	remaining: 2.36s
# 81:	learn: 0.3886644	total: 210ms	remaining: 2.35s
# 82:	learn: 0.3879605	total: 212ms	remaining: 2.34s
# 83:	learn: 0.3862453	total: 214ms	remaining: 2.33s
# 84:	learn: 0.3853401	total: 216ms	remaining: 2.32s
# 85:	learn: 0.3848224	total: 218ms	remaining: 2.31s
# 86:	learn: 0.3845123	total: 220ms	remaining: 2.31s
# 87:	learn: 0.3839466	total: 222ms	remaining: 2.3s
# 88:	learn: 0.3833705	total: 224ms	remaining: 2.29s
# 89:	learn: 0.3828415	total: 225ms	remaining: 2.28s
# 90:	learn: 0.3822773	total: 227ms	remaining: 2.27s
# 91:	learn: 0.3815060	total: 229ms	remaining: 2.26s
# 92:	learn: 0.3807340	total: 231ms	remaining: 2.25s
# 93:	learn: 0.3801654	total: 233ms	remaining: 2.24s
# 94:	learn: 0.3797969	total: 234ms	remaining: 2.23s
# 95:	learn: 0.3791202	total: 236ms	remaining: 2.22s
# 96:	learn: 0.3786804	total: 238ms	remaining: 2.21s
# 97:	learn: 0.3782173	total: 240ms	remaining: 2.21s
# 98:	learn: 0.3774314	total: 241ms	remaining: 2.2s
# 99:	learn: 0.3769693	total: 243ms	remaining: 2.19s
# 100:	learn: 0.3765566	total: 245ms	remaining: 2.18s
# 101:	learn: 0.3761557	total: 247ms	remaining: 2.17s
# 102:	learn: 0.3756815	total: 248ms	remaining: 2.16s
# 103:	learn: 0.3747539	total: 251ms	remaining: 2.16s
# 104:	learn: 0.3743659	total: 253ms	remaining: 2.15s
# 105:	learn: 0.3739516	total: 254ms	remaining: 2.15s
# 106:	learn: 0.3734920	total: 256ms	remaining: 2.14s
# 107:	learn: 0.3730334	total: 258ms	remaining: 2.13s
# 108:	learn: 0.3720279	total: 259ms	remaining: 2.12s
# 109:	learn: 0.3707167	total: 261ms	remaining: 2.11s
# 110:	learn: 0.3701534	total: 263ms	remaining: 2.1s
# 111:	learn: 0.3694486	total: 264ms	remaining: 2.1s
# 112:	learn: 0.3681490	total: 266ms	remaining: 2.09s
# 113:	learn: 0.3676684	total: 268ms	remaining: 2.08s
# 114:	learn: 0.3671928	total: 270ms	remaining: 2.07s
# 115:	learn: 0.3667860	total: 271ms	remaining: 2.07s
# 116:	learn: 0.3664649	total: 273ms	remaining: 2.06s
# 117:	learn: 0.3658856	total: 275ms	remaining: 2.06s
# 118:	learn: 0.3655647	total: 277ms	remaining: 2.05s
# 119:	learn: 0.3646345	total: 279ms	remaining: 2.04s
# 120:	learn: 0.3643391	total: 280ms	remaining: 2.04s
# 121:	learn: 0.3639642	total: 282ms	remaining: 2.03s
# 122:	learn: 0.3636256	total: 284ms	remaining: 2.02s
# 123:	learn: 0.3632494	total: 286ms	remaining: 2.02s
# 124:	learn: 0.3624276	total: 287ms	remaining: 2.01s
# 125:	learn: 0.3616194	total: 289ms	remaining: 2.01s
# 126:	learn: 0.3613164	total: 291ms	remaining: 2s
# 127:	learn: 0.3607015	total: 293ms	remaining: 2s
# 128:	learn: 0.3604268	total: 295ms	remaining: 1.99s
# 129:	learn: 0.3598297	total: 296ms	remaining: 1.98s
# 130:	learn: 0.3595292	total: 299ms	remaining: 1.98s
# 131:	learn: 0.3592343	total: 301ms	remaining: 1.98s
# 132:	learn: 0.3590054	total: 303ms	remaining: 1.97s
# 133:	learn: 0.3587077	total: 305ms	remaining: 1.97s
# 134:	learn: 0.3584782	total: 307ms	remaining: 1.97s
# 135:	learn: 0.3582032	total: 308ms	remaining: 1.96s
# 136:	learn: 0.3578933	total: 310ms	remaining: 1.96s
# 137:	learn: 0.3576021	total: 312ms	remaining: 1.95s
# 138:	learn: 0.3574765	total: 314ms	remaining: 1.94s
# 139:	learn: 0.3567411	total: 315ms	remaining: 1.94s
# 140:	learn: 0.3564866	total: 317ms	remaining: 1.93s
# 141:	learn: 0.3558192	total: 319ms	remaining: 1.93s
# 142:	learn: 0.3555021	total: 321ms	remaining: 1.92s
# 143:	learn: 0.3551901	total: 323ms	remaining: 1.92s
# 144:	learn: 0.3549876	total: 324ms	remaining: 1.91s
# 145:	learn: 0.3547371	total: 326ms	remaining: 1.91s
# 146:	learn: 0.3543351	total: 328ms	remaining: 1.9s
# 147:	learn: 0.3536223	total: 329ms	remaining: 1.9s
# 148:	learn: 0.3533206	total: 331ms	remaining: 1.89s
# 149:	learn: 0.3530540	total: 333ms	remaining: 1.89s
# 150:	learn: 0.3528847	total: 335ms	remaining: 1.88s
# 151:	learn: 0.3526272	total: 337ms	remaining: 1.88s
# 152:	learn: 0.3523832	total: 339ms	remaining: 1.88s
# 153:	learn: 0.3518881	total: 341ms	remaining: 1.87s
# 154:	learn: 0.3517064	total: 343ms	remaining: 1.87s
# 155:	learn: 0.3515389	total: 345ms	remaining: 1.87s
# 156:	learn: 0.3507811	total: 347ms	remaining: 1.86s
# 157:	learn: 0.3505885	total: 348ms	remaining: 1.85s
# 158:	learn: 0.3503517	total: 350ms	remaining: 1.85s
# 159:	learn: 0.3499810	total: 351ms	remaining: 1.84s
# 160:	learn: 0.3498519	total: 353ms	remaining: 1.84s
# 161:	learn: 0.3496998	total: 355ms	remaining: 1.84s
# 162:	learn: 0.3494365	total: 357ms	remaining: 1.83s
# 163:	learn: 0.3487477	total: 359ms	remaining: 1.83s
# 164:	learn: 0.3484132	total: 360ms	remaining: 1.82s
# 165:	learn: 0.3482038	total: 363ms	remaining: 1.82s
# 166:	learn: 0.3478047	total: 365ms	remaining: 1.82s
# 167:	learn: 0.3475512	total: 367ms	remaining: 1.81s
# 168:	learn: 0.3472490	total: 369ms	remaining: 1.81s
# 169:	learn: 0.3470289	total: 370ms	remaining: 1.81s
# 170:	learn: 0.3466864	total: 372ms	remaining: 1.8s
# 171:	learn: 0.3464244	total: 373ms	remaining: 1.8s
# 172:	learn: 0.3459761	total: 375ms	remaining: 1.79s
# 173:	learn: 0.3455866	total: 377ms	remaining: 1.79s
# 174:	learn: 0.3449776	total: 379ms	remaining: 1.79s
# 175:	learn: 0.3448260	total: 381ms	remaining: 1.78s
# 176:	learn: 0.3442834	total: 383ms	remaining: 1.78s
# 177:	learn: 0.3437715	total: 385ms	remaining: 1.77s
# 178:	learn: 0.3433661	total: 386ms	remaining: 1.77s
# 179:	learn: 0.3430660	total: 388ms	remaining: 1.76s
# 180:	learn: 0.3424728	total: 389ms	remaining: 1.76s
# 181:	learn: 0.3422678	total: 391ms	remaining: 1.76s
# 182:	learn: 0.3420109	total: 393ms	remaining: 1.75s
# 183:	learn: 0.3417933	total: 395ms	remaining: 1.75s
# 184:	learn: 0.3413928	total: 397ms	remaining: 1.75s
# 185:	learn: 0.3411466	total: 398ms	remaining: 1.74s
# 186:	learn: 0.3409603	total: 400ms	remaining: 1.74s
# 187:	learn: 0.3408238	total: 402ms	remaining: 1.73s
# 188:	learn: 0.3406594	total: 403ms	remaining: 1.73s
# 189:	learn: 0.3404621	total: 405ms	remaining: 1.73s
# 190:	learn: 0.3402474	total: 407ms	remaining: 1.73s
# 191:	learn: 0.3400741	total: 409ms	remaining: 1.72s
# 192:	learn: 0.3399043	total: 411ms	remaining: 1.72s
# 193:	learn: 0.3396742	total: 413ms	remaining: 1.72s
# 194:	learn: 0.3394421	total: 415ms	remaining: 1.71s
# 195:	learn: 0.3392339	total: 417ms	remaining: 1.71s
# 196:	learn: 0.3390728	total: 418ms	remaining: 1.71s
# 197:	learn: 0.3388121	total: 420ms	remaining: 1.7s
# 198:	learn: 0.3385367	total: 422ms	remaining: 1.7s
# 199:	learn: 0.3382807	total: 424ms	remaining: 1.69s
# 200:	learn: 0.3380218	total: 425ms	remaining: 1.69s
# 201:	learn: 0.3376756	total: 427ms	remaining: 1.69s
# 202:	learn: 0.3373369	total: 429ms	remaining: 1.68s
# 203:	learn: 0.3371511	total: 430ms	remaining: 1.68s
# 204:	learn: 0.3369390	total: 432ms	remaining: 1.68s
# 205:	learn: 0.3368190	total: 434ms	remaining: 1.67s
# 206:	learn: 0.3366329	total: 436ms	remaining: 1.67s
# 207:	learn: 0.3365120	total: 438ms	remaining: 1.67s
# 208:	learn: 0.3363661	total: 439ms	remaining: 1.66s
# 209:	learn: 0.3359032	total: 441ms	remaining: 1.66s
# 210:	learn: 0.3356728	total: 443ms	remaining: 1.66s
# 211:	learn: 0.3355575	total: 445ms	remaining: 1.65s
# 212:	learn: 0.3353436	total: 446ms	remaining: 1.65s
# 213:	learn: 0.3351567	total: 448ms	remaining: 1.64s
# 214:	learn: 0.3348571	total: 449ms	remaining: 1.64s
# 215:	learn: 0.3346713	total: 451ms	remaining: 1.64s
# 216:	learn: 0.3345155	total: 453ms	remaining: 1.63s
# 217:	learn: 0.3343235	total: 454ms	remaining: 1.63s
# 218:	learn: 0.3341757	total: 456ms	remaining: 1.63s
# 219:	learn: 0.3339886	total: 458ms	remaining: 1.62s
# 220:	learn: 0.3338301	total: 459ms	remaining: 1.62s
# 221:	learn: 0.3336231	total: 461ms	remaining: 1.61s
# 222:	learn: 0.3333078	total: 463ms	remaining: 1.61s
# 223:	learn: 0.3331602	total: 464ms	remaining: 1.61s
# 224:	learn: 0.3330020	total: 466ms	remaining: 1.6s
# 225:	learn: 0.3328068	total: 468ms	remaining: 1.6s
# 226:	learn: 0.3326947	total: 470ms	remaining: 1.6s
# 227:	learn: 0.3325586	total: 471ms	remaining: 1.59s
# 228:	learn: 0.3323504	total: 473ms	remaining: 1.59s
# 229:	learn: 0.3321769	total: 474ms	remaining: 1.59s
# 230:	learn: 0.3320822	total: 476ms	remaining: 1.58s
# 231:	learn: 0.3317671	total: 478ms	remaining: 1.58s
# 232:	learn: 0.3315351	total: 480ms	remaining: 1.58s
# 233:	learn: 0.3314157	total: 481ms	remaining: 1.58s
# 234:	learn: 0.3312663	total: 483ms	remaining: 1.57s
# 235:	learn: 0.3311207	total: 485ms	remaining: 1.57s
# 236:	learn: 0.3309925	total: 487ms	remaining: 1.57s
# 237:	learn: 0.3308998	total: 489ms	remaining: 1.56s
# 238:	learn: 0.3307636	total: 490ms	remaining: 1.56s
# 239:	learn: 0.3305840	total: 493ms	remaining: 1.56s
# 240:	learn: 0.3303953	total: 494ms	remaining: 1.56s
# 241:	learn: 0.3302293	total: 496ms	remaining: 1.55s
# 242:	learn: 0.3301531	total: 498ms	remaining: 1.55s
# 243:	learn: 0.3299431	total: 500ms	remaining: 1.55s
# 244:	learn: 0.3298268	total: 502ms	remaining: 1.54s
# 245:	learn: 0.3297264	total: 503ms	remaining: 1.54s
# 246:	learn: 0.3294051	total: 505ms	remaining: 1.54s
# 247:	learn: 0.3292431	total: 507ms	remaining: 1.54s
# 248:	learn: 0.3291074	total: 508ms	remaining: 1.53s
# 249:	learn: 0.3289886	total: 510ms	remaining: 1.53s
# 250:	learn: 0.3286794	total: 512ms	remaining: 1.53s
# 251:	learn: 0.3284264	total: 513ms	remaining: 1.52s
# 252:	learn: 0.3282659	total: 515ms	remaining: 1.52s
# 253:	learn: 0.3281029	total: 516ms	remaining: 1.52s
# 254:	learn: 0.3279426	total: 518ms	remaining: 1.51s
# 255:	learn: 0.3277635	total: 520ms	remaining: 1.51s
# 256:	learn: 0.3274543	total: 521ms	remaining: 1.51s
# 257:	learn: 0.3272718	total: 523ms	remaining: 1.5s
# 258:	learn: 0.3271154	total: 525ms	remaining: 1.5s
# 259:	learn: 0.3269006	total: 527ms	remaining: 1.5s
# 260:	learn: 0.3267984	total: 529ms	remaining: 1.5s
# 261:	learn: 0.3264380	total: 531ms	remaining: 1.49s
# 262:	learn: 0.3261076	total: 532ms	remaining: 1.49s
# 263:	learn: 0.3259281	total: 534ms	remaining: 1.49s
# 264:	learn: 0.3257667	total: 536ms	remaining: 1.49s
# 265:	learn: 0.3256085	total: 538ms	remaining: 1.48s
# 266:	learn: 0.3254086	total: 539ms	remaining: 1.48s
# 267:	learn: 0.3252053	total: 541ms	remaining: 1.48s
# 268:	learn: 0.3250304	total: 543ms	remaining: 1.47s
# 269:	learn: 0.3248768	total: 544ms	remaining: 1.47s
# 270:	learn: 0.3247269	total: 546ms	remaining: 1.47s
# 271:	learn: 0.3246021	total: 548ms	remaining: 1.47s
# 272:	learn: 0.3244860	total: 550ms	remaining: 1.46s
# 273:	learn: 0.3243233	total: 551ms	remaining: 1.46s
# 274:	learn: 0.3240742	total: 553ms	remaining: 1.46s
# 275:	learn: 0.3237259	total: 555ms	remaining: 1.46s
# 276:	learn: 0.3236153	total: 557ms	remaining: 1.45s
# 277:	learn: 0.3234171	total: 558ms	remaining: 1.45s
# 278:	learn: 0.3232024	total: 560ms	remaining: 1.45s
# 279:	learn: 0.3230646	total: 562ms	remaining: 1.44s
# 280:	learn: 0.3228962	total: 563ms	remaining: 1.44s
# 281:	learn: 0.3226522	total: 565ms	remaining: 1.44s
# 282:	learn: 0.3225289	total: 567ms	remaining: 1.44s
# 283:	learn: 0.3223993	total: 569ms	remaining: 1.43s
# 284:	learn: 0.3222390	total: 571ms	remaining: 1.43s
# 285:	learn: 0.3220591	total: 573ms	remaining: 1.43s
# 286:	learn: 0.3217949	total: 575ms	remaining: 1.43s
# 287:	learn: 0.3216875	total: 576ms	remaining: 1.42s
# 288:	learn: 0.3215544	total: 578ms	remaining: 1.42s
# 289:	learn: 0.3214644	total: 580ms	remaining: 1.42s
# 290:	learn: 0.3213402	total: 582ms	remaining: 1.42s
# 291:	learn: 0.3211479	total: 584ms	remaining: 1.42s
# 292:	learn: 0.3210436	total: 586ms	remaining: 1.41s
# 293:	learn: 0.3209704	total: 587ms	remaining: 1.41s
# 294:	learn: 0.3207389	total: 589ms	remaining: 1.41s
# 295:	learn: 0.3205524	total: 591ms	remaining: 1.41s
# 296:	learn: 0.3202270	total: 593ms	remaining: 1.4s
# 297:	learn: 0.3201094	total: 595ms	remaining: 1.4s
# 298:	learn: 0.3199455	total: 597ms	remaining: 1.4s
# 299:	learn: 0.3197212	total: 598ms	remaining: 1.4s
# 300:	learn: 0.3195826	total: 600ms	remaining: 1.39s
# 301:	learn: 0.3194818	total: 601ms	remaining: 1.39s
# 302:	learn: 0.3193456	total: 603ms	remaining: 1.39s
# 303:	learn: 0.3192479	total: 605ms	remaining: 1.38s
# 304:	learn: 0.3191188	total: 606ms	remaining: 1.38s
# 305:	learn: 0.3189483	total: 608ms	remaining: 1.38s
# 306:	learn: 0.3188188	total: 610ms	remaining: 1.38s
# 307:	learn: 0.3186087	total: 612ms	remaining: 1.37s
# 308:	learn: 0.3184456	total: 614ms	remaining: 1.37s
# 309:	learn: 0.3182974	total: 616ms	remaining: 1.37s
# 310:	learn: 0.3180521	total: 617ms	remaining: 1.37s
# 311:	learn: 0.3178412	total: 619ms	remaining: 1.36s
# 312:	learn: 0.3176739	total: 621ms	remaining: 1.36s
# 313:	learn: 0.3175860	total: 622ms	remaining: 1.36s
# 314:	learn: 0.3174004	total: 624ms	remaining: 1.36s
# 315:	learn: 0.3172817	total: 626ms	remaining: 1.35s
# 316:	learn: 0.3170978	total: 628ms	remaining: 1.35s
# 317:	learn: 0.3170002	total: 630ms	remaining: 1.35s
# 318:	learn: 0.3167760	total: 631ms	remaining: 1.35s
# 319:	learn: 0.3166747	total: 633ms	remaining: 1.35s
# 320:	learn: 0.3165023	total: 635ms	remaining: 1.34s
# 321:	learn: 0.3161918	total: 638ms	remaining: 1.34s
# 322:	learn: 0.3160930	total: 640ms	remaining: 1.34s
# 323:	learn: 0.3159238	total: 642ms	remaining: 1.34s
# 324:	learn: 0.3157770	total: 643ms	remaining: 1.34s
# 325:	learn: 0.3156523	total: 645ms	remaining: 1.33s
# 326:	learn: 0.3155073	total: 647ms	remaining: 1.33s
# 327:	learn: 0.3153506	total: 649ms	remaining: 1.33s
# 328:	learn: 0.3151753	total: 651ms	remaining: 1.33s
# 329:	learn: 0.3150213	total: 653ms	remaining: 1.32s
# 330:	learn: 0.3148899	total: 655ms	remaining: 1.32s
# 331:	learn: 0.3147131	total: 656ms	remaining: 1.32s
# 332:	learn: 0.3145777	total: 658ms	remaining: 1.32s
# 333:	learn: 0.3143875	total: 661ms	remaining: 1.32s
# 334:	learn: 0.3142692	total: 663ms	remaining: 1.31s
# 335:	learn: 0.3141999	total: 665ms	remaining: 1.31s
# 336:	learn: 0.3141021	total: 667ms	remaining: 1.31s
# 337:	learn: 0.3139721	total: 668ms	remaining: 1.31s
# 338:	learn: 0.3138258	total: 670ms	remaining: 1.31s
# 339:	learn: 0.3136344	total: 672ms	remaining: 1.3s
# 340:	learn: 0.3135323	total: 674ms	remaining: 1.3s
# 341:	learn: 0.3134831	total: 676ms	remaining: 1.3s
# 342:	learn: 0.3133910	total: 678ms	remaining: 1.3s
# 343:	learn: 0.3132694	total: 680ms	remaining: 1.29s
# 344:	learn: 0.3131020	total: 682ms	remaining: 1.29s
# 345:	learn: 0.3129394	total: 684ms	remaining: 1.29s
# 346:	learn: 0.3127559	total: 686ms	remaining: 1.29s
# 347:	learn: 0.3126275	total: 687ms	remaining: 1.29s
# 348:	learn: 0.3124575	total: 689ms	remaining: 1.28s
# 349:	learn: 0.3123264	total: 691ms	remaining: 1.28s
# 350:	learn: 0.3122073	total: 693ms	remaining: 1.28s
# 351:	learn: 0.3120865	total: 695ms	remaining: 1.28s
# 352:	learn: 0.3119204	total: 696ms	remaining: 1.28s
# 353:	learn: 0.3118268	total: 699ms	remaining: 1.27s
# 354:	learn: 0.3116628	total: 701ms	remaining: 1.27s
# 355:	learn: 0.3115476	total: 702ms	remaining: 1.27s
# 356:	learn: 0.3113782	total: 704ms	remaining: 1.27s
# 357:	learn: 0.3112672	total: 706ms	remaining: 1.26s
# 358:	learn: 0.3110996	total: 708ms	remaining: 1.26s
# 359:	learn: 0.3109516	total: 710ms	remaining: 1.26s
# 360:	learn: 0.3108121	total: 712ms	remaining: 1.26s
# 361:	learn: 0.3106484	total: 714ms	remaining: 1.26s
# 362:	learn: 0.3105269	total: 717ms	remaining: 1.26s
# 363:	learn: 0.3104039	total: 718ms	remaining: 1.25s
# 364:	learn: 0.3102708	total: 720ms	remaining: 1.25s
# 365:	learn: 0.3101402	total: 722ms	remaining: 1.25s
# 366:	learn: 0.3100579	total: 724ms	remaining: 1.25s
# 367:	learn: 0.3099164	total: 726ms	remaining: 1.25s
# 368:	learn: 0.3098077	total: 727ms	remaining: 1.24s
# 369:	learn: 0.3096987	total: 729ms	remaining: 1.24s
# 370:	learn: 0.3095607	total: 731ms	remaining: 1.24s
# 371:	learn: 0.3093410	total: 733ms	remaining: 1.24s
# 372:	learn: 0.3091693	total: 735ms	remaining: 1.24s
# 373:	learn: 0.3089998	total: 737ms	remaining: 1.23s
# 374:	learn: 0.3088303	total: 739ms	remaining: 1.23s
# 375:	learn: 0.3087130	total: 741ms	remaining: 1.23s
# 376:	learn: 0.3086115	total: 742ms	remaining: 1.23s
# 377:	learn: 0.3084254	total: 744ms	remaining: 1.22s
# 378:	learn: 0.3082956	total: 746ms	remaining: 1.22s
# 379:	learn: 0.3081051	total: 747ms	remaining: 1.22s
# 380:	learn: 0.3079523	total: 749ms	remaining: 1.22s
# 381:	learn: 0.3078535	total: 751ms	remaining: 1.21s
# 382:	learn: 0.3077126	total: 752ms	remaining: 1.21s
# 383:	learn: 0.3075253	total: 754ms	remaining: 1.21s
# 384:	learn: 0.3074112	total: 756ms	remaining: 1.21s
# 385:	learn: 0.3072825	total: 757ms	remaining: 1.2s
# 386:	learn: 0.3071823	total: 759ms	remaining: 1.2s
# 387:	learn: 0.3070676	total: 761ms	remaining: 1.2s
# 388:	learn: 0.3069654	total: 763ms	remaining: 1.2s
# 389:	learn: 0.3068825	total: 765ms	remaining: 1.2s
# 390:	learn: 0.3066903	total: 767ms	remaining: 1.19s
# 391:	learn: 0.3065828	total: 768ms	remaining: 1.19s
# 392:	learn: 0.3064315	total: 770ms	remaining: 1.19s
# 393:	learn: 0.3063126	total: 772ms	remaining: 1.19s
# 394:	learn: 0.3061729	total: 773ms	remaining: 1.18s
# 395:	learn: 0.3060085	total: 775ms	remaining: 1.18s
# 396:	learn: 0.3058171	total: 777ms	remaining: 1.18s
# 397:	learn: 0.3056676	total: 779ms	remaining: 1.18s
# 398:	learn: 0.3054771	total: 781ms	remaining: 1.18s
# 399:	learn: 0.3052976	total: 783ms	remaining: 1.17s
# 400:	learn: 0.3051338	total: 785ms	remaining: 1.17s
# 401:	learn: 0.3049633	total: 786ms	remaining: 1.17s
# 402:	learn: 0.3048548	total: 788ms	remaining: 1.17s
# 403:	learn: 0.3047795	total: 790ms	remaining: 1.17s
# 404:	learn: 0.3046659	total: 793ms	remaining: 1.16s
# 405:	learn: 0.3045502	total: 794ms	remaining: 1.16s
# 406:	learn: 0.3043907	total: 797ms	remaining: 1.16s
# 407:	learn: 0.3042114	total: 798ms	remaining: 1.16s
# 408:	learn: 0.3040968	total: 800ms	remaining: 1.16s
# 409:	learn: 0.3039065	total: 802ms	remaining: 1.15s
# 410:	learn: 0.3037994	total: 803ms	remaining: 1.15s
# 411:	learn: 0.3036297	total: 805ms	remaining: 1.15s
# 412:	learn: 0.3034852	total: 807ms	remaining: 1.15s
# 413:	learn: 0.3033385	total: 809ms	remaining: 1.14s
# 414:	learn: 0.3032237	total: 810ms	remaining: 1.14s
# 415:	learn: 0.3031098	total: 812ms	remaining: 1.14s
# 416:	learn: 0.3029489	total: 814ms	remaining: 1.14s
# 417:	learn: 0.3028425	total: 816ms	remaining: 1.14s
# 418:	learn: 0.3027220	total: 818ms	remaining: 1.13s
# 419:	learn: 0.3025713	total: 820ms	remaining: 1.13s
# 420:	learn: 0.3024487	total: 821ms	remaining: 1.13s
# 421:	learn: 0.3023414	total: 823ms	remaining: 1.13s
# 422:	learn: 0.3022410	total: 825ms	remaining: 1.13s
# 423:	learn: 0.3021669	total: 827ms	remaining: 1.12s
# 424:	learn: 0.3020083	total: 829ms	remaining: 1.12s
# 425:	learn: 0.3018928	total: 831ms	remaining: 1.12s
# 426:	learn: 0.3017888	total: 833ms	remaining: 1.12s
# 427:	learn: 0.3016715	total: 835ms	remaining: 1.11s
# 428:	learn: 0.3015363	total: 837ms	remaining: 1.11s
# 429:	learn: 0.3013785	total: 838ms	remaining: 1.11s
# 430:	learn: 0.3012398	total: 840ms	remaining: 1.11s
# 431:	learn: 0.3011324	total: 842ms	remaining: 1.11s
# 432:	learn: 0.3009943	total: 844ms	remaining: 1.1s
# 433:	learn: 0.3008670	total: 846ms	remaining: 1.1s
# 434:	learn: 0.3006320	total: 847ms	remaining: 1.1s
# 435:	learn: 0.3005247	total: 849ms	remaining: 1.1s
# 436:	learn: 0.3004297	total: 851ms	remaining: 1.1s
# 437:	learn: 0.3003258	total: 852ms	remaining: 1.09s
# 438:	learn: 0.3001877	total: 854ms	remaining: 1.09s
# 439:	learn: 0.3000598	total: 856ms	remaining: 1.09s
# 440:	learn: 0.2999056	total: 858ms	remaining: 1.09s
# 441:	learn: 0.2997951	total: 860ms	remaining: 1.08s
# 442:	learn: 0.2996755	total: 862ms	remaining: 1.08s
# 443:	learn: 0.2995014	total: 863ms	remaining: 1.08s
# 444:	learn: 0.2994163	total: 865ms	remaining: 1.08s
# 445:	learn: 0.2992712	total: 867ms	remaining: 1.08s
# 446:	learn: 0.2991898	total: 869ms	remaining: 1.07s
# 447:	learn: 0.2990510	total: 871ms	remaining: 1.07s
# 448:	learn: 0.2988952	total: 873ms	remaining: 1.07s
# 449:	learn: 0.2987830	total: 875ms	remaining: 1.07s
# 450:	learn: 0.2986452	total: 876ms	remaining: 1.07s
# 451:	learn: 0.2985190	total: 878ms	remaining: 1.06s
# 452:	learn: 0.2983485	total: 880ms	remaining: 1.06s
# 453:	learn: 0.2982064	total: 882ms	remaining: 1.06s
# 454:	learn: 0.2980752	total: 884ms	remaining: 1.06s
# 455:	learn: 0.2979300	total: 885ms	remaining: 1.06s
# 456:	learn: 0.2978211	total: 887ms	remaining: 1.05s
# 457:	learn: 0.2976828	total: 889ms	remaining: 1.05s
# 458:	learn: 0.2975721	total: 891ms	remaining: 1.05s
# 459:	learn: 0.2974517	total: 893ms	remaining: 1.05s
# 460:	learn: 0.2973424	total: 895ms	remaining: 1.04s
# 461:	learn: 0.2971853	total: 897ms	remaining: 1.04s
# 462:	learn: 0.2970572	total: 899ms	remaining: 1.04s
# 463:	learn: 0.2969726	total: 900ms	remaining: 1.04s
# 464:	learn: 0.2968438	total: 902ms	remaining: 1.04s
# 465:	learn: 0.2967415	total: 904ms	remaining: 1.03s
# 466:	learn: 0.2966600	total: 906ms	remaining: 1.03s
# 467:	learn: 0.2965495	total: 907ms	remaining: 1.03s
# 468:	learn: 0.2964531	total: 909ms	remaining: 1.03s
# 469:	learn: 0.2963330	total: 911ms	remaining: 1.03s
# 470:	learn: 0.2962588	total: 912ms	remaining: 1.02s
# 471:	learn: 0.2961250	total: 915ms	remaining: 1.02s
# 472:	learn: 0.2960107	total: 916ms	remaining: 1.02s
# 473:	learn: 0.2959085	total: 918ms	remaining: 1.02s
# 474:	learn: 0.2957681	total: 920ms	remaining: 1.02s
# 475:	learn: 0.2956294	total: 922ms	remaining: 1.01s
# 476:	learn: 0.2955391	total: 923ms	remaining: 1.01s
# 477:	learn: 0.2953561	total: 925ms	remaining: 1.01s
# 478:	learn: 0.2952050	total: 927ms	remaining: 1.01s
# 479:	learn: 0.2951050	total: 929ms	remaining: 1s
# 480:	learn: 0.2950117	total: 930ms	remaining: 1s
# 481:	learn: 0.2949205	total: 932ms	remaining: 1s
# 482:	learn: 0.2948216	total: 934ms	remaining: 999ms
# 483:	learn: 0.2946824	total: 935ms	remaining: 997ms
# 484:	learn: 0.2945837	total: 937ms	remaining: 995ms
# 485:	learn: 0.2943871	total: 939ms	remaining: 993ms
# 486:	learn: 0.2942543	total: 941ms	remaining: 991ms
# 487:	learn: 0.2940725	total: 943ms	remaining: 990ms
# 488:	learn: 0.2939508	total: 945ms	remaining: 988ms
# 489:	learn: 0.2937916	total: 947ms	remaining: 986ms
# 490:	learn: 0.2936240	total: 949ms	remaining: 983ms
# 491:	learn: 0.2934726	total: 950ms	remaining: 981ms
# 492:	learn: 0.2932505	total: 952ms	remaining: 979ms
# 493:	learn: 0.2931358	total: 954ms	remaining: 977ms
# 494:	learn: 0.2929664	total: 955ms	remaining: 975ms
# 495:	learn: 0.2928738	total: 957ms	remaining: 973ms
# 496:	learn: 0.2927748	total: 959ms	remaining: 971ms
# 497:	learn: 0.2926328	total: 961ms	remaining: 969ms
# 498:	learn: 0.2924909	total: 964ms	remaining: 968ms
# 499:	learn: 0.2923173	total: 966ms	remaining: 966ms
# 500:	learn: 0.2922175	total: 967ms	remaining: 963ms
# 501:	learn: 0.2920830	total: 969ms	remaining: 961ms
# 502:	learn: 0.2918803	total: 971ms	remaining: 959ms
# 503:	learn: 0.2917446	total: 973ms	remaining: 957ms
# 504:	learn: 0.2915336	total: 974ms	remaining: 955ms
# 505:	learn: 0.2914376	total: 976ms	remaining: 953ms
# 506:	learn: 0.2913194	total: 978ms	remaining: 951ms
# 507:	learn: 0.2911575	total: 980ms	remaining: 949ms
# 508:	learn: 0.2910179	total: 981ms	remaining: 947ms
# 509:	learn: 0.2909001	total: 983ms	remaining: 945ms
# 510:	learn: 0.2907424	total: 985ms	remaining: 943ms
# 511:	learn: 0.2906558	total: 987ms	remaining: 941ms
# 512:	learn: 0.2905130	total: 989ms	remaining: 939ms
# 513:	learn: 0.2904238	total: 992ms	remaining: 938ms
# 514:	learn: 0.2903185	total: 994ms	remaining: 936ms
# 515:	learn: 0.2902044	total: 996ms	remaining: 934ms
# 516:	learn: 0.2901307	total: 997ms	remaining: 932ms
# 517:	learn: 0.2900228	total: 999ms	remaining: 930ms
# 518:	learn: 0.2898964	total: 1s	remaining: 927ms
# 519:	learn: 0.2897915	total: 1s	remaining: 925ms
# 520:	learn: 0.2896746	total: 1s	remaining: 923ms
# 521:	learn: 0.2895028	total: 1s	remaining: 921ms
# 522:	learn: 0.2894241	total: 1.01s	remaining: 919ms
# 523:	learn: 0.2893134	total: 1.01s	remaining: 917ms
# 524:	learn: 0.2892215	total: 1.01s	remaining: 915ms
# 525:	learn: 0.2891126	total: 1.01s	remaining: 913ms
# 526:	learn: 0.2889462	total: 1.01s	remaining: 911ms
# 527:	learn: 0.2888143	total: 1.02s	remaining: 909ms
# 528:	learn: 0.2887524	total: 1.02s	remaining: 907ms
# 529:	learn: 0.2886280	total: 1.02s	remaining: 904ms
# 530:	learn: 0.2884850	total: 1.02s	remaining: 902ms
# 531:	learn: 0.2883795	total: 1.02s	remaining: 901ms
# 532:	learn: 0.2882616	total: 1.02s	remaining: 899ms
# 533:	learn: 0.2881462	total: 1.03s	remaining: 896ms
# 534:	learn: 0.2880196	total: 1.03s	remaining: 894ms
# 535:	learn: 0.2878598	total: 1.03s	remaining: 892ms
# 536:	learn: 0.2877815	total: 1.03s	remaining: 890ms
# 537:	learn: 0.2876580	total: 1.03s	remaining: 888ms
# 538:	learn: 0.2875357	total: 1.03s	remaining: 886ms
# 539:	learn: 0.2874292	total: 1.04s	remaining: 884ms
# 540:	learn: 0.2872756	total: 1.04s	remaining: 881ms
# 541:	learn: 0.2872107	total: 1.04s	remaining: 880ms
# 542:	learn: 0.2870791	total: 1.04s	remaining: 878ms
# 543:	learn: 0.2869754	total: 1.04s	remaining: 876ms
# 544:	learn: 0.2868897	total: 1.05s	remaining: 874ms
# 545:	learn: 0.2867742	total: 1.05s	remaining: 872ms
# 546:	learn: 0.2866368	total: 1.05s	remaining: 871ms
# 547:	learn: 0.2865468	total: 1.05s	remaining: 869ms
# 548:	learn: 0.2863668	total: 1.05s	remaining: 867ms
# 549:	learn: 0.2862571	total: 1.06s	remaining: 864ms
# 550:	learn: 0.2861784	total: 1.06s	remaining: 863ms
# 551:	learn: 0.2860432	total: 1.06s	remaining: 861ms
# 552:	learn: 0.2859588	total: 1.06s	remaining: 859ms
# 553:	learn: 0.2858257	total: 1.06s	remaining: 856ms
# 554:	learn: 0.2857466	total: 1.06s	remaining: 854ms
# 555:	learn: 0.2856151	total: 1.07s	remaining: 852ms
# 556:	learn: 0.2855025	total: 1.07s	remaining: 850ms
# 557:	learn: 0.2854059	total: 1.07s	remaining: 848ms
# 558:	learn: 0.2852790	total: 1.07s	remaining: 847ms
# 559:	learn: 0.2851812	total: 1.07s	remaining: 845ms
# 560:	learn: 0.2850878	total: 1.08s	remaining: 843ms
# 561:	learn: 0.2849572	total: 1.08s	remaining: 840ms
# 562:	learn: 0.2848706	total: 1.08s	remaining: 838ms
# 563:	learn: 0.2847751	total: 1.08s	remaining: 836ms
# 564:	learn: 0.2847059	total: 1.08s	remaining: 834ms
# 565:	learn: 0.2845800	total: 1.08s	remaining: 832ms
# 566:	learn: 0.2843918	total: 1.09s	remaining: 830ms
# 567:	learn: 0.2842666	total: 1.09s	remaining: 828ms
# 568:	learn: 0.2841978	total: 1.09s	remaining: 826ms
# 569:	learn: 0.2841098	total: 1.09s	remaining: 824ms
# 570:	learn: 0.2839958	total: 1.09s	remaining: 822ms
# 571:	learn: 0.2838504	total: 1.09s	remaining: 820ms
# 572:	learn: 0.2836975	total: 1.1s	remaining: 818ms
# 573:	learn: 0.2835715	total: 1.1s	remaining: 816ms
# 574:	learn: 0.2834963	total: 1.1s	remaining: 814ms
# 575:	learn: 0.2833974	total: 1.1s	remaining: 812ms
# 576:	learn: 0.2832815	total: 1.1s	remaining: 810ms
# 577:	learn: 0.2831949	total: 1.11s	remaining: 808ms
# 578:	learn: 0.2830857	total: 1.11s	remaining: 806ms
# 579:	learn: 0.2829673	total: 1.11s	remaining: 803ms
# 580:	learn: 0.2828338	total: 1.11s	remaining: 801ms
# 581:	learn: 0.2827294	total: 1.11s	remaining: 799ms
# 582:	learn: 0.2826419	total: 1.11s	remaining: 797ms
# 583:	learn: 0.2825567	total: 1.12s	remaining: 796ms
# 584:	learn: 0.2824322	total: 1.12s	remaining: 794ms
# 585:	learn: 0.2823148	total: 1.12s	remaining: 792ms
# 586:	learn: 0.2822493	total: 1.12s	remaining: 790ms
# 587:	learn: 0.2821283	total: 1.12s	remaining: 787ms
# 588:	learn: 0.2819259	total: 1.13s	remaining: 785ms
# 589:	learn: 0.2818439	total: 1.13s	remaining: 783ms
# 590:	learn: 0.2817517	total: 1.13s	remaining: 781ms
# 591:	learn: 0.2816112	total: 1.13s	remaining: 779ms
# 592:	learn: 0.2814511	total: 1.13s	remaining: 777ms
# 593:	learn: 0.2813916	total: 1.13s	remaining: 775ms
# 594:	learn: 0.2812581	total: 1.14s	remaining: 773ms
# 595:	learn: 0.2811494	total: 1.14s	remaining: 772ms
# 596:	learn: 0.2811020	total: 1.14s	remaining: 770ms
# 597:	learn: 0.2810092	total: 1.14s	remaining: 768ms
# 598:	learn: 0.2808020	total: 1.14s	remaining: 766ms
# 599:	learn: 0.2807036	total: 1.15s	remaining: 764ms
# 600:	learn: 0.2806098	total: 1.15s	remaining: 762ms
# 601:	learn: 0.2805219	total: 1.15s	remaining: 760ms
# 602:	learn: 0.2804383	total: 1.15s	remaining: 758ms
# 603:	learn: 0.2803486	total: 1.15s	remaining: 756ms
# 604:	learn: 0.2801739	total: 1.15s	remaining: 754ms
# 605:	learn: 0.2800314	total: 1.16s	remaining: 752ms
# 606:	learn: 0.2799499	total: 1.16s	remaining: 750ms
# 607:	learn: 0.2798831	total: 1.16s	remaining: 748ms
# 608:	learn: 0.2797995	total: 1.16s	remaining: 746ms
# 609:	learn: 0.2796738	total: 1.16s	remaining: 744ms
# 610:	learn: 0.2795757	total: 1.17s	remaining: 743ms
# 611:	learn: 0.2795042	total: 1.17s	remaining: 741ms
# 612:	learn: 0.2793011	total: 1.17s	remaining: 739ms
# 613:	learn: 0.2792331	total: 1.17s	remaining: 738ms
# 614:	learn: 0.2790824	total: 1.18s	remaining: 736ms
# 615:	learn: 0.2789590	total: 1.18s	remaining: 734ms
# 616:	learn: 0.2788953	total: 1.18s	remaining: 732ms
# 617:	learn: 0.2788349	total: 1.18s	remaining: 730ms
# 618:	learn: 0.2787632	total: 1.18s	remaining: 728ms
# 619:	learn: 0.2786674	total: 1.18s	remaining: 726ms
# 620:	learn: 0.2785058	total: 1.19s	remaining: 724ms
# 621:	learn: 0.2783256	total: 1.19s	remaining: 722ms
# 622:	learn: 0.2782116	total: 1.19s	remaining: 720ms
# 623:	learn: 0.2780389	total: 1.19s	remaining: 718ms
# 624:	learn: 0.2779526	total: 1.19s	remaining: 716ms
# 625:	learn: 0.2778770	total: 1.2s	remaining: 715ms
# 626:	learn: 0.2777616	total: 1.2s	remaining: 713ms
# 627:	learn: 0.2776978	total: 1.2s	remaining: 711ms
# 628:	learn: 0.2775214	total: 1.2s	remaining: 709ms
# 629:	learn: 0.2774411	total: 1.2s	remaining: 708ms
# 630:	learn: 0.2773772	total: 1.21s	remaining: 706ms
# 631:	learn: 0.2773102	total: 1.21s	remaining: 704ms
# 632:	learn: 0.2772250	total: 1.21s	remaining: 703ms
# 633:	learn: 0.2771038	total: 1.21s	remaining: 701ms
# 634:	learn: 0.2770259	total: 1.22s	remaining: 699ms
# 635:	learn: 0.2768763	total: 1.22s	remaining: 697ms
# 636:	learn: 0.2767973	total: 1.22s	remaining: 695ms
# 637:	learn: 0.2767322	total: 1.22s	remaining: 694ms
# 638:	learn: 0.2766451	total: 1.23s	remaining: 692ms
# 639:	learn: 0.2765334	total: 1.23s	remaining: 691ms
# 640:	learn: 0.2764256	total: 1.23s	remaining: 689ms
# 641:	learn: 0.2762707	total: 1.23s	remaining: 688ms
# 642:	learn: 0.2762108	total: 1.24s	remaining: 686ms
# 643:	learn: 0.2760519	total: 1.24s	remaining: 684ms
# 644:	learn: 0.2759372	total: 1.24s	remaining: 683ms
# 645:	learn: 0.2757347	total: 1.24s	remaining: 681ms
# 646:	learn: 0.2756271	total: 1.25s	remaining: 680ms
# 647:	learn: 0.2754886	total: 1.25s	remaining: 678ms
# 648:	learn: 0.2753857	total: 1.25s	remaining: 676ms
# 649:	learn: 0.2752954	total: 1.25s	remaining: 674ms
# 650:	learn: 0.2752085	total: 1.25s	remaining: 672ms
# 651:	learn: 0.2750930	total: 1.25s	remaining: 670ms
# 652:	learn: 0.2750032	total: 1.26s	remaining: 669ms
# 653:	learn: 0.2749244	total: 1.26s	remaining: 667ms
# 654:	learn: 0.2747883	total: 1.26s	remaining: 665ms
# 655:	learn: 0.2746814	total: 1.26s	remaining: 663ms
# 656:	learn: 0.2746126	total: 1.27s	remaining: 661ms
# 657:	learn: 0.2745211	total: 1.27s	remaining: 659ms
# 658:	learn: 0.2744323	total: 1.27s	remaining: 658ms
# 659:	learn: 0.2743506	total: 1.27s	remaining: 657ms
# 660:	learn: 0.2742701	total: 1.28s	remaining: 655ms
# 661:	learn: 0.2741753	total: 1.28s	remaining: 653ms
# 662:	learn: 0.2740820	total: 1.28s	remaining: 651ms
# 663:	learn: 0.2740196	total: 1.28s	remaining: 649ms
# 664:	learn: 0.2739559	total: 1.28s	remaining: 648ms
# 665:	learn: 0.2738599	total: 1.29s	remaining: 647ms
# 666:	learn: 0.2737160	total: 1.29s	remaining: 647ms
# 667:	learn: 0.2736088	total: 1.3s	remaining: 645ms
# 668:	learn: 0.2734682	total: 1.3s	remaining: 643ms
# 669:	learn: 0.2733539	total: 1.3s	remaining: 641ms
# 670:	learn: 0.2732386	total: 1.3s	remaining: 639ms
# 671:	learn: 0.2731229	total: 1.3s	remaining: 637ms
# 672:	learn: 0.2730324	total: 1.31s	remaining: 636ms
# 673:	learn: 0.2729754	total: 1.31s	remaining: 634ms
# 674:	learn: 0.2728646	total: 1.31s	remaining: 633ms
# 675:	learn: 0.2727807	total: 1.32s	remaining: 631ms
# 676:	learn: 0.2726742	total: 1.32s	remaining: 629ms
# 677:	learn: 0.2725881	total: 1.32s	remaining: 627ms
# 678:	learn: 0.2724928	total: 1.32s	remaining: 626ms
# 679:	learn: 0.2724201	total: 1.33s	remaining: 624ms
# 680:	learn: 0.2723714	total: 1.33s	remaining: 622ms
# 681:	learn: 0.2722505	total: 1.33s	remaining: 620ms
# 682:	learn: 0.2721059	total: 1.33s	remaining: 618ms
# 683:	learn: 0.2720338	total: 1.33s	remaining: 616ms
# 684:	learn: 0.2719570	total: 1.34s	remaining: 615ms
# 685:	learn: 0.2718452	total: 1.34s	remaining: 614ms
# 686:	learn: 0.2716698	total: 1.34s	remaining: 613ms
# 687:	learn: 0.2715341	total: 1.35s	remaining: 611ms
# 688:	learn: 0.2714641	total: 1.35s	remaining: 609ms
# 689:	learn: 0.2713947	total: 1.35s	remaining: 607ms
# 690:	learn: 0.2712008	total: 1.35s	remaining: 605ms
# 691:	learn: 0.2710549	total: 1.36s	remaining: 605ms
# 692:	learn: 0.2709045	total: 1.36s	remaining: 603ms
# 693:	learn: 0.2707515	total: 1.36s	remaining: 601ms
# 694:	learn: 0.2706605	total: 1.36s	remaining: 599ms
# 695:	learn: 0.2705825	total: 1.37s	remaining: 597ms
# 696:	learn: 0.2704460	total: 1.37s	remaining: 596ms
# 697:	learn: 0.2703280	total: 1.37s	remaining: 595ms
# 698:	learn: 0.2702730	total: 1.38s	remaining: 593ms
# 699:	learn: 0.2701883	total: 1.38s	remaining: 591ms
# 700:	learn: 0.2700970	total: 1.38s	remaining: 589ms
# 701:	learn: 0.2699155	total: 1.38s	remaining: 587ms
# 702:	learn: 0.2698430	total: 1.39s	remaining: 585ms
# 703:	learn: 0.2697675	total: 1.39s	remaining: 583ms
# 704:	learn: 0.2696234	total: 1.39s	remaining: 582ms
# 705:	learn: 0.2695072	total: 1.39s	remaining: 580ms
# 706:	learn: 0.2694255	total: 1.39s	remaining: 578ms
# 707:	learn: 0.2693517	total: 1.4s	remaining: 576ms
# 708:	learn: 0.2692323	total: 1.4s	remaining: 574ms
# 709:	learn: 0.2690535	total: 1.4s	remaining: 572ms
# 710:	learn: 0.2689490	total: 1.4s	remaining: 571ms
# 711:	learn: 0.2688115	total: 1.41s	remaining: 569ms
# 712:	learn: 0.2686731	total: 1.41s	remaining: 567ms
# 713:	learn: 0.2686043	total: 1.41s	remaining: 565ms
# 714:	learn: 0.2685008	total: 1.41s	remaining: 563ms
# 715:	learn: 0.2683581	total: 1.42s	remaining: 561ms
# 716:	learn: 0.2682804	total: 1.42s	remaining: 559ms
# 717:	learn: 0.2682218	total: 1.42s	remaining: 557ms
# 718:	learn: 0.2681567	total: 1.42s	remaining: 555ms
# 719:	learn: 0.2680266	total: 1.42s	remaining: 554ms
# 720:	learn: 0.2678646	total: 1.43s	remaining: 552ms
# 721:	learn: 0.2677763	total: 1.43s	remaining: 550ms
# 722:	learn: 0.2676493	total: 1.43s	remaining: 548ms
# 723:	learn: 0.2674919	total: 1.43s	remaining: 546ms
# 724:	learn: 0.2674103	total: 1.43s	remaining: 544ms
# 725:	learn: 0.2673326	total: 1.44s	remaining: 543ms
# 726:	learn: 0.2672037	total: 1.44s	remaining: 541ms
# 727:	learn: 0.2670734	total: 1.44s	remaining: 539ms
# 728:	learn: 0.2670053	total: 1.45s	remaining: 537ms
# 729:	learn: 0.2669244	total: 1.45s	remaining: 536ms
# 730:	learn: 0.2668518	total: 1.45s	remaining: 534ms
# 731:	learn: 0.2667902	total: 1.45s	remaining: 532ms
# 732:	learn: 0.2666683	total: 1.46s	remaining: 530ms
# 733:	learn: 0.2665894	total: 1.46s	remaining: 528ms
# 734:	learn: 0.2665258	total: 1.46s	remaining: 526ms
# 735:	learn: 0.2664583	total: 1.46s	remaining: 524ms
# 736:	learn: 0.2663814	total: 1.46s	remaining: 522ms
# 737:	learn: 0.2663318	total: 1.47s	remaining: 520ms
# 738:	learn: 0.2662882	total: 1.47s	remaining: 518ms
# 739:	learn: 0.2662340	total: 1.47s	remaining: 516ms
# 740:	learn: 0.2660608	total: 1.47s	remaining: 514ms
# 741:	learn: 0.2659820	total: 1.47s	remaining: 512ms
# 742:	learn: 0.2658338	total: 1.48s	remaining: 510ms
# 743:	learn: 0.2657100	total: 1.48s	remaining: 508ms
# 744:	learn: 0.2656359	total: 1.48s	remaining: 506ms
# 745:	learn: 0.2655122	total: 1.48s	remaining: 504ms
# 746:	learn: 0.2653541	total: 1.48s	remaining: 502ms
# 747:	learn: 0.2653084	total: 1.49s	remaining: 500ms
# 748:	learn: 0.2652154	total: 1.49s	remaining: 499ms
# 749:	learn: 0.2650890	total: 1.49s	remaining: 497ms
# 750:	learn: 0.2649693	total: 1.49s	remaining: 494ms
# 751:	learn: 0.2648868	total: 1.49s	remaining: 492ms
# 752:	learn: 0.2647202	total: 1.49s	remaining: 490ms
# 753:	learn: 0.2646593	total: 1.5s	remaining: 488ms
# 754:	learn: 0.2645963	total: 1.5s	remaining: 486ms
# 755:	learn: 0.2645184	total: 1.5s	remaining: 485ms
# 756:	learn: 0.2644297	total: 1.5s	remaining: 483ms
# 757:	learn: 0.2643840	total: 1.5s	remaining: 481ms
# 758:	learn: 0.2642475	total: 1.51s	remaining: 479ms
# 759:	learn: 0.2641430	total: 1.51s	remaining: 477ms
# 760:	learn: 0.2640817	total: 1.51s	remaining: 475ms
# 761:	learn: 0.2639638	total: 1.51s	remaining: 473ms
# 762:	learn: 0.2638911	total: 1.51s	remaining: 471ms
# 763:	learn: 0.2637692	total: 1.52s	remaining: 469ms
# 764:	learn: 0.2636778	total: 1.52s	remaining: 467ms
# 765:	learn: 0.2636308	total: 1.52s	remaining: 465ms
# 766:	learn: 0.2635736	total: 1.52s	remaining: 463ms
# 767:	learn: 0.2634957	total: 1.52s	remaining: 461ms
# 768:	learn: 0.2634214	total: 1.53s	remaining: 459ms
# 769:	learn: 0.2633043	total: 1.53s	remaining: 457ms
# 770:	learn: 0.2631963	total: 1.53s	remaining: 455ms
# 771:	learn: 0.2631275	total: 1.53s	remaining: 453ms
# 772:	learn: 0.2630152	total: 1.53s	remaining: 451ms
# 773:	learn: 0.2629685	total: 1.54s	remaining: 449ms
# 774:	learn: 0.2628981	total: 1.54s	remaining: 447ms
# 775:	learn: 0.2628388	total: 1.54s	remaining: 445ms
# 776:	learn: 0.2627451	total: 1.54s	remaining: 443ms
# 777:	learn: 0.2626447	total: 1.54s	remaining: 441ms
# 778:	learn: 0.2625221	total: 1.55s	remaining: 439ms
# 779:	learn: 0.2624280	total: 1.55s	remaining: 437ms
# 780:	learn: 0.2623154	total: 1.55s	remaining: 435ms
# 781:	learn: 0.2622027	total: 1.55s	remaining: 433ms
# 782:	learn: 0.2621392	total: 1.55s	remaining: 431ms
# 783:	learn: 0.2620517	total: 1.56s	remaining: 429ms
# 784:	learn: 0.2619559	total: 1.56s	remaining: 427ms
# 785:	learn: 0.2618851	total: 1.56s	remaining: 425ms
# 786:	learn: 0.2617333	total: 1.56s	remaining: 423ms
# 787:	learn: 0.2616590	total: 1.56s	remaining: 421ms
# 788:	learn: 0.2615661	total: 1.57s	remaining: 419ms
# 789:	learn: 0.2614943	total: 1.57s	remaining: 417ms
# 790:	learn: 0.2614071	total: 1.57s	remaining: 415ms
# 791:	learn: 0.2613383	total: 1.57s	remaining: 413ms
# 792:	learn: 0.2612498	total: 1.57s	remaining: 411ms
# 793:	learn: 0.2611556	total: 1.58s	remaining: 409ms
# 794:	learn: 0.2610567	total: 1.58s	remaining: 407ms
# 795:	learn: 0.2608913	total: 1.58s	remaining: 405ms
# 796:	learn: 0.2608176	total: 1.58s	remaining: 403ms
# 797:	learn: 0.2607764	total: 1.59s	remaining: 402ms
# 798:	learn: 0.2606478	total: 1.59s	remaining: 400ms
# 799:	learn: 0.2605086	total: 1.59s	remaining: 398ms
# 800:	learn: 0.2604653	total: 1.59s	remaining: 396ms
# 801:	learn: 0.2603331	total: 1.59s	remaining: 394ms
# 802:	learn: 0.2602777	total: 1.59s	remaining: 391ms
# 803:	learn: 0.2601604	total: 1.6s	remaining: 389ms
# 804:	learn: 0.2600620	total: 1.6s	remaining: 388ms
# 805:	learn: 0.2599571	total: 1.6s	remaining: 386ms
# 806:	learn: 0.2598829	total: 1.6s	remaining: 384ms
# 807:	learn: 0.2597733	total: 1.61s	remaining: 382ms
# 808:	learn: 0.2596786	total: 1.61s	remaining: 380ms
# 809:	learn: 0.2596360	total: 1.61s	remaining: 378ms
# 810:	learn: 0.2595869	total: 1.61s	remaining: 376ms
# 811:	learn: 0.2595363	total: 1.61s	remaining: 374ms
# 812:	learn: 0.2594066	total: 1.62s	remaining: 372ms
# 813:	learn: 0.2593353	total: 1.62s	remaining: 370ms
# 814:	learn: 0.2592580	total: 1.62s	remaining: 368ms
# 815:	learn: 0.2591771	total: 1.62s	remaining: 366ms
# 816:	learn: 0.2590968	total: 1.62s	remaining: 364ms
# 817:	learn: 0.2589990	total: 1.63s	remaining: 362ms
# 818:	learn: 0.2589281	total: 1.63s	remaining: 360ms
# 819:	learn: 0.2587707	total: 1.63s	remaining: 358ms
# 820:	learn: 0.2586979	total: 1.63s	remaining: 356ms
# 821:	learn: 0.2586423	total: 1.63s	remaining: 354ms
# 822:	learn: 0.2585466	total: 1.64s	remaining: 352ms
# 823:	learn: 0.2584963	total: 1.64s	remaining: 350ms
# 824:	learn: 0.2584083	total: 1.64s	remaining: 348ms
# 825:	learn: 0.2583490	total: 1.64s	remaining: 346ms
# 826:	learn: 0.2582825	total: 1.65s	remaining: 345ms
# 827:	learn: 0.2582180	total: 1.65s	remaining: 343ms
# 828:	learn: 0.2580984	total: 1.65s	remaining: 341ms
# 829:	learn: 0.2580272	total: 1.66s	remaining: 339ms
# 830:	learn: 0.2579333	total: 1.66s	remaining: 337ms
# 831:	learn: 0.2578139	total: 1.66s	remaining: 336ms
# 832:	learn: 0.2577008	total: 1.67s	remaining: 334ms
# 833:	learn: 0.2575948	total: 1.67s	remaining: 332ms
# 834:	learn: 0.2575051	total: 1.67s	remaining: 330ms
# 835:	learn: 0.2574051	total: 1.67s	remaining: 328ms
# 836:	learn: 0.2573068	total: 1.68s	remaining: 327ms
# 837:	learn: 0.2572362	total: 1.68s	remaining: 325ms
# 838:	learn: 0.2570827	total: 1.68s	remaining: 323ms
# 839:	learn: 0.2569660	total: 1.68s	remaining: 321ms
# 840:	learn: 0.2569058	total: 1.69s	remaining: 319ms
# 841:	learn: 0.2568425	total: 1.69s	remaining: 317ms
# 842:	learn: 0.2567689	total: 1.69s	remaining: 315ms
# 843:	learn: 0.2566405	total: 1.69s	remaining: 313ms
# 844:	learn: 0.2565065	total: 1.7s	remaining: 311ms
# 845:	learn: 0.2564386	total: 1.7s	remaining: 309ms
# 846:	learn: 0.2563050	total: 1.7s	remaining: 307ms
# 847:	learn: 0.2562297	total: 1.7s	remaining: 305ms
# 848:	learn: 0.2561391	total: 1.71s	remaining: 303ms
# 849:	learn: 0.2560805	total: 1.71s	remaining: 301ms
# 850:	learn: 0.2559635	total: 1.71s	remaining: 299ms
# 851:	learn: 0.2558958	total: 1.71s	remaining: 298ms
# 852:	learn: 0.2557875	total: 1.72s	remaining: 296ms
# 853:	learn: 0.2557051	total: 1.72s	remaining: 294ms
# 854:	learn: 0.2556056	total: 1.72s	remaining: 292ms
# 855:	learn: 0.2555165	total: 1.72s	remaining: 290ms
# 856:	learn: 0.2554245	total: 1.72s	remaining: 288ms
# 857:	learn: 0.2553399	total: 1.73s	remaining: 286ms
# 858:	learn: 0.2552485	total: 1.73s	remaining: 284ms
# 859:	learn: 0.2551745	total: 1.73s	remaining: 282ms
# 860:	learn: 0.2550117	total: 1.73s	remaining: 280ms
# 861:	learn: 0.2549196	total: 1.74s	remaining: 278ms
# 862:	learn: 0.2548502	total: 1.74s	remaining: 276ms
# 863:	learn: 0.2547945	total: 1.74s	remaining: 274ms
# 864:	learn: 0.2547357	total: 1.74s	remaining: 272ms
# 865:	learn: 0.2546690	total: 1.74s	remaining: 270ms
# 866:	learn: 0.2545944	total: 1.75s	remaining: 268ms
# 867:	learn: 0.2544940	total: 1.75s	remaining: 266ms
# 868:	learn: 0.2544135	total: 1.75s	remaining: 264ms
# 869:	learn: 0.2543643	total: 1.75s	remaining: 262ms
# 870:	learn: 0.2543087	total: 1.75s	remaining: 260ms
# 871:	learn: 0.2542025	total: 1.76s	remaining: 258ms
# 872:	learn: 0.2540917	total: 1.76s	remaining: 256ms
# 873:	learn: 0.2540062	total: 1.76s	remaining: 254ms
# 874:	learn: 0.2539229	total: 1.76s	remaining: 252ms
# 875:	learn: 0.2538113	total: 1.76s	remaining: 250ms
# 876:	learn: 0.2537426	total: 1.76s	remaining: 248ms
# 877:	learn: 0.2536748	total: 1.77s	remaining: 246ms
# 878:	learn: 0.2536231	total: 1.77s	remaining: 244ms
# 879:	learn: 0.2535575	total: 1.77s	remaining: 242ms
# 880:	learn: 0.2534447	total: 1.77s	remaining: 240ms
# 881:	learn: 0.2532893	total: 1.78s	remaining: 238ms
# 882:	learn: 0.2532284	total: 1.78s	remaining: 236ms
# 883:	learn: 0.2531557	total: 1.78s	remaining: 234ms
# 884:	learn: 0.2530678	total: 1.78s	remaining: 232ms
# 885:	learn: 0.2529077	total: 1.78s	remaining: 230ms
# 886:	learn: 0.2528509	total: 1.79s	remaining: 228ms
# 887:	learn: 0.2527571	total: 1.79s	remaining: 226ms
# 888:	learn: 0.2526989	total: 1.79s	remaining: 224ms
# 889:	learn: 0.2526198	total: 1.79s	remaining: 222ms
# 890:	learn: 0.2525211	total: 1.79s	remaining: 220ms
# 891:	learn: 0.2524475	total: 1.8s	remaining: 218ms
# 892:	learn: 0.2523794	total: 1.8s	remaining: 216ms
# 893:	learn: 0.2523132	total: 1.8s	remaining: 213ms
# 894:	learn: 0.2522305	total: 1.8s	remaining: 211ms
# 895:	learn: 0.2521588	total: 1.8s	remaining: 210ms
# 896:	learn: 0.2520900	total: 1.81s	remaining: 208ms
# 897:	learn: 0.2519819	total: 1.81s	remaining: 206ms
# 898:	learn: 0.2519007	total: 1.81s	remaining: 204ms
# 899:	learn: 0.2518113	total: 1.81s	remaining: 202ms
# 900:	learn: 0.2517113	total: 1.82s	remaining: 200ms
# 901:	learn: 0.2516146	total: 1.82s	remaining: 198ms
# 902:	learn: 0.2515501	total: 1.82s	remaining: 196ms
# 903:	learn: 0.2514474	total: 1.82s	remaining: 194ms
# 904:	learn: 0.2513829	total: 1.82s	remaining: 192ms
# 905:	learn: 0.2513303	total: 1.83s	remaining: 190ms
# 906:	learn: 0.2512047	total: 1.83s	remaining: 188ms
# 907:	learn: 0.2511178	total: 1.83s	remaining: 186ms
# 908:	learn: 0.2510774	total: 1.83s	remaining: 184ms
# 909:	learn: 0.2509630	total: 1.84s	remaining: 182ms
# 910:	learn: 0.2509155	total: 1.84s	remaining: 180ms
# 911:	learn: 0.2507980	total: 1.84s	remaining: 178ms
# 912:	learn: 0.2507170	total: 1.84s	remaining: 176ms
# 913:	learn: 0.2506565	total: 1.84s	remaining: 174ms
# 914:	learn: 0.2505514	total: 1.85s	remaining: 172ms
# 915:	learn: 0.2504131	total: 1.85s	remaining: 170ms
# 916:	learn: 0.2503541	total: 1.85s	remaining: 168ms
# 917:	learn: 0.2502695	total: 1.85s	remaining: 166ms
# 918:	learn: 0.2501901	total: 1.86s	remaining: 164ms
# 919:	learn: 0.2500836	total: 1.86s	remaining: 162ms
# 920:	learn: 0.2499869	total: 1.86s	remaining: 160ms
# 921:	learn: 0.2498865	total: 1.86s	remaining: 158ms
# 922:	learn: 0.2497978	total: 1.86s	remaining: 156ms
# 923:	learn: 0.2497457	total: 1.87s	remaining: 153ms
# 924:	learn: 0.2496447	total: 1.87s	remaining: 151ms
# 925:	learn: 0.2496066	total: 1.87s	remaining: 150ms
# 926:	learn: 0.2495571	total: 1.87s	remaining: 148ms
# 927:	learn: 0.2494741	total: 1.88s	remaining: 146ms
# 928:	learn: 0.2494267	total: 1.88s	remaining: 144ms
# 929:	learn: 0.2493828	total: 1.88s	remaining: 142ms
# 930:	learn: 0.2493213	total: 1.88s	remaining: 140ms
# 931:	learn: 0.2492290	total: 1.89s	remaining: 138ms
# 932:	learn: 0.2491116	total: 1.89s	remaining: 136ms
# 933:	learn: 0.2490423	total: 1.89s	remaining: 134ms
# 934:	learn: 0.2489458	total: 1.89s	remaining: 132ms
# 935:	learn: 0.2488684	total: 1.9s	remaining: 130ms
# 936:	learn: 0.2488124	total: 1.9s	remaining: 128ms
# 937:	learn: 0.2487581	total: 1.9s	remaining: 126ms
# 938:	learn: 0.2486655	total: 1.9s	remaining: 124ms
# 939:	learn: 0.2485814	total: 1.91s	remaining: 122ms
# 940:	learn: 0.2485464	total: 1.91s	remaining: 120ms
# 941:	learn: 0.2484555	total: 1.91s	remaining: 118ms
# 942:	learn: 0.2483894	total: 1.91s	remaining: 116ms
# 943:	learn: 0.2482444	total: 1.92s	remaining: 114ms
# 944:	learn: 0.2481950	total: 1.92s	remaining: 112ms
# 945:	learn: 0.2481287	total: 1.92s	remaining: 110ms
# 946:	learn: 0.2480750	total: 1.92s	remaining: 108ms
# 947:	learn: 0.2480137	total: 1.92s	remaining: 106ms
# 948:	learn: 0.2479469	total: 1.93s	remaining: 104ms
# 949:	learn: 0.2478602	total: 1.93s	remaining: 101ms
# 950:	learn: 0.2477789	total: 1.93s	remaining: 99.5ms
# 951:	learn: 0.2477162	total: 1.93s	remaining: 97.4ms
# 952:	learn: 0.2476144	total: 1.93s	remaining: 95.4ms
# 953:	learn: 0.2475372	total: 1.94s	remaining: 93.3ms
# 954:	learn: 0.2474532	total: 1.94s	remaining: 91.3ms
# 955:	learn: 0.2473643	total: 1.94s	remaining: 89.3ms
# 956:	learn: 0.2473187	total: 1.94s	remaining: 87.3ms
# 957:	learn: 0.2472618	total: 1.94s	remaining: 85.2ms
# 958:	learn: 0.2471198	total: 1.95s	remaining: 83.2ms
# 959:	learn: 0.2470350	total: 1.95s	remaining: 81.2ms
# 960:	learn: 0.2469361	total: 1.95s	remaining: 79.1ms
# 961:	learn: 0.2468355	total: 1.95s	remaining: 77.1ms
# 962:	learn: 0.2467485	total: 1.95s	remaining: 75.1ms
# 963:	learn: 0.2466997	total: 1.96s	remaining: 73ms
# 964:	learn: 0.2466158	total: 1.96s	remaining: 71ms
# 965:	learn: 0.2465570	total: 1.96s	remaining: 69ms
# 966:	learn: 0.2465130	total: 1.96s	remaining: 66.9ms
# 967:	learn: 0.2464323	total: 1.96s	remaining: 64.9ms
# 968:	learn: 0.2463676	total: 1.96s	remaining: 62.9ms
# 969:	learn: 0.2462473	total: 1.97s	remaining: 60.8ms
# 970:	learn: 0.2461252	total: 1.97s	remaining: 58.8ms
# 971:	learn: 0.2460541	total: 1.97s	remaining: 56.8ms
# 972:	learn: 0.2459882	total: 1.97s	remaining: 54.7ms
# 973:	learn: 0.2459356	total: 1.97s	remaining: 52.7ms
# 974:	learn: 0.2458124	total: 1.98s	remaining: 50.7ms
# 975:	learn: 0.2457159	total: 1.98s	remaining: 48.6ms
# 976:	learn: 0.2456193	total: 1.98s	remaining: 46.6ms
# 977:	learn: 0.2455140	total: 1.98s	remaining: 44.6ms
# 978:	learn: 0.2454575	total: 1.98s	remaining: 42.6ms
# 979:	learn: 0.2453763	total: 1.99s	remaining: 40.6ms
# 980:	learn: 0.2452878	total: 1.99s	remaining: 38.5ms
# 981:	learn: 0.2452246	total: 1.99s	remaining: 36.5ms
# 982:	learn: 0.2451347	total: 1.99s	remaining: 34.5ms
# 983:	learn: 0.2450593	total: 1.99s	remaining: 32.4ms
# 984:	learn: 0.2449641	total: 2s	remaining: 30.4ms
# 985:	learn: 0.2448696	total: 2s	remaining: 28.4ms
# 986:	learn: 0.2447666	total: 2s	remaining: 26.4ms
# 987:	learn: 0.2446618	total: 2s	remaining: 24.3ms
# 988:	learn: 0.2445550	total: 2s	remaining: 22.3ms
# 989:	learn: 0.2444755	total: 2.01s	remaining: 20.3ms
# 990:	learn: 0.2443414	total: 2.01s	remaining: 18.3ms
# 991:	learn: 0.2442803	total: 2.01s	remaining: 16.2ms
# 992:	learn: 0.2441422	total: 2.01s	remaining: 14.2ms
# 993:	learn: 0.2440912	total: 2.02s	remaining: 12.2ms
# 994:	learn: 0.2439668	total: 2.02s	remaining: 10.1ms
# 995:	learn: 0.2439208	total: 2.02s	remaining: 8.12ms
# 996:	learn: 0.2438609	total: 2.02s	remaining: 6.09ms
# 997:	learn: 0.2437616	total: 2.03s	remaining: 4.06ms
# 998:	learn: 0.2436190	total: 2.03s	remaining: 2.03ms
# 999:	learn: 0.2435776	total: 2.03s	remaining: 0us

# %%
pd.DataFrame(res).sort_values("F1 Score", ascending=False)
# Out:
#                      Model  Accuracy  Precision    Recall  F1 Score
# 2            Random Forest  0.852657   0.846227  0.860194  0.853154
# 8                 LightGBM  0.846377   0.837761  0.857282  0.847409
# 10               CAT Boost  0.844928   0.837941  0.853398  0.845599
# 7                  XGBoost  0.841546   0.833650  0.851456  0.842459
# 6        Gradient Boosting  0.832367   0.811872  0.863107  0.836706
# 5   Support Vector Machine  0.830435   0.818182  0.847573  0.832618
# 9             ADA Boosting  0.821256   0.788967  0.874757  0.829650
# 4      K-Nearest Neighbors  0.820290   0.788091  0.873786  0.828729
# 0      Logistic Regression  0.808696   0.781528  0.854369  0.816327
# 1            Decision Tree  0.813527   0.809615  0.817476  0.813527
# 3     Gaussian Naive Bayes  0.776812   0.753571  0.819417  0.785116

# %%
pd.DataFrame(res).sort_values("Recall", ascending=False)
# Out:
#                      Model  Accuracy  Precision    Recall  F1 Score
# 9             ADA Boosting  0.821256   0.788967  0.874757  0.829650
# 4      K-Nearest Neighbors  0.820290   0.788091  0.873786  0.828729
# 6        Gradient Boosting  0.832367   0.811872  0.863107  0.836706
# 2            Random Forest  0.852657   0.846227  0.860194  0.853154
# 8                 LightGBM  0.846377   0.837761  0.857282  0.847409
# 0      Logistic Regression  0.808696   0.781528  0.854369  0.816327
# 10               CAT Boost  0.844928   0.837941  0.853398  0.845599
# 7                  XGBoost  0.841546   0.833650  0.851456  0.842459
# 5   Support Vector Machine  0.830435   0.818182  0.847573  0.832618
# 3     Gaussian Naive Bayes  0.776812   0.753571  0.819417  0.785116
# 1            Decision Tree  0.813527   0.809615  0.817476  0.813527

# %% [markdown]
# ## One Hot Encoding

# %%
X = df.drop(columns=["Churn", "AON", "Number of Additional Services"])
y = df["Churn"].replace({"Yes": 1, "No": 0})
X = pd.get_dummies(X).replace({True: 1, False: 0})

# %%
over = SMOTE(sampling_strategy = 1)
X,y = over.fit_resample(X,y)

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, random_state = 2, test_size = 0.2)

# %%
ss = StandardScaler()
mm = MinMaxScaler()
cols = ["MonthlyCharges", "TotalCharges", "tenure"]
x_train[cols] = mm.fit_transform(x_train[cols])

# %%
x_test[cols] = mm.transform(x_test[cols])

# %%
res = ml_model(x_train, x_test, y_train, y_test)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 4144, number of negative: 4134
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001363 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 667
# [LightGBM] [Info] Number of data points in the train set: 8278, number of used features: 45
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500604 -> initscore=0.002416
# [LightGBM] [Info] Start training from score 0.002416
# Learning rate set to 0.025403
# 0:	learn: 0.6757263	total: 3.06ms	remaining: 3.05s
# 1:	learn: 0.6595030	total: 5.33ms	remaining: 2.66s
# 2:	learn: 0.6474982	total: 7.62ms	remaining: 2.53s
# 3:	learn: 0.6325573	total: 10ms	remaining: 2.5s
# 4:	learn: 0.6190826	total: 12.5ms	remaining: 2.48s
# 5:	learn: 0.6058962	total: 14.8ms	remaining: 2.45s
# 6:	learn: 0.5919306	total: 17.1ms	remaining: 2.42s
# 7:	learn: 0.5791895	total: 19.4ms	remaining: 2.41s
# 8:	learn: 0.5684289	total: 21.6ms	remaining: 2.38s
# 9:	learn: 0.5571931	total: 23.8ms	remaining: 2.36s
# 10:	learn: 0.5459696	total: 26.1ms	remaining: 2.34s
# 11:	learn: 0.5343852	total: 28.3ms	remaining: 2.33s
# 12:	learn: 0.5260625	total: 30.6ms	remaining: 2.33s
# 13:	learn: 0.5188993	total: 33ms	remaining: 2.32s
# 14:	learn: 0.5096198	total: 35.5ms	remaining: 2.33s
# 15:	learn: 0.4975421	total: 37.7ms	remaining: 2.32s
# 16:	learn: 0.4892528	total: 40.1ms	remaining: 2.31s
# 17:	learn: 0.4829718	total: 42.5ms	remaining: 2.32s
# 18:	learn: 0.4727826	total: 44.9ms	remaining: 2.32s
# 19:	learn: 0.4683789	total: 47.5ms	remaining: 2.33s
# 20:	learn: 0.4622599	total: 49.8ms	remaining: 2.32s
# 21:	learn: 0.4564426	total: 52.1ms	remaining: 2.32s
# 22:	learn: 0.4502279	total: 54.7ms	remaining: 2.32s
# 23:	learn: 0.4461068	total: 56.9ms	remaining: 2.31s
# 24:	learn: 0.4401234	total: 59.3ms	remaining: 2.31s
# 25:	learn: 0.4350906	total: 61.7ms	remaining: 2.31s
# 26:	learn: 0.4315664	total: 64.1ms	remaining: 2.31s
# 27:	learn: 0.4246677	total: 66.4ms	remaining: 2.3s
# 28:	learn: 0.4212236	total: 68.6ms	remaining: 2.29s
# 29:	learn: 0.4172537	total: 70.9ms	remaining: 2.29s
# 30:	learn: 0.4139510	total: 73.5ms	remaining: 2.3s
# 31:	learn: 0.4112723	total: 75.9ms	remaining: 2.29s
# 32:	learn: 0.4087542	total: 78.1ms	remaining: 2.29s
# 33:	learn: 0.4050470	total: 80.4ms	remaining: 2.29s
# 34:	learn: 0.4016101	total: 82.8ms	remaining: 2.28s
# 35:	learn: 0.3993097	total: 85ms	remaining: 2.27s
# 36:	learn: 0.3960963	total: 87.2ms	remaining: 2.27s
# 37:	learn: 0.3926567	total: 89.3ms	remaining: 2.26s
# 38:	learn: 0.3896962	total: 91.5ms	remaining: 2.25s
# 39:	learn: 0.3864677	total: 93.9ms	remaining: 2.25s
# 40:	learn: 0.3847038	total: 96.2ms	remaining: 2.25s
# 41:	learn: 0.3825212	total: 98.5ms	remaining: 2.25s
# 42:	learn: 0.3806904	total: 101ms	remaining: 2.24s
# 43:	learn: 0.3790490	total: 103ms	remaining: 2.24s
# 44:	learn: 0.3765699	total: 105ms	remaining: 2.23s
# 45:	learn: 0.3729715	total: 108ms	remaining: 2.23s
# 46:	learn: 0.3691682	total: 110ms	remaining: 2.23s
# 47:	learn: 0.3668912	total: 112ms	remaining: 2.22s
# 48:	learn: 0.3655478	total: 115ms	remaining: 2.23s
# 49:	learn: 0.3638337	total: 117ms	remaining: 2.23s
# 50:	learn: 0.3600199	total: 120ms	remaining: 2.23s
# 51:	learn: 0.3588872	total: 122ms	remaining: 2.22s
# 52:	learn: 0.3570527	total: 124ms	remaining: 2.22s
# 53:	learn: 0.3559837	total: 126ms	remaining: 2.21s
# 54:	learn: 0.3550367	total: 129ms	remaining: 2.21s
# 55:	learn: 0.3517748	total: 131ms	remaining: 2.21s
# 56:	learn: 0.3507014	total: 134ms	remaining: 2.21s
# 57:	learn: 0.3491011	total: 136ms	remaining: 2.21s
# 58:	learn: 0.3467873	total: 139ms	remaining: 2.21s
# 59:	learn: 0.3458242	total: 141ms	remaining: 2.21s
# 60:	learn: 0.3435669	total: 143ms	remaining: 2.2s
# 61:	learn: 0.3426638	total: 145ms	remaining: 2.2s
# 62:	learn: 0.3418861	total: 148ms	remaining: 2.2s
# 63:	learn: 0.3410122	total: 151ms	remaining: 2.21s
# 64:	learn: 0.3404143	total: 153ms	remaining: 2.21s
# 65:	learn: 0.3395566	total: 156ms	remaining: 2.2s
# 66:	learn: 0.3388541	total: 158ms	remaining: 2.2s
# 67:	learn: 0.3371509	total: 160ms	remaining: 2.2s
# 68:	learn: 0.3358566	total: 163ms	remaining: 2.2s
# 69:	learn: 0.3342873	total: 165ms	remaining: 2.19s
# 70:	learn: 0.3337556	total: 168ms	remaining: 2.19s
# 71:	learn: 0.3331411	total: 170ms	remaining: 2.19s
# 72:	learn: 0.3325941	total: 172ms	remaining: 2.19s
# 73:	learn: 0.3316714	total: 175ms	remaining: 2.19s
# 74:	learn: 0.3310649	total: 177ms	remaining: 2.18s
# 75:	learn: 0.3295243	total: 179ms	remaining: 2.18s
# 76:	learn: 0.3288636	total: 182ms	remaining: 2.18s
# 77:	learn: 0.3270667	total: 184ms	remaining: 2.18s
# 78:	learn: 0.3264593	total: 186ms	remaining: 2.17s
# 79:	learn: 0.3258972	total: 188ms	remaining: 2.17s
# 80:	learn: 0.3253204	total: 191ms	remaining: 2.16s
# 81:	learn: 0.3249570	total: 193ms	remaining: 2.16s
# 82:	learn: 0.3236451	total: 195ms	remaining: 2.16s
# 83:	learn: 0.3231451	total: 197ms	remaining: 2.15s
# 84:	learn: 0.3227567	total: 200ms	remaining: 2.15s
# 85:	learn: 0.3223234	total: 202ms	remaining: 2.15s
# 86:	learn: 0.3218273	total: 205ms	remaining: 2.15s
# 87:	learn: 0.3214608	total: 207ms	remaining: 2.15s
# 88:	learn: 0.3203577	total: 210ms	remaining: 2.15s
# 89:	learn: 0.3199260	total: 212ms	remaining: 2.15s
# 90:	learn: 0.3191598	total: 215ms	remaining: 2.15s
# 91:	learn: 0.3181927	total: 218ms	remaining: 2.15s
# 92:	learn: 0.3178209	total: 220ms	remaining: 2.15s
# 93:	learn: 0.3172714	total: 223ms	remaining: 2.15s
# 94:	learn: 0.3168280	total: 226ms	remaining: 2.15s
# 95:	learn: 0.3164503	total: 229ms	remaining: 2.15s
# 96:	learn: 0.3160853	total: 232ms	remaining: 2.15s
# 97:	learn: 0.3157417	total: 234ms	remaining: 2.15s
# 98:	learn: 0.3153284	total: 237ms	remaining: 2.15s
# 99:	learn: 0.3143857	total: 239ms	remaining: 2.15s
# 100:	learn: 0.3140632	total: 241ms	remaining: 2.15s
# 101:	learn: 0.3137528	total: 244ms	remaining: 2.15s
# 102:	learn: 0.3132864	total: 247ms	remaining: 2.15s
# 103:	learn: 0.3129219	total: 249ms	remaining: 2.15s
# 104:	learn: 0.3125951	total: 251ms	remaining: 2.14s
# 105:	learn: 0.3122644	total: 254ms	remaining: 2.14s
# 106:	learn: 0.3110542	total: 256ms	remaining: 2.14s
# 107:	learn: 0.3107393	total: 258ms	remaining: 2.13s
# 108:	learn: 0.3105368	total: 261ms	remaining: 2.13s
# 109:	learn: 0.3094101	total: 263ms	remaining: 2.13s
# 110:	learn: 0.3091042	total: 266ms	remaining: 2.13s
# 111:	learn: 0.3088952	total: 268ms	remaining: 2.13s
# 112:	learn: 0.3086910	total: 271ms	remaining: 2.12s
# 113:	learn: 0.3084725	total: 273ms	remaining: 2.12s
# 114:	learn: 0.3081127	total: 275ms	remaining: 2.12s
# 115:	learn: 0.3078321	total: 278ms	remaining: 2.12s
# 116:	learn: 0.3070863	total: 280ms	remaining: 2.11s
# 117:	learn: 0.3066428	total: 282ms	remaining: 2.11s
# 118:	learn: 0.3064610	total: 285ms	remaining: 2.11s
# 119:	learn: 0.3057573	total: 287ms	remaining: 2.1s
# 120:	learn: 0.3051206	total: 289ms	remaining: 2.1s
# 121:	learn: 0.3049072	total: 292ms	remaining: 2.1s
# 122:	learn: 0.3045891	total: 294ms	remaining: 2.1s
# 123:	learn: 0.3043159	total: 296ms	remaining: 2.09s
# 124:	learn: 0.3040260	total: 299ms	remaining: 2.09s
# 125:	learn: 0.3037628	total: 301ms	remaining: 2.09s
# 126:	learn: 0.3035142	total: 303ms	remaining: 2.08s
# 127:	learn: 0.3032633	total: 306ms	remaining: 2.08s
# 128:	learn: 0.3029878	total: 308ms	remaining: 2.08s
# 129:	learn: 0.3027965	total: 310ms	remaining: 2.08s
# 130:	learn: 0.3025842	total: 313ms	remaining: 2.07s
# 131:	learn: 0.3023455	total: 315ms	remaining: 2.07s
# 132:	learn: 0.3020649	total: 317ms	remaining: 2.07s
# 133:	learn: 0.3018936	total: 320ms	remaining: 2.07s
# 134:	learn: 0.3017461	total: 323ms	remaining: 2.07s
# 135:	learn: 0.3016007	total: 325ms	remaining: 2.07s
# 136:	learn: 0.3014026	total: 328ms	remaining: 2.06s
# 137:	learn: 0.3010959	total: 330ms	remaining: 2.06s
# 138:	learn: 0.3009407	total: 333ms	remaining: 2.06s
# 139:	learn: 0.3003589	total: 335ms	remaining: 2.06s
# 140:	learn: 0.3001573	total: 338ms	remaining: 2.06s
# 141:	learn: 0.3000448	total: 340ms	remaining: 2.05s
# 142:	learn: 0.2997994	total: 342ms	remaining: 2.05s
# 143:	learn: 0.2995504	total: 344ms	remaining: 2.05s
# 144:	learn: 0.2993474	total: 347ms	remaining: 2.04s
# 145:	learn: 0.2991307	total: 349ms	remaining: 2.04s
# 146:	learn: 0.2989398	total: 352ms	remaining: 2.04s
# 147:	learn: 0.2987399	total: 355ms	remaining: 2.04s
# 148:	learn: 0.2985265	total: 357ms	remaining: 2.04s
# 149:	learn: 0.2983006	total: 359ms	remaining: 2.04s
# 150:	learn: 0.2977862	total: 362ms	remaining: 2.03s
# 151:	learn: 0.2976372	total: 364ms	remaining: 2.03s
# 152:	learn: 0.2974445	total: 366ms	remaining: 2.03s
# 153:	learn: 0.2973024	total: 369ms	remaining: 2.03s
# 154:	learn: 0.2968487	total: 371ms	remaining: 2.02s
# 155:	learn: 0.2967416	total: 374ms	remaining: 2.02s
# 156:	learn: 0.2965858	total: 376ms	remaining: 2.02s
# 157:	learn: 0.2963556	total: 378ms	remaining: 2.02s
# 158:	learn: 0.2961970	total: 380ms	remaining: 2.01s
# 159:	learn: 0.2960182	total: 383ms	remaining: 2.01s
# 160:	learn: 0.2958007	total: 385ms	remaining: 2s
# 161:	learn: 0.2956767	total: 387ms	remaining: 2s
# 162:	learn: 0.2955532	total: 390ms	remaining: 2s
# 163:	learn: 0.2950215	total: 392ms	remaining: 2s
# 164:	learn: 0.2947446	total: 395ms	remaining: 2s
# 165:	learn: 0.2946335	total: 397ms	remaining: 2s
# 166:	learn: 0.2942417	total: 400ms	remaining: 1.99s
# 167:	learn: 0.2941160	total: 402ms	remaining: 1.99s
# 168:	learn: 0.2939350	total: 404ms	remaining: 1.99s
# 169:	learn: 0.2937277	total: 407ms	remaining: 1.99s
# 170:	learn: 0.2935124	total: 409ms	remaining: 1.98s
# 171:	learn: 0.2933383	total: 412ms	remaining: 1.98s
# 172:	learn: 0.2931330	total: 414ms	remaining: 1.98s
# 173:	learn: 0.2929167	total: 417ms	remaining: 1.98s
# 174:	learn: 0.2927455	total: 419ms	remaining: 1.98s
# 175:	learn: 0.2925903	total: 422ms	remaining: 1.97s
# 176:	learn: 0.2920557	total: 425ms	remaining: 1.97s
# 177:	learn: 0.2918935	total: 428ms	remaining: 1.97s
# 178:	learn: 0.2917684	total: 430ms	remaining: 1.97s
# 179:	learn: 0.2916000	total: 433ms	remaining: 1.97s
# 180:	learn: 0.2914507	total: 436ms	remaining: 1.97s
# 181:	learn: 0.2913443	total: 439ms	remaining: 1.97s
# 182:	learn: 0.2912011	total: 441ms	remaining: 1.97s
# 183:	learn: 0.2910736	total: 444ms	remaining: 1.97s
# 184:	learn: 0.2907831	total: 447ms	remaining: 1.97s
# 185:	learn: 0.2906213	total: 449ms	remaining: 1.97s
# 186:	learn: 0.2904345	total: 452ms	remaining: 1.96s
# 187:	learn: 0.2903525	total: 454ms	remaining: 1.96s
# 188:	learn: 0.2901917	total: 457ms	remaining: 1.96s
# 189:	learn: 0.2896942	total: 459ms	remaining: 1.96s
# 190:	learn: 0.2895542	total: 461ms	remaining: 1.95s
# 191:	learn: 0.2893450	total: 463ms	remaining: 1.95s
# 192:	learn: 0.2891982	total: 466ms	remaining: 1.95s
# 193:	learn: 0.2890156	total: 468ms	remaining: 1.94s
# 194:	learn: 0.2887296	total: 470ms	remaining: 1.94s
# 195:	learn: 0.2886407	total: 473ms	remaining: 1.94s
# 196:	learn: 0.2884760	total: 475ms	remaining: 1.94s
# 197:	learn: 0.2883136	total: 477ms	remaining: 1.93s
# 198:	learn: 0.2881658	total: 480ms	remaining: 1.93s
# 199:	learn: 0.2880396	total: 482ms	remaining: 1.93s
# 200:	learn: 0.2878893	total: 484ms	remaining: 1.92s
# 201:	learn: 0.2877648	total: 487ms	remaining: 1.92s
# 202:	learn: 0.2875788	total: 489ms	remaining: 1.92s
# 203:	learn: 0.2874304	total: 491ms	remaining: 1.92s
# 204:	learn: 0.2872844	total: 494ms	remaining: 1.91s
# 205:	learn: 0.2871519	total: 496ms	remaining: 1.91s
# 206:	learn: 0.2870148	total: 498ms	remaining: 1.91s
# 207:	learn: 0.2867926	total: 501ms	remaining: 1.91s
# 208:	learn: 0.2866819	total: 503ms	remaining: 1.9s
# 209:	learn: 0.2864950	total: 505ms	remaining: 1.9s
# 210:	learn: 0.2864074	total: 507ms	remaining: 1.9s
# 211:	learn: 0.2862804	total: 510ms	remaining: 1.89s
# 212:	learn: 0.2861578	total: 512ms	remaining: 1.89s
# 213:	learn: 0.2860627	total: 514ms	remaining: 1.89s
# 214:	learn: 0.2858954	total: 517ms	remaining: 1.89s
# 215:	learn: 0.2857304	total: 520ms	remaining: 1.89s
# 216:	learn: 0.2855352	total: 522ms	remaining: 1.88s
# 217:	learn: 0.2854315	total: 524ms	remaining: 1.88s
# 218:	learn: 0.2852287	total: 526ms	remaining: 1.88s
# 219:	learn: 0.2850990	total: 529ms	remaining: 1.87s
# 220:	learn: 0.2849491	total: 531ms	remaining: 1.87s
# 221:	learn: 0.2847811	total: 533ms	remaining: 1.87s
# 222:	learn: 0.2844851	total: 535ms	remaining: 1.86s
# 223:	learn: 0.2843257	total: 538ms	remaining: 1.86s
# 224:	learn: 0.2842061	total: 540ms	remaining: 1.86s
# 225:	learn: 0.2840728	total: 543ms	remaining: 1.86s
# 226:	learn: 0.2839384	total: 545ms	remaining: 1.85s
# 227:	learn: 0.2838055	total: 547ms	remaining: 1.85s
# 228:	learn: 0.2836607	total: 549ms	remaining: 1.85s
# 229:	learn: 0.2835342	total: 552ms	remaining: 1.85s
# 230:	learn: 0.2834046	total: 554ms	remaining: 1.84s
# 231:	learn: 0.2832295	total: 556ms	remaining: 1.84s
# 232:	learn: 0.2831072	total: 559ms	remaining: 1.84s
# 233:	learn: 0.2829914	total: 562ms	remaining: 1.84s
# 234:	learn: 0.2828750	total: 565ms	remaining: 1.84s
# 235:	learn: 0.2827413	total: 567ms	remaining: 1.84s
# 236:	learn: 0.2826135	total: 569ms	remaining: 1.83s
# 237:	learn: 0.2823147	total: 572ms	remaining: 1.83s
# 238:	learn: 0.2821274	total: 574ms	remaining: 1.83s
# 239:	learn: 0.2817805	total: 576ms	remaining: 1.82s
# 240:	learn: 0.2815412	total: 579ms	remaining: 1.82s
# 241:	learn: 0.2814550	total: 581ms	remaining: 1.82s
# 242:	learn: 0.2813175	total: 583ms	remaining: 1.82s
# 243:	learn: 0.2812063	total: 586ms	remaining: 1.81s
# 244:	learn: 0.2810909	total: 588ms	remaining: 1.81s
# 245:	learn: 0.2809822	total: 590ms	remaining: 1.81s
# 246:	learn: 0.2808435	total: 593ms	remaining: 1.81s
# 247:	learn: 0.2807529	total: 596ms	remaining: 1.81s
# 248:	learn: 0.2805501	total: 598ms	remaining: 1.8s
# 249:	learn: 0.2804825	total: 601ms	remaining: 1.8s
# 250:	learn: 0.2803473	total: 603ms	remaining: 1.8s
# 251:	learn: 0.2800842	total: 605ms	remaining: 1.79s
# 252:	learn: 0.2798604	total: 607ms	remaining: 1.79s
# 253:	learn: 0.2796140	total: 609ms	remaining: 1.79s
# 254:	learn: 0.2794746	total: 612ms	remaining: 1.79s
# 255:	learn: 0.2792974	total: 615ms	remaining: 1.79s
# 256:	learn: 0.2791916	total: 618ms	remaining: 1.78s
# 257:	learn: 0.2791005	total: 620ms	remaining: 1.78s
# 258:	learn: 0.2788120	total: 623ms	remaining: 1.78s
# 259:	learn: 0.2786730	total: 625ms	remaining: 1.78s
# 260:	learn: 0.2785030	total: 627ms	remaining: 1.78s
# 261:	learn: 0.2783329	total: 630ms	remaining: 1.77s
# 262:	learn: 0.2782242	total: 632ms	remaining: 1.77s
# 263:	learn: 0.2780825	total: 634ms	remaining: 1.77s
# 264:	learn: 0.2779936	total: 637ms	remaining: 1.76s
# 265:	learn: 0.2778599	total: 639ms	remaining: 1.76s
# 266:	learn: 0.2777422	total: 641ms	remaining: 1.76s
# 267:	learn: 0.2774966	total: 644ms	remaining: 1.76s
# 268:	learn: 0.2773732	total: 646ms	remaining: 1.75s
# 269:	learn: 0.2772055	total: 648ms	remaining: 1.75s
# 270:	learn: 0.2770184	total: 651ms	remaining: 1.75s
# 271:	learn: 0.2769048	total: 653ms	remaining: 1.75s
# 272:	learn: 0.2767958	total: 656ms	remaining: 1.75s
# 273:	learn: 0.2766684	total: 658ms	remaining: 1.74s
# 274:	learn: 0.2765665	total: 660ms	remaining: 1.74s
# 275:	learn: 0.2764029	total: 663ms	remaining: 1.74s
# 276:	learn: 0.2763111	total: 665ms	remaining: 1.74s
# 277:	learn: 0.2762537	total: 667ms	remaining: 1.73s
# 278:	learn: 0.2759475	total: 669ms	remaining: 1.73s
# 279:	learn: 0.2757844	total: 672ms	remaining: 1.73s
# 280:	learn: 0.2756092	total: 674ms	remaining: 1.72s
# 281:	learn: 0.2754907	total: 677ms	remaining: 1.72s
# 282:	learn: 0.2751063	total: 679ms	remaining: 1.72s
# 283:	learn: 0.2748830	total: 681ms	remaining: 1.72s
# 284:	learn: 0.2748069	total: 684ms	remaining: 1.72s
# 285:	learn: 0.2746614	total: 686ms	remaining: 1.71s
# 286:	learn: 0.2745175	total: 688ms	remaining: 1.71s
# 287:	learn: 0.2743861	total: 690ms	remaining: 1.71s
# 288:	learn: 0.2742981	total: 692ms	remaining: 1.7s
# 289:	learn: 0.2742019	total: 695ms	remaining: 1.7s
# 290:	learn: 0.2740851	total: 697ms	remaining: 1.7s
# 291:	learn: 0.2739264	total: 699ms	remaining: 1.7s
# 292:	learn: 0.2738213	total: 702ms	remaining: 1.69s
# 293:	learn: 0.2735087	total: 704ms	remaining: 1.69s
# 294:	learn: 0.2733833	total: 706ms	remaining: 1.69s
# 295:	learn: 0.2732454	total: 709ms	remaining: 1.69s
# 296:	learn: 0.2731348	total: 711ms	remaining: 1.68s
# 297:	learn: 0.2730186	total: 713ms	remaining: 1.68s
# 298:	learn: 0.2728967	total: 716ms	remaining: 1.68s
# 299:	learn: 0.2727646	total: 718ms	remaining: 1.68s
# 300:	learn: 0.2725637	total: 721ms	remaining: 1.67s
# 301:	learn: 0.2724083	total: 723ms	remaining: 1.67s
# 302:	learn: 0.2722779	total: 725ms	remaining: 1.67s
# 303:	learn: 0.2720482	total: 727ms	remaining: 1.67s
# 304:	learn: 0.2718906	total: 730ms	remaining: 1.66s
# 305:	learn: 0.2717444	total: 732ms	remaining: 1.66s
# 306:	learn: 0.2715512	total: 734ms	remaining: 1.66s
# 307:	learn: 0.2713434	total: 737ms	remaining: 1.66s
# 308:	learn: 0.2712290	total: 739ms	remaining: 1.65s
# 309:	learn: 0.2710518	total: 742ms	remaining: 1.65s
# 310:	learn: 0.2709273	total: 744ms	remaining: 1.65s
# 311:	learn: 0.2707627	total: 747ms	remaining: 1.65s
# 312:	learn: 0.2706645	total: 749ms	remaining: 1.64s
# 313:	learn: 0.2705475	total: 751ms	remaining: 1.64s
# 314:	learn: 0.2703781	total: 754ms	remaining: 1.64s
# 315:	learn: 0.2703332	total: 756ms	remaining: 1.64s
# 316:	learn: 0.2702254	total: 758ms	remaining: 1.63s
# 317:	learn: 0.2701341	total: 760ms	remaining: 1.63s
# 318:	learn: 0.2699453	total: 763ms	remaining: 1.63s
# 319:	learn: 0.2698313	total: 765ms	remaining: 1.63s
# 320:	learn: 0.2697119	total: 767ms	remaining: 1.62s
# 321:	learn: 0.2696872	total: 769ms	remaining: 1.62s
# 322:	learn: 0.2694963	total: 771ms	remaining: 1.61s
# 323:	learn: 0.2693563	total: 773ms	remaining: 1.61s
# 324:	learn: 0.2692387	total: 775ms	remaining: 1.61s
# 325:	learn: 0.2690400	total: 778ms	remaining: 1.61s
# 326:	learn: 0.2688471	total: 780ms	remaining: 1.6s
# 327:	learn: 0.2686976	total: 782ms	remaining: 1.6s
# 328:	learn: 0.2685269	total: 784ms	remaining: 1.6s
# 329:	learn: 0.2683735	total: 787ms	remaining: 1.6s
# 330:	learn: 0.2680978	total: 789ms	remaining: 1.59s
# 331:	learn: 0.2679095	total: 791ms	remaining: 1.59s
# 332:	learn: 0.2678118	total: 793ms	remaining: 1.59s
# 333:	learn: 0.2677326	total: 796ms	remaining: 1.59s
# 334:	learn: 0.2676182	total: 798ms	remaining: 1.58s
# 335:	learn: 0.2675100	total: 800ms	remaining: 1.58s
# 336:	learn: 0.2674139	total: 803ms	remaining: 1.58s
# 337:	learn: 0.2672931	total: 805ms	remaining: 1.58s
# 338:	learn: 0.2671254	total: 807ms	remaining: 1.57s
# 339:	learn: 0.2670182	total: 810ms	remaining: 1.57s
# 340:	learn: 0.2668948	total: 812ms	remaining: 1.57s
# 341:	learn: 0.2667930	total: 815ms	remaining: 1.57s
# 342:	learn: 0.2666265	total: 818ms	remaining: 1.57s
# 343:	learn: 0.2665234	total: 821ms	remaining: 1.56s
# 344:	learn: 0.2663900	total: 823ms	remaining: 1.56s
# 345:	learn: 0.2662281	total: 825ms	remaining: 1.56s
# 346:	learn: 0.2660796	total: 828ms	remaining: 1.56s
# 347:	learn: 0.2659811	total: 830ms	remaining: 1.55s
# 348:	learn: 0.2657739	total: 832ms	remaining: 1.55s
# 349:	learn: 0.2656178	total: 834ms	remaining: 1.55s
# 350:	learn: 0.2654564	total: 836ms	remaining: 1.55s
# 351:	learn: 0.2653784	total: 839ms	remaining: 1.54s
# 352:	learn: 0.2652804	total: 841ms	remaining: 1.54s
# 353:	learn: 0.2651380	total: 843ms	remaining: 1.54s
# 354:	learn: 0.2649989	total: 845ms	remaining: 1.54s
# 355:	learn: 0.2647925	total: 848ms	remaining: 1.53s
# 356:	learn: 0.2646998	total: 850ms	remaining: 1.53s
# 357:	learn: 0.2645585	total: 852ms	remaining: 1.53s
# 358:	learn: 0.2644417	total: 855ms	remaining: 1.53s
# 359:	learn: 0.2642984	total: 858ms	remaining: 1.52s
# 360:	learn: 0.2641385	total: 860ms	remaining: 1.52s
# 361:	learn: 0.2640187	total: 862ms	remaining: 1.52s
# 362:	learn: 0.2638079	total: 864ms	remaining: 1.52s
# 363:	learn: 0.2636761	total: 867ms	remaining: 1.51s
# 364:	learn: 0.2635532	total: 869ms	remaining: 1.51s
# 365:	learn: 0.2633705	total: 871ms	remaining: 1.51s
# 366:	learn: 0.2632677	total: 874ms	remaining: 1.51s
# 367:	learn: 0.2631283	total: 876ms	remaining: 1.5s
# 368:	learn: 0.2630476	total: 879ms	remaining: 1.5s
# 369:	learn: 0.2629307	total: 881ms	remaining: 1.5s
# 370:	learn: 0.2627863	total: 883ms	remaining: 1.5s
# 371:	learn: 0.2627080	total: 886ms	remaining: 1.5s
# 372:	learn: 0.2624277	total: 888ms	remaining: 1.49s
# 373:	learn: 0.2622793	total: 891ms	remaining: 1.49s
# 374:	learn: 0.2622067	total: 893ms	remaining: 1.49s
# 375:	learn: 0.2620938	total: 896ms	remaining: 1.49s
# 376:	learn: 0.2619919	total: 898ms	remaining: 1.48s
# 377:	learn: 0.2618859	total: 901ms	remaining: 1.48s
# 378:	learn: 0.2618042	total: 903ms	remaining: 1.48s
# 379:	learn: 0.2616777	total: 905ms	remaining: 1.48s
# 380:	learn: 0.2615835	total: 908ms	remaining: 1.47s
# 381:	learn: 0.2614867	total: 910ms	remaining: 1.47s
# 382:	learn: 0.2614242	total: 912ms	remaining: 1.47s
# 383:	learn: 0.2613543	total: 915ms	remaining: 1.47s
# 384:	learn: 0.2612146	total: 917ms	remaining: 1.46s
# 385:	learn: 0.2610610	total: 919ms	remaining: 1.46s
# 386:	learn: 0.2609307	total: 922ms	remaining: 1.46s
# 387:	learn: 0.2608096	total: 924ms	remaining: 1.46s
# 388:	learn: 0.2607121	total: 926ms	remaining: 1.46s
# 389:	learn: 0.2605894	total: 929ms	remaining: 1.45s
# 390:	learn: 0.2604756	total: 931ms	remaining: 1.45s
# 391:	learn: 0.2604079	total: 933ms	remaining: 1.45s
# 392:	learn: 0.2602858	total: 936ms	remaining: 1.45s
# 393:	learn: 0.2601823	total: 938ms	remaining: 1.44s
# 394:	learn: 0.2600291	total: 941ms	remaining: 1.44s
# 395:	learn: 0.2599061	total: 943ms	remaining: 1.44s
# 396:	learn: 0.2597915	total: 946ms	remaining: 1.44s
# 397:	learn: 0.2596583	total: 948ms	remaining: 1.43s
# 398:	learn: 0.2595001	total: 950ms	remaining: 1.43s
# 399:	learn: 0.2593598	total: 953ms	remaining: 1.43s
# 400:	learn: 0.2592285	total: 955ms	remaining: 1.43s
# 401:	learn: 0.2590771	total: 958ms	remaining: 1.42s
# 402:	learn: 0.2589457	total: 960ms	remaining: 1.42s
# 403:	learn: 0.2588648	total: 963ms	remaining: 1.42s
# 404:	learn: 0.2587573	total: 965ms	remaining: 1.42s
# 405:	learn: 0.2586314	total: 967ms	remaining: 1.42s
# 406:	learn: 0.2583231	total: 970ms	remaining: 1.41s
# 407:	learn: 0.2581244	total: 972ms	remaining: 1.41s
# 408:	learn: 0.2580486	total: 974ms	remaining: 1.41s
# 409:	learn: 0.2579304	total: 977ms	remaining: 1.41s
# 410:	learn: 0.2578408	total: 980ms	remaining: 1.4s
# 411:	learn: 0.2576771	total: 983ms	remaining: 1.4s
# 412:	learn: 0.2575717	total: 986ms	remaining: 1.4s
# 413:	learn: 0.2573902	total: 988ms	remaining: 1.4s
# 414:	learn: 0.2572636	total: 991ms	remaining: 1.4s
# 415:	learn: 0.2571862	total: 993ms	remaining: 1.39s
# 416:	learn: 0.2570230	total: 995ms	remaining: 1.39s
# 417:	learn: 0.2568788	total: 998ms	remaining: 1.39s
# 418:	learn: 0.2567297	total: 1s	remaining: 1.39s
# 419:	learn: 0.2565676	total: 1s	remaining: 1.38s
# 420:	learn: 0.2564871	total: 1s	remaining: 1.38s
# 421:	learn: 0.2563858	total: 1.01s	remaining: 1.38s
# 422:	learn: 0.2561758	total: 1.01s	remaining: 1.38s
# 423:	learn: 0.2560665	total: 1.01s	remaining: 1.37s
# 424:	learn: 0.2559357	total: 1.01s	remaining: 1.37s
# 425:	learn: 0.2558682	total: 1.02s	remaining: 1.37s
# 426:	learn: 0.2557051	total: 1.02s	remaining: 1.37s
# 427:	learn: 0.2555800	total: 1.02s	remaining: 1.36s
# 428:	learn: 0.2554788	total: 1.02s	remaining: 1.36s
# 429:	learn: 0.2552749	total: 1.03s	remaining: 1.36s
# 430:	learn: 0.2552037	total: 1.03s	remaining: 1.36s
# 431:	learn: 0.2550945	total: 1.03s	remaining: 1.35s
# 432:	learn: 0.2549746	total: 1.03s	remaining: 1.35s
# 433:	learn: 0.2548327	total: 1.03s	remaining: 1.35s
# 434:	learn: 0.2547592	total: 1.04s	remaining: 1.35s
# 435:	learn: 0.2546884	total: 1.04s	remaining: 1.35s
# 436:	learn: 0.2546116	total: 1.04s	remaining: 1.34s
# 437:	learn: 0.2544814	total: 1.04s	remaining: 1.34s
# 438:	learn: 0.2544049	total: 1.05s	remaining: 1.34s
# 439:	learn: 0.2543088	total: 1.05s	remaining: 1.34s
# 440:	learn: 0.2541618	total: 1.05s	remaining: 1.33s
# 441:	learn: 0.2540162	total: 1.05s	remaining: 1.33s
# 442:	learn: 0.2539265	total: 1.06s	remaining: 1.33s
# 443:	learn: 0.2538315	total: 1.06s	remaining: 1.33s
# 444:	learn: 0.2536810	total: 1.06s	remaining: 1.32s
# 445:	learn: 0.2535214	total: 1.06s	remaining: 1.32s
# 446:	learn: 0.2534189	total: 1.07s	remaining: 1.32s
# 447:	learn: 0.2533305	total: 1.07s	remaining: 1.32s
# 448:	learn: 0.2532583	total: 1.07s	remaining: 1.31s
# 449:	learn: 0.2530930	total: 1.07s	remaining: 1.31s
# 450:	learn: 0.2529952	total: 1.08s	remaining: 1.31s
# 451:	learn: 0.2529045	total: 1.08s	remaining: 1.31s
# 452:	learn: 0.2527848	total: 1.08s	remaining: 1.3s
# 453:	learn: 0.2527018	total: 1.08s	remaining: 1.3s
# 454:	learn: 0.2526226	total: 1.09s	remaining: 1.3s
# 455:	learn: 0.2525384	total: 1.09s	remaining: 1.3s
# 456:	learn: 0.2523838	total: 1.09s	remaining: 1.3s
# 457:	learn: 0.2522688	total: 1.09s	remaining: 1.29s
# 458:	learn: 0.2521719	total: 1.09s	remaining: 1.29s
# 459:	learn: 0.2520934	total: 1.1s	remaining: 1.29s
# 460:	learn: 0.2519414	total: 1.1s	remaining: 1.29s
# 461:	learn: 0.2518039	total: 1.1s	remaining: 1.28s
# 462:	learn: 0.2517003	total: 1.1s	remaining: 1.28s
# 463:	learn: 0.2515726	total: 1.11s	remaining: 1.28s
# 464:	learn: 0.2514272	total: 1.11s	remaining: 1.28s
# 465:	learn: 0.2513333	total: 1.11s	remaining: 1.27s
# 466:	learn: 0.2512750	total: 1.11s	remaining: 1.27s
# 467:	learn: 0.2511733	total: 1.12s	remaining: 1.27s
# 468:	learn: 0.2511182	total: 1.12s	remaining: 1.27s
# 469:	learn: 0.2509774	total: 1.12s	remaining: 1.26s
# 470:	learn: 0.2509180	total: 1.12s	remaining: 1.26s
# 471:	learn: 0.2508558	total: 1.13s	remaining: 1.26s
# 472:	learn: 0.2507324	total: 1.13s	remaining: 1.26s
# 473:	learn: 0.2505873	total: 1.13s	remaining: 1.26s
# 474:	learn: 0.2505199	total: 1.13s	remaining: 1.25s
# 475:	learn: 0.2504370	total: 1.14s	remaining: 1.25s
# 476:	learn: 0.2503102	total: 1.14s	remaining: 1.25s
# 477:	learn: 0.2501321	total: 1.14s	remaining: 1.25s
# 478:	learn: 0.2500639	total: 1.14s	remaining: 1.24s
# 479:	learn: 0.2499088	total: 1.15s	remaining: 1.24s
# 480:	learn: 0.2498003	total: 1.15s	remaining: 1.24s
# 481:	learn: 0.2497011	total: 1.15s	remaining: 1.24s
# 482:	learn: 0.2496358	total: 1.15s	remaining: 1.24s
# 483:	learn: 0.2494317	total: 1.16s	remaining: 1.23s
# 484:	learn: 0.2493505	total: 1.16s	remaining: 1.23s
# 485:	learn: 0.2492421	total: 1.16s	remaining: 1.23s
# 486:	learn: 0.2491814	total: 1.16s	remaining: 1.23s
# 487:	learn: 0.2490463	total: 1.17s	remaining: 1.22s
# 488:	learn: 0.2489288	total: 1.17s	remaining: 1.22s
# 489:	learn: 0.2488682	total: 1.17s	remaining: 1.22s
# 490:	learn: 0.2487867	total: 1.17s	remaining: 1.22s
# 491:	learn: 0.2486156	total: 1.18s	remaining: 1.21s
# 492:	learn: 0.2485036	total: 1.18s	remaining: 1.21s
# 493:	learn: 0.2484345	total: 1.18s	remaining: 1.21s
# 494:	learn: 0.2483642	total: 1.18s	remaining: 1.21s
# 495:	learn: 0.2483163	total: 1.19s	remaining: 1.2s
# 496:	learn: 0.2482396	total: 1.19s	remaining: 1.2s
# 497:	learn: 0.2481851	total: 1.19s	remaining: 1.2s
# 498:	learn: 0.2480530	total: 1.19s	remaining: 1.2s
# 499:	learn: 0.2479369	total: 1.19s	remaining: 1.19s
# 500:	learn: 0.2478840	total: 1.2s	remaining: 1.19s
# 501:	learn: 0.2477276	total: 1.2s	remaining: 1.19s
# 502:	learn: 0.2475990	total: 1.2s	remaining: 1.19s
# 503:	learn: 0.2475348	total: 1.2s	remaining: 1.18s
# 504:	learn: 0.2474807	total: 1.21s	remaining: 1.18s
# 505:	learn: 0.2472597	total: 1.21s	remaining: 1.18s
# 506:	learn: 0.2471881	total: 1.21s	remaining: 1.18s
# 507:	learn: 0.2470496	total: 1.21s	remaining: 1.18s
# 508:	learn: 0.2469994	total: 1.22s	remaining: 1.17s
# 509:	learn: 0.2468427	total: 1.22s	remaining: 1.17s
# 510:	learn: 0.2467786	total: 1.22s	remaining: 1.17s
# 511:	learn: 0.2467172	total: 1.22s	remaining: 1.17s
# 512:	learn: 0.2466614	total: 1.23s	remaining: 1.16s
# 513:	learn: 0.2465601	total: 1.23s	remaining: 1.16s
# 514:	learn: 0.2464834	total: 1.23s	remaining: 1.16s
# 515:	learn: 0.2463622	total: 1.23s	remaining: 1.16s
# 516:	learn: 0.2462721	total: 1.24s	remaining: 1.16s
# 517:	learn: 0.2461903	total: 1.24s	remaining: 1.15s
# 518:	learn: 0.2460513	total: 1.24s	remaining: 1.15s
# 519:	learn: 0.2459680	total: 1.24s	remaining: 1.15s
# 520:	learn: 0.2458092	total: 1.25s	remaining: 1.15s
# 521:	learn: 0.2456773	total: 1.25s	remaining: 1.14s
# 522:	learn: 0.2455235	total: 1.25s	remaining: 1.14s
# 523:	learn: 0.2454235	total: 1.25s	remaining: 1.14s
# 524:	learn: 0.2452820	total: 1.25s	remaining: 1.14s
# 525:	learn: 0.2451881	total: 1.26s	remaining: 1.13s
# 526:	learn: 0.2450614	total: 1.26s	remaining: 1.13s
# 527:	learn: 0.2448990	total: 1.26s	remaining: 1.13s
# 528:	learn: 0.2447735	total: 1.26s	remaining: 1.13s
# 529:	learn: 0.2446661	total: 1.27s	remaining: 1.12s
# 530:	learn: 0.2445223	total: 1.27s	remaining: 1.12s
# 531:	learn: 0.2443984	total: 1.27s	remaining: 1.12s
# 532:	learn: 0.2442854	total: 1.27s	remaining: 1.12s
# 533:	learn: 0.2442108	total: 1.28s	remaining: 1.11s
# 534:	learn: 0.2440932	total: 1.28s	remaining: 1.11s
# 535:	learn: 0.2439716	total: 1.28s	remaining: 1.11s
# 536:	learn: 0.2438559	total: 1.28s	remaining: 1.11s
# 537:	learn: 0.2437490	total: 1.29s	remaining: 1.1s
# 538:	learn: 0.2435985	total: 1.29s	remaining: 1.1s
# 539:	learn: 0.2435056	total: 1.29s	remaining: 1.1s
# 540:	learn: 0.2434223	total: 1.29s	remaining: 1.1s
# 541:	learn: 0.2433117	total: 1.3s	remaining: 1.09s
# 542:	learn: 0.2432569	total: 1.3s	remaining: 1.09s
# 543:	learn: 0.2431408	total: 1.3s	remaining: 1.09s
# 544:	learn: 0.2429837	total: 1.3s	remaining: 1.09s
# 545:	learn: 0.2429292	total: 1.3s	remaining: 1.08s
# 546:	learn: 0.2427991	total: 1.31s	remaining: 1.08s
# 547:	learn: 0.2426712	total: 1.31s	remaining: 1.08s
# 548:	learn: 0.2425462	total: 1.31s	remaining: 1.08s
# 549:	learn: 0.2424038	total: 1.31s	remaining: 1.07s
# 550:	learn: 0.2423411	total: 1.32s	remaining: 1.07s
# 551:	learn: 0.2422261	total: 1.32s	remaining: 1.07s
# 552:	learn: 0.2421091	total: 1.32s	remaining: 1.07s
# 553:	learn: 0.2419882	total: 1.32s	remaining: 1.07s
# 554:	learn: 0.2419414	total: 1.33s	remaining: 1.06s
# 555:	learn: 0.2418663	total: 1.33s	remaining: 1.06s
# 556:	learn: 0.2418205	total: 1.33s	remaining: 1.06s
# 557:	learn: 0.2416707	total: 1.33s	remaining: 1.06s
# 558:	learn: 0.2415566	total: 1.34s	remaining: 1.05s
# 559:	learn: 0.2414283	total: 1.34s	remaining: 1.05s
# 560:	learn: 0.2413789	total: 1.34s	remaining: 1.05s
# 561:	learn: 0.2413036	total: 1.34s	remaining: 1.05s
# 562:	learn: 0.2412081	total: 1.35s	remaining: 1.04s
# 563:	learn: 0.2411047	total: 1.35s	remaining: 1.04s
# 564:	learn: 0.2410388	total: 1.35s	remaining: 1.04s
# 565:	learn: 0.2408812	total: 1.35s	remaining: 1.04s
# 566:	learn: 0.2408261	total: 1.36s	remaining: 1.04s
# 567:	learn: 0.2407531	total: 1.36s	remaining: 1.03s
# 568:	learn: 0.2406652	total: 1.36s	remaining: 1.03s
# 569:	learn: 0.2405405	total: 1.36s	remaining: 1.03s
# 570:	learn: 0.2404357	total: 1.37s	remaining: 1.03s
# 571:	learn: 0.2403359	total: 1.37s	remaining: 1.02s
# 572:	learn: 0.2402012	total: 1.37s	remaining: 1.02s
# 573:	learn: 0.2400537	total: 1.37s	remaining: 1.02s
# 574:	learn: 0.2399204	total: 1.38s	remaining: 1.02s
# 575:	learn: 0.2397733	total: 1.38s	remaining: 1.01s
# 576:	learn: 0.2396720	total: 1.38s	remaining: 1.01s
# 577:	learn: 0.2395305	total: 1.38s	remaining: 1.01s
# 578:	learn: 0.2394734	total: 1.39s	remaining: 1.01s
# 579:	learn: 0.2394349	total: 1.39s	remaining: 1s
# 580:	learn: 0.2392827	total: 1.39s	remaining: 1s
# 581:	learn: 0.2391390	total: 1.39s	remaining: 1s
# 582:	learn: 0.2390555	total: 1.4s	remaining: 998ms
# 583:	learn: 0.2389252	total: 1.4s	remaining: 996ms
# 584:	learn: 0.2387822	total: 1.4s	remaining: 993ms
# 585:	learn: 0.2386577	total: 1.4s	remaining: 991ms
# 586:	learn: 0.2385610	total: 1.4s	remaining: 988ms
# 587:	learn: 0.2384822	total: 1.41s	remaining: 986ms
# 588:	learn: 0.2383458	total: 1.41s	remaining: 984ms
# 589:	learn: 0.2382610	total: 1.41s	remaining: 981ms
# 590:	learn: 0.2381313	total: 1.41s	remaining: 979ms
# 591:	learn: 0.2380307	total: 1.42s	remaining: 977ms
# 592:	learn: 0.2378884	total: 1.42s	remaining: 975ms
# 593:	learn: 0.2377930	total: 1.42s	remaining: 972ms
# 594:	learn: 0.2376990	total: 1.43s	remaining: 970ms
# 595:	learn: 0.2375569	total: 1.43s	remaining: 968ms
# 596:	learn: 0.2374522	total: 1.43s	remaining: 965ms
# 597:	learn: 0.2373476	total: 1.43s	remaining: 963ms
# 598:	learn: 0.2372817	total: 1.43s	remaining: 960ms
# 599:	learn: 0.2371360	total: 1.44s	remaining: 958ms
# 600:	learn: 0.2370241	total: 1.44s	remaining: 956ms
# 601:	learn: 0.2369159	total: 1.44s	remaining: 953ms
# 602:	learn: 0.2368443	total: 1.44s	remaining: 951ms
# 603:	learn: 0.2367694	total: 1.45s	remaining: 948ms
# 604:	learn: 0.2367075	total: 1.45s	remaining: 946ms
# 605:	learn: 0.2366227	total: 1.45s	remaining: 943ms
# 606:	learn: 0.2365544	total: 1.45s	remaining: 941ms
# 607:	learn: 0.2364939	total: 1.46s	remaining: 939ms
# 608:	learn: 0.2364181	total: 1.46s	remaining: 936ms
# 609:	learn: 0.2363472	total: 1.46s	remaining: 934ms
# 610:	learn: 0.2362049	total: 1.46s	remaining: 932ms
# 611:	learn: 0.2360632	total: 1.47s	remaining: 929ms
# 612:	learn: 0.2359661	total: 1.47s	remaining: 927ms
# 613:	learn: 0.2358886	total: 1.47s	remaining: 924ms
# 614:	learn: 0.2358299	total: 1.47s	remaining: 922ms
# 615:	learn: 0.2357245	total: 1.47s	remaining: 919ms
# 616:	learn: 0.2355782	total: 1.48s	remaining: 917ms
# 617:	learn: 0.2354703	total: 1.48s	remaining: 914ms
# 618:	learn: 0.2353316	total: 1.48s	remaining: 912ms
# 619:	learn: 0.2351731	total: 1.48s	remaining: 910ms
# 620:	learn: 0.2350079	total: 1.49s	remaining: 907ms
# 621:	learn: 0.2349140	total: 1.49s	remaining: 905ms
# 622:	learn: 0.2347843	total: 1.49s	remaining: 902ms
# 623:	learn: 0.2346929	total: 1.49s	remaining: 900ms
# 624:	learn: 0.2345593	total: 1.5s	remaining: 898ms
# 625:	learn: 0.2343997	total: 1.5s	remaining: 895ms
# 626:	learn: 0.2342872	total: 1.5s	remaining: 893ms
# 627:	learn: 0.2341758	total: 1.5s	remaining: 891ms
# 628:	learn: 0.2340825	total: 1.5s	remaining: 888ms
# 629:	learn: 0.2339802	total: 1.51s	remaining: 886ms
# 630:	learn: 0.2339102	total: 1.51s	remaining: 884ms
# 631:	learn: 0.2338068	total: 1.51s	remaining: 881ms
# 632:	learn: 0.2337498	total: 1.51s	remaining: 879ms
# 633:	learn: 0.2336867	total: 1.52s	remaining: 876ms
# 634:	learn: 0.2335756	total: 1.52s	remaining: 874ms
# 635:	learn: 0.2334885	total: 1.52s	remaining: 871ms
# 636:	learn: 0.2333719	total: 1.52s	remaining: 869ms
# 637:	learn: 0.2332397	total: 1.53s	remaining: 867ms
# 638:	learn: 0.2330929	total: 1.53s	remaining: 864ms
# 639:	learn: 0.2329637	total: 1.53s	remaining: 862ms
# 640:	learn: 0.2328763	total: 1.53s	remaining: 859ms
# 641:	learn: 0.2327824	total: 1.54s	remaining: 857ms
# 642:	learn: 0.2326727	total: 1.54s	remaining: 855ms
# 643:	learn: 0.2325671	total: 1.54s	remaining: 852ms
# 644:	learn: 0.2324649	total: 1.54s	remaining: 850ms
# 645:	learn: 0.2323469	total: 1.55s	remaining: 847ms
# 646:	learn: 0.2322925	total: 1.55s	remaining: 845ms
# 647:	learn: 0.2321948	total: 1.55s	remaining: 843ms
# 648:	learn: 0.2320137	total: 1.55s	remaining: 840ms
# 649:	learn: 0.2319658	total: 1.56s	remaining: 838ms
# 650:	learn: 0.2318527	total: 1.56s	remaining: 836ms
# 651:	learn: 0.2317579	total: 1.56s	remaining: 833ms
# 652:	learn: 0.2316275	total: 1.56s	remaining: 831ms
# 653:	learn: 0.2315708	total: 1.57s	remaining: 829ms
# 654:	learn: 0.2315198	total: 1.57s	remaining: 826ms
# 655:	learn: 0.2314851	total: 1.57s	remaining: 824ms
# 656:	learn: 0.2314187	total: 1.57s	remaining: 821ms
# 657:	learn: 0.2312970	total: 1.57s	remaining: 819ms
# 658:	learn: 0.2311902	total: 1.58s	remaining: 816ms
# 659:	learn: 0.2311333	total: 1.58s	remaining: 814ms
# 660:	learn: 0.2310162	total: 1.58s	remaining: 812ms
# 661:	learn: 0.2309309	total: 1.58s	remaining: 809ms
# 662:	learn: 0.2308355	total: 1.59s	remaining: 807ms
# 663:	learn: 0.2307329	total: 1.59s	remaining: 804ms
# 664:	learn: 0.2306302	total: 1.59s	remaining: 802ms
# 665:	learn: 0.2305733	total: 1.59s	remaining: 799ms
# 666:	learn: 0.2305283	total: 1.6s	remaining: 797ms
# 667:	learn: 0.2304599	total: 1.6s	remaining: 794ms
# 668:	learn: 0.2303978	total: 1.6s	remaining: 792ms
# 669:	learn: 0.2302983	total: 1.6s	remaining: 790ms
# 670:	learn: 0.2302421	total: 1.6s	remaining: 787ms
# 671:	learn: 0.2301179	total: 1.61s	remaining: 785ms
# 672:	learn: 0.2300768	total: 1.61s	remaining: 782ms
# 673:	learn: 0.2300024	total: 1.61s	remaining: 780ms
# 674:	learn: 0.2298966	total: 1.61s	remaining: 778ms
# 675:	learn: 0.2298256	total: 1.62s	remaining: 776ms
# 676:	learn: 0.2297472	total: 1.62s	remaining: 773ms
# 677:	learn: 0.2296698	total: 1.62s	remaining: 771ms
# 678:	learn: 0.2296196	total: 1.63s	remaining: 768ms
# 679:	learn: 0.2295506	total: 1.63s	remaining: 766ms
# 680:	learn: 0.2294568	total: 1.63s	remaining: 764ms
# 681:	learn: 0.2293714	total: 1.63s	remaining: 761ms
# 682:	learn: 0.2292721	total: 1.63s	remaining: 759ms
# 683:	learn: 0.2291062	total: 1.64s	remaining: 756ms
# 684:	learn: 0.2289765	total: 1.64s	remaining: 754ms
# 685:	learn: 0.2289234	total: 1.64s	remaining: 751ms
# 686:	learn: 0.2288390	total: 1.64s	remaining: 749ms
# 687:	learn: 0.2287582	total: 1.65s	remaining: 746ms
# 688:	learn: 0.2286953	total: 1.65s	remaining: 744ms
# 689:	learn: 0.2285652	total: 1.65s	remaining: 742ms
# 690:	learn: 0.2284217	total: 1.65s	remaining: 739ms
# 691:	learn: 0.2283161	total: 1.66s	remaining: 737ms
# 692:	learn: 0.2282571	total: 1.66s	remaining: 735ms
# 693:	learn: 0.2281710	total: 1.66s	remaining: 732ms
# 694:	learn: 0.2280414	total: 1.66s	remaining: 730ms
# 695:	learn: 0.2279255	total: 1.67s	remaining: 727ms
# 696:	learn: 0.2277670	total: 1.67s	remaining: 725ms
# 697:	learn: 0.2277156	total: 1.67s	remaining: 723ms
# 698:	learn: 0.2276065	total: 1.67s	remaining: 721ms
# 699:	learn: 0.2275423	total: 1.68s	remaining: 718ms
# 700:	learn: 0.2274434	total: 1.68s	remaining: 716ms
# 701:	learn: 0.2273957	total: 1.68s	remaining: 713ms
# 702:	learn: 0.2272748	total: 1.68s	remaining: 711ms
# 703:	learn: 0.2272153	total: 1.69s	remaining: 709ms
# 704:	learn: 0.2271536	total: 1.69s	remaining: 706ms
# 705:	learn: 0.2270918	total: 1.69s	remaining: 704ms
# 706:	learn: 0.2270015	total: 1.69s	remaining: 701ms
# 707:	learn: 0.2268857	total: 1.69s	remaining: 699ms
# 708:	learn: 0.2267958	total: 1.7s	remaining: 697ms
# 709:	learn: 0.2267290	total: 1.7s	remaining: 694ms
# 710:	learn: 0.2266047	total: 1.7s	remaining: 692ms
# 711:	learn: 0.2265256	total: 1.7s	remaining: 690ms
# 712:	learn: 0.2263738	total: 1.71s	remaining: 687ms
# 713:	learn: 0.2263234	total: 1.71s	remaining: 685ms
# 714:	learn: 0.2262789	total: 1.71s	remaining: 682ms
# 715:	learn: 0.2261390	total: 1.71s	remaining: 680ms
# 716:	learn: 0.2260089	total: 1.72s	remaining: 678ms
# 717:	learn: 0.2259306	total: 1.72s	remaining: 675ms
# 718:	learn: 0.2258698	total: 1.72s	remaining: 673ms
# 719:	learn: 0.2258032	total: 1.72s	remaining: 670ms
# 720:	learn: 0.2256904	total: 1.73s	remaining: 668ms
# 721:	learn: 0.2255840	total: 1.73s	remaining: 666ms
# 722:	learn: 0.2254807	total: 1.73s	remaining: 663ms
# 723:	learn: 0.2254261	total: 1.73s	remaining: 661ms
# 724:	learn: 0.2253540	total: 1.74s	remaining: 659ms
# 725:	learn: 0.2252474	total: 1.74s	remaining: 656ms
# 726:	learn: 0.2251349	total: 1.74s	remaining: 654ms
# 727:	learn: 0.2250060	total: 1.74s	remaining: 651ms
# 728:	learn: 0.2248923	total: 1.75s	remaining: 649ms
# 729:	learn: 0.2247703	total: 1.75s	remaining: 647ms
# 730:	learn: 0.2247072	total: 1.75s	remaining: 644ms
# 731:	learn: 0.2246447	total: 1.75s	remaining: 642ms
# 732:	learn: 0.2245711	total: 1.75s	remaining: 640ms
# 733:	learn: 0.2245348	total: 1.76s	remaining: 637ms
# 734:	learn: 0.2244711	total: 1.76s	remaining: 635ms
# 735:	learn: 0.2243786	total: 1.76s	remaining: 632ms
# 736:	learn: 0.2242813	total: 1.76s	remaining: 630ms
# 737:	learn: 0.2241848	total: 1.77s	remaining: 628ms
# 738:	learn: 0.2241329	total: 1.77s	remaining: 625ms
# 739:	learn: 0.2240357	total: 1.77s	remaining: 623ms
# 740:	learn: 0.2239199	total: 1.77s	remaining: 620ms
# 741:	learn: 0.2238363	total: 1.78s	remaining: 618ms
# 742:	learn: 0.2237778	total: 1.78s	remaining: 616ms
# 743:	learn: 0.2236795	total: 1.78s	remaining: 613ms
# 744:	learn: 0.2235778	total: 1.78s	remaining: 611ms
# 745:	learn: 0.2235039	total: 1.79s	remaining: 608ms
# 746:	learn: 0.2234037	total: 1.79s	remaining: 606ms
# 747:	learn: 0.2233402	total: 1.79s	remaining: 603ms
# 748:	learn: 0.2232925	total: 1.79s	remaining: 601ms
# 749:	learn: 0.2231870	total: 1.8s	remaining: 599ms
# 750:	learn: 0.2231464	total: 1.8s	remaining: 596ms
# 751:	learn: 0.2230825	total: 1.8s	remaining: 594ms
# 752:	learn: 0.2229718	total: 1.8s	remaining: 591ms
# 753:	learn: 0.2229253	total: 1.81s	remaining: 589ms
# 754:	learn: 0.2228165	total: 1.81s	remaining: 587ms
# 755:	learn: 0.2227355	total: 1.81s	remaining: 585ms
# 756:	learn: 0.2226248	total: 1.81s	remaining: 582ms
# 757:	learn: 0.2225569	total: 1.82s	remaining: 580ms
# 758:	learn: 0.2224569	total: 1.82s	remaining: 578ms
# 759:	learn: 0.2223982	total: 1.82s	remaining: 575ms
# 760:	learn: 0.2222839	total: 1.82s	remaining: 573ms
# 761:	learn: 0.2222195	total: 1.83s	remaining: 570ms
# 762:	learn: 0.2221350	total: 1.83s	remaining: 568ms
# 763:	learn: 0.2220497	total: 1.83s	remaining: 566ms
# 764:	learn: 0.2219246	total: 1.83s	remaining: 563ms
# 765:	learn: 0.2218864	total: 1.84s	remaining: 561ms
# 766:	learn: 0.2218284	total: 1.84s	remaining: 558ms
# 767:	learn: 0.2217529	total: 1.84s	remaining: 556ms
# 768:	learn: 0.2216938	total: 1.84s	remaining: 554ms
# 769:	learn: 0.2216595	total: 1.84s	remaining: 551ms
# 770:	learn: 0.2215615	total: 1.85s	remaining: 549ms
# 771:	learn: 0.2214769	total: 1.85s	remaining: 547ms
# 772:	learn: 0.2214121	total: 1.85s	remaining: 544ms
# 773:	learn: 0.2213241	total: 1.85s	remaining: 542ms
# 774:	learn: 0.2212239	total: 1.86s	remaining: 539ms
# 775:	learn: 0.2211510	total: 1.86s	remaining: 537ms
# 776:	learn: 0.2211011	total: 1.86s	remaining: 535ms
# 777:	learn: 0.2209992	total: 1.86s	remaining: 532ms
# 778:	learn: 0.2209579	total: 1.87s	remaining: 530ms
# 779:	learn: 0.2208587	total: 1.87s	remaining: 528ms
# 780:	learn: 0.2207628	total: 1.87s	remaining: 525ms
# 781:	learn: 0.2207303	total: 1.87s	remaining: 523ms
# 782:	learn: 0.2206363	total: 1.88s	remaining: 520ms
# 783:	learn: 0.2205352	total: 1.88s	remaining: 518ms
# 784:	learn: 0.2204646	total: 1.88s	remaining: 515ms
# 785:	learn: 0.2204315	total: 1.88s	remaining: 513ms
# 786:	learn: 0.2203245	total: 1.89s	remaining: 511ms
# 787:	learn: 0.2202444	total: 1.89s	remaining: 508ms
# 788:	learn: 0.2201508	total: 1.89s	remaining: 506ms
# 789:	learn: 0.2200456	total: 1.89s	remaining: 503ms
# 790:	learn: 0.2200021	total: 1.9s	remaining: 501ms
# 791:	learn: 0.2199264	total: 1.9s	remaining: 499ms
# 792:	learn: 0.2198697	total: 1.9s	remaining: 496ms
# 793:	learn: 0.2197676	total: 1.9s	remaining: 494ms
# 794:	learn: 0.2197102	total: 1.91s	remaining: 491ms
# 795:	learn: 0.2196788	total: 1.91s	remaining: 489ms
# 796:	learn: 0.2196073	total: 1.91s	remaining: 487ms
# 797:	learn: 0.2195551	total: 1.91s	remaining: 484ms
# 798:	learn: 0.2194658	total: 1.92s	remaining: 482ms
# 799:	learn: 0.2193754	total: 1.92s	remaining: 479ms
# 800:	learn: 0.2192807	total: 1.92s	remaining: 477ms
# 801:	learn: 0.2191146	total: 1.92s	remaining: 475ms
# 802:	learn: 0.2190290	total: 1.92s	remaining: 472ms
# 803:	learn: 0.2189457	total: 1.93s	remaining: 470ms
# 804:	learn: 0.2188713	total: 1.93s	remaining: 467ms
# 805:	learn: 0.2187927	total: 1.93s	remaining: 465ms
# 806:	learn: 0.2187227	total: 1.93s	remaining: 463ms
# 807:	learn: 0.2186699	total: 1.94s	remaining: 460ms
# 808:	learn: 0.2186249	total: 1.94s	remaining: 458ms
# 809:	learn: 0.2185659	total: 1.94s	remaining: 455ms
# 810:	learn: 0.2185069	total: 1.94s	remaining: 453ms
# 811:	learn: 0.2184720	total: 1.95s	remaining: 451ms
# 812:	learn: 0.2183916	total: 1.95s	remaining: 448ms
# 813:	learn: 0.2182923	total: 1.95s	remaining: 446ms
# 814:	learn: 0.2182106	total: 1.95s	remaining: 443ms
# 815:	learn: 0.2181160	total: 1.96s	remaining: 441ms
# 816:	learn: 0.2180410	total: 1.96s	remaining: 439ms
# 817:	learn: 0.2179458	total: 1.96s	remaining: 436ms
# 818:	learn: 0.2178712	total: 1.96s	remaining: 434ms
# 819:	learn: 0.2178207	total: 1.97s	remaining: 431ms
# 820:	learn: 0.2177530	total: 1.97s	remaining: 429ms
# 821:	learn: 0.2177090	total: 1.97s	remaining: 427ms
# 822:	learn: 0.2176398	total: 1.97s	remaining: 424ms
# 823:	learn: 0.2175872	total: 1.98s	remaining: 422ms
# 824:	learn: 0.2174806	total: 1.98s	remaining: 419ms
# 825:	learn: 0.2173996	total: 1.98s	remaining: 417ms
# 826:	learn: 0.2173052	total: 1.98s	remaining: 415ms
# 827:	learn: 0.2172587	total: 1.99s	remaining: 412ms
# 828:	learn: 0.2172033	total: 1.99s	remaining: 410ms
# 829:	learn: 0.2171523	total: 1.99s	remaining: 407ms
# 830:	learn: 0.2170778	total: 1.99s	remaining: 405ms
# 831:	learn: 0.2170112	total: 1.99s	remaining: 403ms
# 832:	learn: 0.2169183	total: 2s	remaining: 400ms
# 833:	learn: 0.2168382	total: 2s	remaining: 398ms
# 834:	learn: 0.2167359	total: 2s	remaining: 395ms
# 835:	learn: 0.2166847	total: 2s	remaining: 393ms
# 836:	learn: 0.2166293	total: 2s	remaining: 391ms
# 837:	learn: 0.2165326	total: 2.01s	remaining: 388ms
# 838:	learn: 0.2164777	total: 2.01s	remaining: 386ms
# 839:	learn: 0.2164197	total: 2.01s	remaining: 383ms
# 840:	learn: 0.2163263	total: 2.02s	remaining: 381ms
# 841:	learn: 0.2163028	total: 2.02s	remaining: 379ms
# 842:	learn: 0.2162217	total: 2.02s	remaining: 376ms
# 843:	learn: 0.2161482	total: 2.02s	remaining: 374ms
# 844:	learn: 0.2161105	total: 2.03s	remaining: 372ms
# 845:	learn: 0.2159879	total: 2.03s	remaining: 369ms
# 846:	learn: 0.2159180	total: 2.03s	remaining: 367ms
# 847:	learn: 0.2158743	total: 2.03s	remaining: 364ms
# 848:	learn: 0.2158113	total: 2.04s	remaining: 362ms
# 849:	learn: 0.2157335	total: 2.04s	remaining: 360ms
# 850:	learn: 0.2156101	total: 2.04s	remaining: 357ms
# 851:	learn: 0.2155222	total: 2.04s	remaining: 355ms
# 852:	learn: 0.2154715	total: 2.04s	remaining: 352ms
# 853:	learn: 0.2154139	total: 2.05s	remaining: 350ms
# 854:	learn: 0.2153735	total: 2.05s	remaining: 348ms
# 855:	learn: 0.2152737	total: 2.05s	remaining: 345ms
# 856:	learn: 0.2152096	total: 2.06s	remaining: 343ms
# 857:	learn: 0.2151616	total: 2.06s	remaining: 341ms
# 858:	learn: 0.2150303	total: 2.06s	remaining: 338ms
# 859:	learn: 0.2149177	total: 2.06s	remaining: 336ms
# 860:	learn: 0.2148484	total: 2.06s	remaining: 333ms
# 861:	learn: 0.2147938	total: 2.07s	remaining: 331ms
# 862:	learn: 0.2147322	total: 2.07s	remaining: 329ms
# 863:	learn: 0.2146475	total: 2.07s	remaining: 326ms
# 864:	learn: 0.2146018	total: 2.08s	remaining: 324ms
# 865:	learn: 0.2145065	total: 2.08s	remaining: 322ms
# 866:	learn: 0.2144157	total: 2.08s	remaining: 319ms
# 867:	learn: 0.2142936	total: 2.08s	remaining: 317ms
# 868:	learn: 0.2142377	total: 2.08s	remaining: 314ms
# 869:	learn: 0.2141455	total: 2.09s	remaining: 312ms
# 870:	learn: 0.2141057	total: 2.09s	remaining: 309ms
# 871:	learn: 0.2140312	total: 2.09s	remaining: 307ms
# 872:	learn: 0.2139546	total: 2.09s	remaining: 305ms
# 873:	learn: 0.2138614	total: 2.1s	remaining: 302ms
# 874:	learn: 0.2138057	total: 2.1s	remaining: 300ms
# 875:	learn: 0.2137080	total: 2.1s	remaining: 297ms
# 876:	learn: 0.2135645	total: 2.1s	remaining: 295ms
# 877:	learn: 0.2134903	total: 2.1s	remaining: 293ms
# 878:	learn: 0.2134431	total: 2.11s	remaining: 290ms
# 879:	learn: 0.2134074	total: 2.11s	remaining: 288ms
# 880:	learn: 0.2133580	total: 2.11s	remaining: 285ms
# 881:	learn: 0.2132553	total: 2.12s	remaining: 283ms
# 882:	learn: 0.2131419	total: 2.12s	remaining: 281ms
# 883:	learn: 0.2130537	total: 2.12s	remaining: 278ms
# 884:	learn: 0.2129558	total: 2.12s	remaining: 276ms
# 885:	learn: 0.2128148	total: 2.12s	remaining: 273ms
# 886:	learn: 0.2127209	total: 2.13s	remaining: 271ms
# 887:	learn: 0.2126517	total: 2.13s	remaining: 269ms
# 888:	learn: 0.2125938	total: 2.13s	remaining: 266ms
# 889:	learn: 0.2124808	total: 2.13s	remaining: 264ms
# 890:	learn: 0.2123680	total: 2.14s	remaining: 261ms
# 891:	learn: 0.2122739	total: 2.14s	remaining: 259ms
# 892:	learn: 0.2122269	total: 2.14s	remaining: 257ms
# 893:	learn: 0.2121482	total: 2.14s	remaining: 254ms
# 894:	learn: 0.2120619	total: 2.15s	remaining: 252ms
# 895:	learn: 0.2119848	total: 2.15s	remaining: 249ms
# 896:	learn: 0.2119398	total: 2.15s	remaining: 247ms
# 897:	learn: 0.2118441	total: 2.15s	remaining: 245ms
# 898:	learn: 0.2117773	total: 2.16s	remaining: 242ms
# 899:	learn: 0.2117077	total: 2.16s	remaining: 240ms
# 900:	learn: 0.2116452	total: 2.16s	remaining: 237ms
# 901:	learn: 0.2115535	total: 2.16s	remaining: 235ms
# 902:	learn: 0.2114935	total: 2.17s	remaining: 233ms
# 903:	learn: 0.2114083	total: 2.17s	remaining: 230ms
# 904:	learn: 0.2113648	total: 2.17s	remaining: 228ms
# 905:	learn: 0.2112815	total: 2.17s	remaining: 225ms
# 906:	learn: 0.2111977	total: 2.17s	remaining: 223ms
# 907:	learn: 0.2111115	total: 2.18s	remaining: 221ms
# 908:	learn: 0.2110325	total: 2.18s	remaining: 218ms
# 909:	learn: 0.2110061	total: 2.18s	remaining: 216ms
# 910:	learn: 0.2109332	total: 2.18s	remaining: 213ms
# 911:	learn: 0.2108333	total: 2.19s	remaining: 211ms
# 912:	learn: 0.2107760	total: 2.19s	remaining: 209ms
# 913:	learn: 0.2107254	total: 2.19s	remaining: 206ms
# 914:	learn: 0.2106828	total: 2.19s	remaining: 204ms
# 915:	learn: 0.2106326	total: 2.2s	remaining: 201ms
# 916:	learn: 0.2105377	total: 2.2s	remaining: 199ms
# 917:	learn: 0.2104350	total: 2.2s	remaining: 197ms
# 918:	learn: 0.2103849	total: 2.2s	remaining: 194ms
# 919:	learn: 0.2103134	total: 2.21s	remaining: 192ms
# 920:	learn: 0.2102228	total: 2.21s	remaining: 189ms
# 921:	learn: 0.2101443	total: 2.21s	remaining: 187ms
# 922:	learn: 0.2100708	total: 2.21s	remaining: 185ms
# 923:	learn: 0.2100164	total: 2.22s	remaining: 182ms
# 924:	learn: 0.2099154	total: 2.22s	remaining: 180ms
# 925:	learn: 0.2098575	total: 2.22s	remaining: 177ms
# 926:	learn: 0.2097946	total: 2.22s	remaining: 175ms
# 927:	learn: 0.2097304	total: 2.23s	remaining: 173ms
# 928:	learn: 0.2096713	total: 2.23s	remaining: 170ms
# 929:	learn: 0.2096029	total: 2.23s	remaining: 168ms
# 930:	learn: 0.2095162	total: 2.23s	remaining: 165ms
# 931:	learn: 0.2094335	total: 2.23s	remaining: 163ms
# 932:	learn: 0.2093839	total: 2.24s	remaining: 161ms
# 933:	learn: 0.2092891	total: 2.24s	remaining: 158ms
# 934:	learn: 0.2092307	total: 2.24s	remaining: 156ms
# 935:	learn: 0.2091619	total: 2.24s	remaining: 153ms
# 936:	learn: 0.2090013	total: 2.25s	remaining: 151ms
# 937:	learn: 0.2089540	total: 2.25s	remaining: 149ms
# 938:	learn: 0.2088287	total: 2.25s	remaining: 146ms
# 939:	learn: 0.2087820	total: 2.25s	remaining: 144ms
# 940:	learn: 0.2086805	total: 2.26s	remaining: 141ms
# 941:	learn: 0.2086116	total: 2.26s	remaining: 139ms
# 942:	learn: 0.2085328	total: 2.26s	remaining: 137ms
# 943:	learn: 0.2084706	total: 2.26s	remaining: 134ms
# 944:	learn: 0.2083870	total: 2.27s	remaining: 132ms
# 945:	learn: 0.2083269	total: 2.27s	remaining: 129ms
# 946:	learn: 0.2082668	total: 2.27s	remaining: 127ms
# 947:	learn: 0.2082090	total: 2.27s	remaining: 125ms
# 948:	learn: 0.2081529	total: 2.27s	remaining: 122ms
# 949:	learn: 0.2080708	total: 2.28s	remaining: 120ms
# 950:	learn: 0.2079860	total: 2.28s	remaining: 117ms
# 951:	learn: 0.2078057	total: 2.28s	remaining: 115ms
# 952:	learn: 0.2077592	total: 2.29s	remaining: 113ms
# 953:	learn: 0.2076813	total: 2.29s	remaining: 110ms
# 954:	learn: 0.2076074	total: 2.29s	remaining: 108ms
# 955:	learn: 0.2075175	total: 2.29s	remaining: 106ms
# 956:	learn: 0.2074323	total: 2.29s	remaining: 103ms
# 957:	learn: 0.2073752	total: 2.3s	remaining: 101ms
# 958:	learn: 0.2073188	total: 2.3s	remaining: 98.3ms
# 959:	learn: 0.2072910	total: 2.3s	remaining: 95.9ms
# 960:	learn: 0.2072570	total: 2.3s	remaining: 93.5ms
# 961:	learn: 0.2071726	total: 2.31s	remaining: 91.1ms
# 962:	learn: 0.2071425	total: 2.31s	remaining: 88.7ms
# 963:	learn: 0.2070978	total: 2.31s	remaining: 86.3ms
# 964:	learn: 0.2070323	total: 2.31s	remaining: 83.9ms
# 965:	learn: 0.2069806	total: 2.31s	remaining: 81.5ms
# 966:	learn: 0.2069343	total: 2.32s	remaining: 79.1ms
# 967:	learn: 0.2068665	total: 2.32s	remaining: 76.7ms
# 968:	learn: 0.2067855	total: 2.32s	remaining: 74.3ms
# 969:	learn: 0.2067419	total: 2.33s	remaining: 71.9ms
# 970:	learn: 0.2066942	total: 2.33s	remaining: 69.5ms
# 971:	learn: 0.2065997	total: 2.33s	remaining: 67.2ms
# 972:	learn: 0.2065469	total: 2.33s	remaining: 64.8ms
# 973:	learn: 0.2064708	total: 2.34s	remaining: 62.4ms
# 974:	learn: 0.2064254	total: 2.34s	remaining: 60ms
# 975:	learn: 0.2063774	total: 2.34s	remaining: 57.6ms
# 976:	learn: 0.2063103	total: 2.34s	remaining: 55.2ms
# 977:	learn: 0.2061950	total: 2.35s	remaining: 52.8ms
# 978:	learn: 0.2061087	total: 2.35s	remaining: 50.4ms
# 979:	learn: 0.2060289	total: 2.35s	remaining: 48ms
# 980:	learn: 0.2059800	total: 2.35s	remaining: 45.6ms
# 981:	learn: 0.2059389	total: 2.36s	remaining: 43.2ms
# 982:	learn: 0.2058606	total: 2.36s	remaining: 40.8ms
# 983:	learn: 0.2057901	total: 2.36s	remaining: 38.4ms
# 984:	learn: 0.2056949	total: 2.36s	remaining: 36ms
# 985:	learn: 0.2055799	total: 2.37s	remaining: 33.6ms
# 986:	learn: 0.2055083	total: 2.37s	remaining: 31.2ms
# 987:	learn: 0.2054446	total: 2.37s	remaining: 28.8ms
# 988:	learn: 0.2053554	total: 2.37s	remaining: 26.4ms
# 989:	learn: 0.2052696	total: 2.38s	remaining: 24ms
# 990:	learn: 0.2051956	total: 2.38s	remaining: 21.6ms
# 991:	learn: 0.2051163	total: 2.38s	remaining: 19.2ms
# 992:	learn: 0.2049967	total: 2.38s	remaining: 16.8ms
# 993:	learn: 0.2049362	total: 2.38s	remaining: 14.4ms
# 994:	learn: 0.2048342	total: 2.39s	remaining: 12ms
# 995:	learn: 0.2047368	total: 2.39s	remaining: 9.6ms
# 996:	learn: 0.2046571	total: 2.39s	remaining: 7.2ms
# 997:	learn: 0.2045732	total: 2.39s	remaining: 4.8ms
# 998:	learn: 0.2045103	total: 2.4s	remaining: 2.4ms
# 999:	learn: 0.2044296	total: 2.4s	remaining: 0us

# %% [markdown]
# # Hyperparameter tuning

# %%
# lgbm = LGBMClassifier(random_state=42)

# param_grid = {
#     'learning_rate': [0.1, 0.01],
#     'n_estimators': [50, 100, 150],
#     'max_depth': [4, 6],
#     'colsample_bytree': [0.7, 0.8, 0.9],
#     'subsample': [0.7, 0.8, 0.9],
#     'min_child_samples': [1, 5, 10]
# }

# GS = GridSearchCV(estimator=lgbm, 
#                   param_grid=param_grid, 
#                   scoring="f1", 
#                   cv=6, 
#                   refit="f1", 
#                   verbose=4)

# GS.fit(x_train, y_train)

# GS.best_params_

# {'colsample_bytree': 0.9,
#  'learning_rate': 0.1,
#  'max_depth': 6,
#  'min_child_samples': 1,
#  'n_estimators': 150,
#  'subsample': 0.7}

# %%
lgbm = LGBMClassifier(random_state=42, colsample_bytree=0.9, learning_rate=0.1, max_depth=6, min_child_samples=1, n_estimators=150, subsample=0.7)

lgbm.fit(x_train, y_train)
predictions = lgbm.predict(x_test)

print("ROC AUC: ", '{:.4%}'.format(roc_auc_score(y_test, predictions)))
print("Model accuracy: ", '{:.4%}'.format(accuracy_score(y_test, predictions)))
print("Precision: ", '{:.4%}'.format(precision_score(y_test, predictions)))
print("Recall: ", '{:.4%}'.format(recall_score(y_test, predictions)))
print("F1 Score: ", '{:.4%}'.format(f1_score(y_test, predictions)))
# Out:
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Info] Number of positive: 4144, number of negative: 4134
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000621 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 667
# [LightGBM] [Info] Number of data points in the train set: 8278, number of used features: 45
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500604 -> initscore=0.002416
# [LightGBM] [Info] Start training from score 0.002416
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# ROC AUC:  86.3718%
# Model accuracy:  86.3768%
# Precision:  87.0297%
# Recall:  85.3398%
# F1 Score:  86.1765%

# %%
# xgb = XGBClassifier(random_state=42)

# params = {
#         'min_child_weight': [1, 5, 10],
#         'gamma': [0.5, 1, 1.5, 2, 5],
#         'subsample': [0.6, 0.8, 1.0],
#         'colsample_bytree': [0.6, 0.8, 1.0],
#         'max_depth': [3, 4, 5]
#         }

# GS = GridSearchCV(estimator=xgb, 
#                   param_grid=params, 
#                   scoring="f1", 
#                   cv=6, 
#                   refit="f1", 
#                   verbose=4)

# GS.fit(x_train, y_train)

# GS.best_params_

# {'colsample_bytree': 1.0,
#  'gamma': 1,
#  'max_depth': 5,
#  'min_child_weight': 5,
#  'subsample': 0.8}

# %%
xgb = XGBClassifier(random_state=42, colsample_bytree=1, gamma=1, max_depth=5, min_child_weight=5, subsample=0.8)

xgb.fit(x_train, y_train)
predictions = xgb.predict(x_test)

print("ROC AUC: ", '{:.4%}'.format(roc_auc_score(y_test, predictions)))
print("Model accuracy: ", '{:.4%}'.format(accuracy_score(y_test, predictions)))
print("Precision: ", '{:.4%}'.format(precision_score(y_test, predictions)))
print("Recall: ", '{:.4%}'.format(recall_score(y_test, predictions)))
print("F1 Score: ", '{:.4%}'.format(f1_score(y_test, predictions)))
# Out:
# ROC AUC:  85.1167%
# Model accuracy:  85.1208%
# Precision:  85.6016%
# Recall:  84.2718%
# F1 Score:  84.9315%

# %%
# ada = AdaBoostClassifier(random_state=42)

# grid = dict()
# grid['n_estimators'] = [10, 50, 100, 500]
# grid['learning_rate'] = [0.0001, 0.001, 0.01, 0.1, 1.0]

# grid_search = GridSearchCV(estimator=ada, param_grid=grid, n_jobs=-1, cv=5, scoring='f1')

# grid_search.fit(x_train, y_train)

# grid_search.best_params_

# {'learning_rate': 1.0, 'n_estimators': 100}

# %%
ada = AdaBoostClassifier(random_state=42, learning_rate=1, n_estimators=100, )

ada.fit(x_train, y_train)
predictions = ada.predict(x_test)

print("ROC AUC: ", '{:.4%}'.format(roc_auc_score(y_test, predictions)))
print("Model accuracy: ", '{:.4%}'.format(accuracy_score(y_test, predictions)))
print("Precision: ", '{:.4%}'.format(precision_score(y_test, predictions)))
print("Recall: ", '{:.4%}'.format(recall_score(y_test, predictions)))
print("F1 Score: ", '{:.4%}'.format(f1_score(y_test, predictions)))
# Out:
# ROC AUC:  85.1204%
# Model accuracy:  85.1208%
# Precision:  85.0485%
# Recall:  85.0485%
# F1 Score:  85.0485%

# %%
# gbc = GradientBoostingClassifier()

# parameters = {
#     "n_estimators":[5,50,250,500],
#     "max_depth":[1,3,5,7,9],
#     "learning_rate":[0.01,0.1,1,10,100]
# }

# GS = GridSearchCV(estimator=gbc, 
#                   param_grid=parameters, 
#                   scoring="f1", 
#                   cv=6, 
#                   refit="f1", 
#                   verbose=4)

# GS.fit(x_train, y_train)

# GS.best_params_

# {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 250}

# %%
gbc = GradientBoostingClassifier(random_state=42, learning_rate=0.1, max_depth=3, n_estimators=250)

gbc.fit(x_train, y_train)
predictions = gbc.predict(x_test)

print("ROC AUC: ", '{:.4%}'.format(roc_auc_score(y_test, predictions)))
print("Model accuracy: ", '{:.4%}'.format(accuracy_score(y_test, predictions)))
print("Precision: ", '{:.4%}'.format(precision_score(y_test, predictions)))
print("Recall: ", '{:.4%}'.format(recall_score(y_test, predictions)))
print("F1 Score: ", '{:.4%}'.format(f1_score(y_test, predictions)))
# Out:
# ROC AUC:  85.0201%
# Model accuracy:  85.0242%
# Precision:  85.5030%
# Recall:  84.1748%
# F1 Score:  84.8337%

# %% [markdown]
# ## Final Machine Learning Model - GradientBoosting

# %%
X = df.drop(columns=["Churn", "AON", "Number of Additional Services"])
y = df["Churn"].replace({"Yes": 1, "No": 0})
X = pd.get_dummies(X).replace({True: 1, False: 0})

# %%
over = SMOTE(sampling_strategy = 1)
X,y = over.fit_resample(X,y)

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, random_state = 2, test_size = 0.2)

# %%
ss = StandardScaler()
mm = MinMaxScaler()
cols = ["MonthlyCharges", "TotalCharges", "tenure"]
x_train[cols] = mm.fit_transform(x_train[cols])

# %%
x_test[cols] = mm.transform(x_test[cols])

# %%
gbc = GradientBoostingClassifier(random_state=42)

gbc.fit(x_train, y_train)
predictions = gbc.predict(x_test)

print("ROC AUC: ", '{:.4%}'.format(roc_auc_score(y_test, predictions)))
print("Model accuracy: ", '{:.4%}'.format(accuracy_score(y_test, predictions)))
print("Precision: ", '{:.4%}'.format(precision_score(y_test, predictions)))
print("Recall: ", '{:.4%}'.format(recall_score(y_test, predictions)))
print("F1 Score: ", '{:.4%}'.format(f1_score(y_test, predictions)))

c_matrix = confusion_matrix(y_test, predictions)
    
percentages = (c_matrix / np.sum(c_matrix, axis=1)[:, np.newaxis]).round(2) * 100
labels = [[f"{c_matrix[i, j]} ({percentages[i, j]:.2f}%)" for j in range(c_matrix.shape[1])] for i in range(c_matrix.shape[0])]
labels = np.asarray(labels)

sns.heatmap(c_matrix, annot=labels, fmt='', cmap='Blues');
# Out:
# ROC AUC:  85.2656%
# Model accuracy:  85.2657%
# Precision:  85.1600%
# Recall:  85.2427%
# F1 Score:  85.2014%

# %%
predictions = gbc.predict(x_test)
fpr_rf, tpr_rf, thresholds = roc_curve(y_test, predictions)
plt.plot([0, 1], [0, 1], 'k--' )
plt.plot(fpr_rf, tpr_rf, label='GradientBoost Forest',color = "r")
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('GradientBoost ROC Curve',fontsize=16)
plt.show();

# %%
k = 5  
k_fold = KFold(n_splits = k, random_state = None)  
gbc = GradientBoostingClassifier(random_state=42)
gbc.fit(x_train, y_train)  
  
score = cross_val_score(gbc, x_test, y_test, cv = k_fold)  
  
mean_acc_score = sum(score) / len(score)  
   
print("Accuracy score of each fold: ", score)  
print("Mean accuracy score: ", mean_acc_score)
# Out:
# Accuracy score of each fold:  [0.83574879 0.852657   0.86231884 0.84299517 0.83574879]
# Mean accuracy score:  0.8458937198067632

# %%
pd.DataFrame({"features": x_train.columns, "importance":gbc.feature_importances_}).sort_values("importance", ascending=False)
# Out:
#                                    features  importance
# 36                  Contract_Month-to-month    0.232009
# 37                        Contract_One year    0.124859
# 1                                    tenure    0.111246
# 38                        Contract_Two year    0.056958
# 39                      PaperlessBilling_No    0.051438
# 16              InternetService_Fiber optic    0.039466
# 20                       OnlineSecurity_Yes    0.036799
# 29                          TechSupport_Yes    0.031771
# 44               PaymentMethod_Mailed check    0.024997
# 2                            MonthlyCharges    0.024796
# 40                     PaperlessBilling_Yes    0.024670
# 42    PaymentMethod_Credit card (automatic)    0.022979
# 6                                Partner_No    0.022563
# 3                              TotalCharges    0.020147
# 4                             gender_Female    0.019826
# 9                            Dependents_Yes    0.018843
# 8                             Dependents_No    0.017578
# 7                               Partner_Yes    0.011575
# 41  PaymentMethod_Bank transfer (automatic)    0.011134
# 12                         MultipleLines_No    0.010003
# 19       OnlineSecurity_No internet service    0.008929
# 21                          OnlineBackup_No    0.008868
# 31          StreamingTV_No internet service    0.008264
# 27                           TechSupport_No    0.007810
# 23                         OnlineBackup_Yes    0.007582
# 43           PaymentMethod_Electronic check    0.007554
# 34      StreamingMovies_No internet service    0.007203
# 5                               gender_Male    0.005320
# 14                        MultipleLines_Yes    0.004761
# 18                        OnlineSecurity_No    0.004563
# 15                      InternetService_DSL    0.004332
# 33                       StreamingMovies_No    0.002433
# 30                           StreamingTV_No    0.002194
# 17                       InternetService_No    0.001871
# 26                     DeviceProtection_Yes    0.001853
# 24                      DeviceProtection_No    0.000946
# 11                         PhoneService_Yes    0.000776
# 13           MultipleLines_No phone service    0.000612
# 0                             SeniorCitizen    0.000473
# 35                      StreamingMovies_Yes    0.000000
# 32                          StreamingTV_Yes    0.000000
# 28          TechSupport_No internet service    0.000000
# 25     DeviceProtection_No internet service    0.000000
# 10                          PhoneService_No    0.000000
# 22         OnlineBackup_No internet service    0.000000
